# %% [raw]
# Compile the slides:
# jupyter nbconvert Basic_workflows_service_integration.ipynb --to slides --template reveal_mod --SlidesExporter.reveal_scroll=True

# %% [markdown]
# <img src="https://www.uu.se/images/18.17dda5f1791cdbd287d9b55/1622452923523/uu-logo-red.svg" alt="Uppsala universitet logo" width="10%" style="position: absolute; top: 0; left: 0;"/>
# <img src="./images/EPOS_SS_square.png" alt="EPOS Summer School 2025" width="50%" style="float: right; padding:0; margin:0;"/>
# <div style="padding-top: 15%;"/>
#
# ***
# ## <center><span style="color:green; line-height:1.5em;">Discovery, automation/scripting and integration of EPOS data and services</span><br><span style="font-size:0.8em;">Basic workflows in JupyterLab</span></center>
# ***
#
# <center>Henning Lorenz<br>Uppsala University, Sweden<br><a href="mailto:henning.lorenz@geo.uu.se">henning.lorenz@geo.uu.se</a></center>
#
#
#
# &nbsp;
#
# &nbsp;
#
# <img src="https://epos-se.se/images/Steering%20committee/outreach/EPOS_SWEDEN_small.png" alt="EPOS Sweden logo" width="20%" style="position: absolute; bottom: 0; left: 0;"/>

# %% [markdown]
# ## <span style="color:green">Topics we touch:</span>
# <br>
#
# __The Basics__
#   * Summary of the basic setup of JupyterLab
#   * Basic useful modules
#
# __Data and Data Transfer__>
#   * How to interface with EPOS Services
#     * Data/service types
#     * Standards
#     * Interaction with services
#     * Dedicated Python modules
#   * How to read the data
#     * Data formats
#     * Standards
#
# __What to do with the data__
#
#   * Data handling
#   * Processing and visualisation
#
# __Examples__
#
#   * Interacting with services and data
#
# __Demonstration case__

# %% [markdown]
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <center><span style="color:green; font-size:3em; font-weight:bold;">The Basics</span></center>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>

# %% [markdown]
# ## <span style="color:green">Summary of the basic setup of JupyterLab:<br><span style="font-size: .8rem">(Assuming that Python runs under the operating system, assuming here Linux/Ubuntu.)</span>
#
# #### Install python virtual environments
# ```
# sudo apt install python3-venv
# ```
#
# #### Create a python virtual environment <span style="font-size: .8rem">(If you are on a virtual machine, like WSL, the python virtual environment has to be on the Linux file system!)</span>
# ```
# python -m venv jupyter-EPOS-SS2025
# ```
#
# #### Create a working folder for JupyterLabs <span style="font-size: .8rem">(If you are on a virtual machine, like WSL, this folder can be anywhere, also in mounted file systems, like that of the host.)</span>
# ```
# mkdir jupyter-EPOS-SS2025/projects
# ```
#
# #### Go to the working folder and start your virtual environment
# ```
# cd jupyter-EPOS-SS2025/projects
# source ../bin/activate
# ```
# Check that the command prompt starts with (\<name\>) of the virtual environment, which indicates that it is running.

# %% [markdown]
# #### Update the pip package manager to the latest version
# This regards the package manager of your virtual environment. Thus, it is important to activate the virtual environment before updating!
# ```
# python -m pip install --upgrade pip
# ```

# %% [markdown]
# #### Install JupyterLab and all modules needed for this notebook
# ```
# pip install jupyter scikit-image owslib pyproj pprintpp obspy cartopy folium mpld3 geopandas
# ```

# %% [markdown]
# ## <span style="color:green">Some basic modules that are good to remember:
# | | |
# |-|-|
# |__os__                  | Provides usage of operating system dependent functionality, e.g. `os.path()` to manipulate paths |
# |__warnings&emsp;__      | Handles warning and error messages, e.g. suppress warnings that interfere with your work with `warnings.simplefilter("ignore")` |
# |__re__                  | Provides regular expression matching operations similar to those found in Perl - use [https://regexr.com/](RegExr) or similar for testing filters|
# |__math__                | Provides access to the mathematical functions defined by the C standard |
# |__pprint__              | Pretty printing of data structures |
# |__pprintpp__<br>(pp-ez) | Another pretty-printer for data structures _(pip install pp-ez)_ |
#
# Sometimes, JupyterLab recogises modules that are installed while it is running, sometimes you have to restart.

# %% [markdown]
# ## <span style="color:green; line-height: 1.5em;"><center>Remember:<br>Your best friend is the documentation!
# ### <center>For core modules: [https://docs.python.org/3/library/<module-name\>.html](https://docs.python.org/3/library/<module-name>.html)
# ### <center>For projects (modules installed with pip): [https://pypi.org/project/<project-name\>/](https://pypi.org/project/<project-name>/)
# ### <center>For basics, look at https://www.w3schools.com/python
# ### <center>Scientific modules and web services often have dedicated tutorials

# %% [markdown]
# ## <span style="color:green; line-height: 1.5em;"><center>Remember as well:<br>Most problems were encountered and solved before!
# ### <center>Search dedicated web-fora, e.g. [Python Forum](https://python-forum.io/)
# ### <center>Search the web! (Reddit, stackoverflow, ...)
# ### <center>Ask your preferred AI model.

# %% [markdown]
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <center><span style="color:green; font-size:3em; font-weight:bold;">Data and data transfer</span></center><br>
# <center><span style="color:green; font-size:2.5em; font-weight:bold;">How to interface with EPOS services</span></center>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>

# %% [markdown]
# <span style="font-size:1.25em;">How to interface with EPOS services</span><br>
# <span style="color:green; font-size: 2em;">What (community) standards for data and data exchange do the TCSs use?</span>

# %% [markdown]
# <span style="font-size:1.2em;">TCS Seismology</span><br>
# <i>Data formats:</i>&emsp; various ASCII, JSON (GeoJSON), XML, images, SAC (binary or ASCII) and binary miniSEED time series<br>
# <i>Data transfer:</i><br>
# &emsp;<i>Webservices:</i>&emsp; WFS, WMS, ESM (Engineering Strong Motion) Web Services, FDSN (Federation of Digital Seismographs) Web Service<br>
# &emsp;<i>APIs:</i>&emsp;&emsp;&emsp;&emsp;&nbsp; EMSC (European-Mediterranean Seismological Centre) APIs, EIDA (European Integrated Data Archive) API<br>
# &emsp;<i>other:</i>&emsp;&emsp;&emsp;&emsp; -
# <br>
# <br>
# <br>
# <span style="font-size:1.2em;">TCS Near-Fault Observatories</span><br>
# <i>Data formats:</i>&emsp; ASCII, JSON (GeoJSON, CovJSON), XML, binary miniSEED time series<br>
# <i>Data transfer:</i><br>
# &emsp;<i>Webservices:</i>&emsp; WFS, NFO Web Service, FDSNWS<br>
# &emsp;<i>APIs:</i>&emsp;&emsp;&emsp;&emsp;&nbsp; EIDA API<br>
# &emsp;<i>other:</i>&emsp;&emsp;&emsp;&emsp; -
# <br>
# <br>
# <br>
# <span style="font-size:1.2em;">TCS GNSS Data and Products</span><br>
# <i>Data formats:</i>&emsp; ASCII, JSON (CovJSON), XML, image, RINEX<br>
# <i>Data transfer:</i><br>
# &emsp;<i>Webservices:</i>&emsp; -<br>
# &emsp;<i>APIs:</i>&emsp;&emsp;&emsp;&emsp;&nbsp; <i>GLASS (Geodetic Linkage Advance Software System) Framework API</i><br>
# &emsp;<i>other:</i>&emsp;&emsp;&emsp;&emsp; HTTP download
# <br>
# <br>
# <br>
# <span style="font-size:1.2em;">TCS Volcano Observations</span><br>
# <i>Data formats:</i>&emsp; ASCII, JSON (GeoJSON, CovJSON), XML, image, georeferenced image, PDF, RINEX, binary octet-stream & miniSEED time series<br>
# <i>Data transfer:</i><br>
# &emsp;<i>Webservices:</i>&emsp; WMS, FDSNWS, EPOS Volcano Activity Reports Web Service<br>
# &emsp;<i>APIs:</i>&emsp;&emsp;&emsp;&emsp;&nbsp; diverse APIs for EPOS, Geo-INQUIRE API<br>
# &emsp;<i>other:</i>&emsp;&emsp;&emsp;&emsp; HTTP download
# <br>
# <br>
# <br>
# <span style="font-size:1.2em;">TCS Satellite Data</span><br>
# <i>Data formats:</i>&emsp; JSON (GeoJSON), image, georeferenced image, NetCDF<br>
# <i>Data transfer:</i><br>
# &emsp;<i>Webservices:</i>&emsp; diverse web services for EPOS<br>
# &emsp;<i>APIs:</i>&emsp;&emsp;&emsp;&emsp;&nbsp; -<br>
# &emsp;<i>other:</i>&emsp;&emsp;&emsp;&emsp; HTTP download
# <br>
# <br>
# <br>
# <span style="font-size:1.2em;">TCS Geomagnetic Observations</span><br>
# <i>Data formats:</i>&emsp; various ASCII (e.g. IAGA-2002), JSON (MT-JSON, CovJSON), image<br>
# <i>Data transfer:</i><br>
# &emsp;<i>Webservices:</i>&emsp; ISGI (International Service of Geomagnetic Indices), INTERMAGNET Web Service, EMTDAMO (European Service of Magnetotelluric Data and Models), Geomagnetic Model Web Service, WDC webservices at BGS<br>
# &emsp;<i>APIs:</i>&emsp;&emsp;&emsp;&emsp;&nbsp; -<br>
# &emsp;<i>other:</i>&emsp;&emsp;&emsp;&emsp; HTTP download
# <br>
# <br>
# <br>
# <span style="font-size:1.2em;">TCS Anthropogenic Hazards</span><br>
# <i>Data formats:</i>&emsp; various ASCII (e.g GDF, MDDF) JSON (GeoJSON), XML (SeisComP3Markup Language), binary Matlab, SAC (binary and ASCII) & binary SEED/miniSEED time series<br>
# <i>Data transfer:</i><br>
# &emsp;<i>Webservices:</i>&emsp; -<br>
# &emsp;<i>APIs:</i>&emsp;&emsp;&emsp;&emsp;&nbsp; <i>EPISODES PLATFORM</i><br>
# &emsp;<i>other:</i>&emsp;&emsp;&emsp;&emsp; HTTP download
# <br>
# <br>
# <br>
# <span style="font-size:1.2em;">TCS Geological Information and Modelling</span><br>
# <i>Data formats:</i>&emsp; XML (GeoSciML, ERML, extended), JSON (GeoJSON), image<br>
# <i>Data transfer:</i><br>
# &emsp;<i>Webservices:</i>&emsp; WFS, WMS<br>
# &emsp;<i>APIs:</i>&emsp;&emsp;&emsp;&emsp;&nbsp; -<br>
# &emsp;<i>other:</i>&emsp;&emsp;&emsp;&emsp; -
# <br>
# <br>
# <br>
# <span style="font-size:1.2em;">TCS Multi-Scale Laboratories</span><br>
# <i>Data formats:</i>&emsp; JSON (GeoJSON) -> various formats as used in data publications<br>
# <i>Data transfer:</i><br>
# &emsp;<i>Webservices:</i>&emsp; -<br>
# &emsp;<i>APIs:</i>&emsp;&emsp;&emsp;&emsp;&nbsp; EPOS MSL API<br>
# &emsp;<i>other:</i>&emsp;&emsp;&emsp;&emsp; HTTP download<br>
# <br>
# <br>
# <br>
# <span style="font-size:1.2em;">TCS Tsunami</span><br>
# <i>Data formats:</i>&emsp; ASCII, JSON (GeoJSON), image<br>
# <i>Data transfer:</i><br>
# &emsp;<i>Webservices:</i>&emsp; WFS, WMS<br>
# &emsp;<i>APIs:</i>&emsp;&emsp;&emsp;&emsp;&nbsp; -<br>
# &emsp;<i>other:</i>&emsp;&emsp;&emsp;&emsp; -

# %% [markdown]
# <span style="font-size:1.25em;">How to interface with EPOS services</span><br>
# <span style="color:green; font-size: 2em;">Data and related services</span>

# %% [markdown]
# <span style="font-size:1.4em;">Metadata/Metainformation</span><br>
# &emsp;<span style="font-size:1.2em;">&rarr; Information about Data.</span>
# * In the strict IT definition, it describes only the form of data (data sets, data services).
# * In the scientific context, it is often used as description for "something" that provides context to the scientific data set.<br>
#   &rarr; According to the IT definition, the scientific metadata are data.

# %% [markdown]
# <span style="font-size:1.4em;">"Discovery data"</span> <i>(informal)</i><br>
# &emsp;<span style="font-size:1.2em;">&rarr; Data that provide essential information about a data set or an object,<br>&emsp;&emsp;allowing a user to decide whether the instance in question is relevant for a certain purpose or not.</span>
# * Related to the scientific definition of metainformation.
# * Most of what we see in the EPOS portal falls in this category.
# * A similar concept as IUGS CGI/OGC standards (GeoSciML) Portrayal/Lite

# %% [markdown]
# <span style="font-size:1.4em;">Data/data sets</span><br>
# &emsp;<span style="font-size:1.2em;">&rarr; The scientific data.</span>
# * What it is all about.

# %% [markdown]
# <span style="font-size:1.25em;">How to interface with EPOS services</span><br>
# <span style="color:green; font-size: 2em;">Interacting with the <a href="https://www.ics-c.epos-eu.org/">EPOS data portal</a> in JupyterLab (JL)</span>

# %% [markdown]
# <span style="font-size:1.4em;">__Distinct discovered data sets__</span><br>
# &emsp;<span style="font-size:1.2em;">&rarr; You know exactly what you want and proceed to processing/visualisation.</span>
# * ICS-D: Add the filtered service to your "Favourites" in the portal. The data set will be part of the generated JL.
# * Any JL: __In the "Download" pop-up window, use the HTML link to the data set.<br>Then you have to (down)load the data set in JL.__

# %% [markdown]
# <span style="font-size:1.4em;">__Web services and APIs, automatisation__</span><br>
# &emsp;<span style="font-size:1.2em;">&rarr; You use the portal for exploring available content, but interface services in JL, to establish<br>&emsp;&emsp;workflows for repeated task or for easy tuning of paramenters in the data discovery.</span>
# * ICS-D: Add the filtered service to your "Favourites" in the portal.
# * Any JL: __In the "Download" pop-up window, use the HTML link to the "raw service response".__

# %% [markdown]
# <span style="font-size:1.4em;">__Any combination of the above__</span><br>
# &emsp;<span style="font-size:1.2em;">&rarr; Use the EPOS services how they best fit your task. Integrate your local data in the processing.</span>

# %% [markdown]
# <span style="font-size:1.25em;">How to interface with EPOS services in Python</span><br>
# <span style="color:green; font-size: 2em;">Summary of services and APIs</span>

# %% [markdown]
# <span style="font-size:1.4em;">International standards</span><br>
# OWS (WFS, WMS)

# %% [markdown]
# <span style="font-size:1.4em;">Community standards</span><br>
# ESM Web Services, FDSN Web Service, ISGI, INTERMAGNET Web Service<br>
# EMSC API, EIDA API

# %% [markdown]
# <span style="font-size:1.4em;">EPOS related</span><br>
# &emsp;<span style="font-size:1.2em;">&rarr; "New community standards"</span><br>
# NFO Web Service, EPOS Volcano Activity Reports Web Service, EMTDAMO, Geomagnetic Model Web Service<br>
# GLASS Framework API, Geo-INQUIRE API, EPISODES Platform, EPOS MSL API
#
# TCS SD web services, TCS VO APIs, WDC webservices at BGS

# %% [markdown]
# <span style="font-size:1.25em;">How to interface with EPOS services in Python</span><br>
# <span style="color:green; font-size: 2em;">Interaction with standardised services</span>

# %% [markdown]
# ### General HTTP requests <span style="font-size:0.8em;">_(data set download and all services/APIs)_</span>
# __urllib__ - `urllib.request()` for opening and reading URLs (`urllib.parse()` for parsing URLs)
#
# __requests__ - User friendly handling of HTTP requests _(pip install requests)_
#
# __pooch__ - (part of Fatiando a Terra, see below) Fetch data files, also by DOI _(pip install pooch)_

# %% [markdown]
# ### Open Geospatial Consortium (OGC) web services (OWS) <span style="font-size:0.8em;">_some services are also ISO standard_</span>
# __OWSLib__ - Facilitates the interaction with OWS like WFS, WMS, OGC API, and many more _(pip install OWSLib)_<br>
# &emsp;&rarr; <a href="https://www.osgeo.org/projects/owslib/">Homepage</a><br>
# &emsp;&rarr; <a href="https://owslib.readthedocs.io">Documentation</a><br>
# &emsp;&rarr; <a href="https://lists.osgeo.org/mailman/listinfo/owslib-users">Mailing list</a>

# %% [markdown]
# <span style="font-size:1.25em;">How to interface with EPOS services in Python</span><br>
# <span style="color:green; font-size: 2em;">Other modules that facilitate data access and processing/visualisation</span>

# %% [markdown]
# ### TCS Seismology
# __ObsPy__ - A Python framework for Seismology _(pip install obspy)_<br>
# "ObsPy is an open-source project dedicated to provide a Python framework for processing seismological data. It provides parsers for common file formats, clients to access data centers and seismological signal processing routines which allow the manipulation of seismological time series."<br>
# &emsp;&rarr; <a href="https://pypi.org/project/obspy/">Module page</a><br>
# &emsp;&rarr; <a href="https://www.obspy.org">Homepage</a><br>
# &emsp;&rarr; <a href="https://docs.obspy.org/">Documentation</a><br>
# &emsp;&rarr; <a href="https://discourse.obspy.org/">Forum</a>
#
# __EMSC__: scripts available at <a href="https://github.com/EMSC-CSEM/webservices101">Github</a>

# %% [markdown]
# ### TCS GNSS Data and Products
# __Pyglass__ - Python command line tool to query a GLASS server _(no pip install, pip would install a different package with the same name)_<br>
# &emsp;&rarr; <a href="https://gitlab.com/gpseurope">GitLab</a>
#
# __gnss-lib-py__ - Python tool for parsing, analyzing, and visualizing Global Navigation Satellite Systems (GNSS) data and state estimates _(pip install gnss-lib-py)_<br>
# &emsp;&rarr; <a href="https://pypi.org/project/gnss-lib-py/">Module page</a><br>
# &emsp;&rarr; <a href="https://github.com/Stanford-NavLab/gnss_lib_py">GitHub</a><br>
# &emsp;&rarr; <a href="https://gnss-lib-py.readthedocs.io/en/latest/">Documentation</a>

# %% [markdown]
# <span style="font-size:1.25em;">How to interface with EPOS services in Python</span><br>
# <span style="color:green; font-size: 2em;">Other modules that facilitate data access and processing/visualisation</span>

# %% [markdown]
# ### TCS Geomagnetic Observations
# __GeomagPy__ - A Python package for analysing and displaying geomagnetic data _(pip install geomagpy)_<br>
# "MagPy provides tools for geomagnetic data analysis with special focus on typical data processing routines in observatories. MagPy provides methods for data format conversion, plotting and mathematical procedures with specifically geomagnetic analysis routines such as basevalue and baseline calculation and database handling."<br>
# &emsp;&rarr; <a href="https://pypi.org/project/geomagpy">Module page</a><br>
# &emsp;&rarr; <a href="https://github.com/geomagpy/magpy">GitHub</a>
#
# __MTpy-v2__: A Python Toolbox for working with Magnetotelluric (MT) Data _(pip install mtpy-v2)_<br>
# "mtpy provides tools for working with magnetotelluric (MT) data... a central data type that can hold transfer functions and then read/write to your modeling program, plot, and analyze your data."<br>
# &emsp;&rarr; <a href="https://pypi.org/project/mtpy-v2/">Module page</a><br>
# &emsp;&rarr; <a href="https://github.com/MTgeophysics/mtpy-v2">GitHub</a><br>
# &emsp;&rarr; <a href="https://mtpy-v2.readthedocs.io">Documentation</a>

# %% [markdown]
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <center><span style="color:green; font-size:3em; font-weight:bold;">Data and data transfer</span></center><br>
# <center><span style="color:green; font-size:2.5em; font-weight:bold;">How to read the data</span></center>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>

# %% [markdown]
# <span style="font-size:1.25em;">How to read the data</span><br>
# <span style="color:green; font-size: 2em;">Summary of data formats</span>

# %% [markdown]
# <span style="font-size:1.4em;">International standards</span><br>
# ASCII/UTF-8 (CSV, ...), JSON (GeoJSON), XML, image (TIFF, GeoTIFF), NetCDF

# %% [markdown]
# <span style="font-size:1.4em;">Community standards</span><br>
# ASCII (IAGA-2002, GDF, MDDF), JSON (CovJSON, MT-JSON), SAC (binary or ASCII), miniSEED (binary), RINEX, octet-stream (binary)

# %% [markdown]
# <span style="font-size:1.4em;">Proprietary</span><br>
# MatLab

# %% [markdown]
# <span style="font-size:1.25em;">How to read the data</span><br>
# <span style="color:green; font-size: 2em;">ASCII/UTF-8 vs binary data formats</span>

# %% [markdown]
# * <span style="font-size:1.2em;">Python can open and read any ASCII/UTF-8 encoded file to a variable. However, it might be difficult to interact with the data in the file.</span><br>
# * <span style="font-size:1.2em;">Binary files are notorously difficult to handle if no modules/libraries exist for accessing the data.</span>

# %% [markdown]
# &emsp;<span style="font-size:1.2em;">&rarr; Check the modules listed under services (above).</span><br>

# %% [markdown]
# <span style="font-size:1.25em;">How to read the data</span><br>
# <span style="color:green; font-size: 2em;">Community standards</span>

# %% [markdown]
# &emsp;<span style="font-size:1.2em;">&rarr; Check the modules listed under services (above).</span><br>
# &emsp;&emsp;&emsp;__Obspy__ to interact with the seismic data formats,<br>
# &emsp;&emsp;&emsp;__Pyglass__ and __gnss-lib-py__ for RINEX data,<br>
# &emsp;&emsp;&emsp;__GeomagPy__ and __MTpy-v2__ for geomagnetic data.

# %% [markdown]
# <span style="font-size:1.25em;">How to read the data</span><br>
# <span style="color:green; font-size: 2em;">Standards/Universal data formats</span>

# %% [markdown]
# ### JSON
# __json__ - JSON encoder and decoder
#
# ### XML
# __xml__ - Collection of XML modules, of which xml.etree.ElementTree is the XML processor<br>
# __lxml__ - User friendly third-party XML processor: lxml.etree _(pip install lxml)_
#
# ### CSV
# __csv__ - CSV file reading and writing
#
# ### TIFF, GeoTIFF
# __Pillow__ - Image import and processing (a Python Imaging Library fork) _(pip install pillow)_<br>
# __geotiff__ - Reading and writing geotiff files without using GDAL _(pip install geotiff)_<br>
# __GDAL__ - GDAL (Geospatial Data Abstraction Library) support for Python _(pip install gdal)_ [regard this as the universal geospatial multi-tool]<br>
# &emsp;&rarr; <a href="https://pypi.org/project/GDAL/">Module page</a><br>
# &emsp;&rarr; <a href="https://www.osgeo.org/projects/gdal/">Homepage</a><br>
# &emsp;&rarr; <a href="https://gdal.org/en/stable/">GDAL Documentation</a><br>
#
# ### netCDF (also HDF5!)
# __netCDF4__ - Provides an object-oriented python interface to the netCDF version 4 library (on top of HDF5) _(pip install netCDF4)_<br>
# &emsp;&rarr; Search the software repository! Plenty of modules for universal and also very specific tasks (e.g. converters, extractors, ...)

# %% [markdown]
# <span style="font-size:1.25em;">How to read the data</span><br>
# <span style="color:green; font-size:2em;">Proprietary data formats</span>

# %% [markdown]
# <center><span style="color:darkred; font-size:3em; font-weight:bold;">Good luck!</span></center>

# %% [markdown]
# ### MatLab
# MatLab files can often be read by the open source alternatives GNU Octave and Scilab.
#
# * If you have a MatLab licence:<br>
# Use __"MATLAB Engine API for Python"__ to call MatLab.
# * Try with GNU Octave
# __oct2py__ - 'Python to GNU Octave bridge --> run m-files from python.' _(pip install oct2py)_
# * Try with Scilab
# scilab2py - The Python to Scilab bridge is hopelessly outdated.
# * __dedicated Jupyter Python kernels__
#   * __octave-kernel__ - A Jupyter kernel for GNU Octave _(pip install octave-kernel)_
#   * __scilab-kernel__ - A Jupyter kernel for Scilab _(pip install scilab-kernel)_
#   * and others

# %% [markdown]
# ### Other formats
#
# * Search the Python module repository<br>
# * Search the web

# %% [markdown]
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <center><span style="color:green; font-size:3em; font-weight:bold;">What to do with the data in Python?</span></center>

# %% [markdown]
# <center><span style="color:green; font-size:2.5em; font-weight:bold;">Put them in variables</span></center>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>

# %% [markdown]
# <span style="font-size:1.25em;">What to do with the data in Python</span><br>
# <span style="color:green; font-size:2em;">Put them in variables</span>

# %% [markdown]
# <span style="font-size:1.4em;">Read entire data set to a variable</span><br>
# &emsp;<span style="font-size:1.2em;">&rarr; Choose a suitable function or module for the purpose!</span>
# * Open/read ASCII, TIFF, etc. files to variables (e.g. `f = open("somefile.asc")`)
# * Interface a web service and read the response into a variable

# %% [markdown]
# <span style="font-size:1.4em;">Use arrays to structure your data</span><br>

# %% [markdown]
# <span style="font-size:1.2em;">Indexed array: Python "list" - has a numeric index starting with 0</span>

# %%
indexed_array = ["seismology", "GNSS", "Boreholes"]

print(indexed_array[0])
# Out:
# seismology

# %%
print(indexed_array[1])
# Out:
# GNSS

# %%
print(indexed_array[2])
# Out:
# Boreholes

# %%
indexed_array.append("Maps")
print(indexed_array)
# Out:
# ['seismology', 'GNSS', 'Boreholes', 'Maps']

# %%
indexed_array.append(["Volcano", "Observations"])
print(indexed_array)
# Out:
# ['seismology', 'GNSS', 'Boreholes', 'Maps', ['Volcano', 'Observations']]

# %% [markdown]
# <span style="font-size:1.2em;">Associative array: Python "dictionary" - key &rarr; value</span>

# %%
associative_array = {'topic': "geology", 'feature': "borehole", 'country': "Spain"}

# %%
print(associative_array['feature'])
# Out:
# borehole

# %%
associative_array["depth_m"] = 2312
print(associative_array)
# Out:
# {'topic': 'geology', 'feature': 'borehole', 'country': 'Spain', 'depth_m': 2312}

# %%
associative_array['purpose'] = ["basic research", "ore exploration"]
associative_array['driller'] = {'period_1': "driller1", 'period2': "driller2"}
print(associative_array)
# Out:
# {'topic': 'geology', 'feature': 'borehole', 'country': 'Spain', 'depth_m': 2312, 'purpose': ['basic research', 'ore exploration'], 'driller': {'period_1': 'driller1', 'period2': 'driller2'}}

# %% [markdown]
# * multidimensional array - multiple levels of lists and/or dictionaries

# %% [markdown]
# * other usful types exist, like set (unordered list of unique values) - please refer to the documentation

# %% [markdown]
# <span style="font-size:1.4em;">NumPy - Arrays as objects</span><br>

# %% [markdown]
# &emsp;<span style="font-size:1.2em;">&rarr; Class and Object?</span>

# %% [markdown]
# Quick example: image stack as 4D array.

# %%
# import numpy
import numpy as np
# scikit-image scientific image processing, here for demonstration
from skimage import io
# glob unix path handler
import glob

files = glob.glob('data/teststack/*.tiff')

load = []
for file in files:
    load.append(io.imread(file))
stack = np.asarray(load)

# %%
stack.shape
# Out:
# (10, 20, 30, 4)

# %%
dir(stack)
# Out:
# ['T',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_finalize__',
#  '__array_function__',
#  '__array_interface__',
#  '__array_namespace__',
#  '__array_priority__',
#  '__array_struct__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__buffer__',
#  '__class__',
#  '__class_getitem__',
#  '__complex__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__divmod__',
#  '__dlpack__',
#  '__dlpack_device__',
#  '__doc__',
#  '__eq__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__ilshift__',
#  '__imatmul__',
#  '__imod__',
#  '__imul__',
#  '__index__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__irshift__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lshift__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
#  '__new__',
#  '__or__',
#  '__pos__',
#  '__pow__',
#  '__radd__',
#  '__rand__',
#  '__rdivmod__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rfloordiv__',
#  '__rlshift__',
#  '__rmatmul__',
#  '__rmod__',
#  '__rmul__',
#  '__ror__',
#  '__rpow__',
#  '__rrshift__',
#  '__rshift__',
#  '__rsub__',
#  '__rtruediv__',
#  '__rxor__',
#  '__setattr__',
#  '__setitem__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__sub__',
#  '__subclasshook__',
#  '__truediv__',
#  '__xor__',
#  'all',
#  'any',
#  'argmax',
#  'argmin',
#  'argpartition',
#  'argsort',
#  'astype',
#  'base',
#  'byteswap',
#  'choose',
#  'clip',
#  'compress',
#  'conj',
#  'conjugate',
#  'copy',
#  'ctypes',
#  'cumprod',
#  'cumsum',
#  'data',
#  'device',
#  'diagonal',
#  'dot',
#  'dtype',
#  'dump',
#  'dumps',
#  'fill',
#  'flags',
#  'flat',
#  'flatten',
#  'getfield',
#  'imag',
#  'item',
#  'itemset',
#  'itemsize',
#  'mT',
#  'max',
#  'mean',
#  'min',
#  'nbytes',
#  'ndim',
#  'newbyteorder',
#  'nonzero',
#  'partition',
#  'prod',
#  'ptp',
#  'put',
#  'ravel',
#  'real',
#  'repeat',
#  'reshape',
#  'resize',
#  'round',
#  'searchsorted',
#  'setfield',
#  'setflags',
#  'shape',
#  'size',
#  'sort',
#  'squeeze',
#  'std',
#  'strides',
#  'sum',
#  'swapaxes',
#  'take',
#  'to_device',
#  'tobytes',
#  'tofile',
#  'tolist',
#  'tostring',
#  'trace',
#  'transpose',
#  'var',
#  'view']

# %%
stack.view()
# Out:
# array([[[[182, 182, 182, 255],
#          [168, 168, 168, 255],
#          [153, 153, 153, 255],
#          ...,
#          [159, 159, 159, 255],
#          [174, 174, 174, 255],
#          [187, 187, 187, 255]],
#
#         [[172, 172, 172, 255],
#          [156, 156, 156, 255],
#          [141, 141, 141, 255],
#          ...,
#          [147, 147, 147, 255],
#          [164, 164, 164, 255],
#          [179, 179, 179, 255]],
#
#         [[162, 162, 162, 255],
#          [145, 145, 145, 255],
#          [129, 129, 129, 255],
#          ...,
#          [136, 136, 136, 255],
#          [152, 152, 152, 255],
#          [169, 169, 169, 255]],
#
#         ...,
#
#         [[160, 160, 160, 255],
#          [143, 143, 143, 255],
#          [126, 126, 126, 255],
#          ...,
#          [120, 120, 120, 255],
#          [138, 138, 138, 255],
#          [157, 157, 157, 255]],
#
#         [[168, 168, 168, 255],
#          [152, 152, 152, 255],
#          [137, 137, 137, 255],
#          ...,
#          [133, 133, 133, 255],
#          [150, 150, 150, 255],
#          [166, 166, 166, 255]],
#
#         [[179, 179, 179, 255],
#          [164, 164, 164, 255],
#          [149, 149, 149, 255],
#          ...,
#          [144, 144, 144, 255],
#          [160, 160, 160, 255],
#          [175, 175, 175, 255]]],
#
#
#        [[[182, 182, 182, 255],
#          [168, 168, 168, 255],
#          [153, 153, 153, 255],
#          ...,
#          [159, 159, 159, 255],
#          [174, 174, 174, 255],
#          [187, 187, 187, 255]],
#
#         [[172, 172, 172, 255],
#          [156, 156, 156, 255],
#          [141, 141, 141, 255],
#          ...,
#          [147, 147, 147, 255],
#          [164, 164, 164, 255],
#          [179, 179, 179, 255]],
#
#         [[162, 162, 162, 255],
#          [145, 145, 145, 255],
#          [129, 129, 129, 255],
#          ...,
#          [136, 136, 136, 255],
#          [152, 152, 152, 255],
#          [169, 169, 169, 255]],
#
#         ...,
#
#         [[160, 160, 160, 255],
#          [143, 143, 143, 255],
#          [126, 126, 126, 255],
#          ...,
#          [120, 120, 120, 255],
#          [138, 138, 138, 255],
#          [157, 157, 157, 255]],
#
#         [[168, 168, 168, 255],
#          [152, 152, 152, 255],
#          [137, 137, 137, 255],
#          ...,
#          [133, 133, 133, 255],
#          [150, 150, 150, 255],
#          [166, 166, 166, 255]],
#
#         [[179, 179, 179, 255],
#          [164, 164, 164, 255],
#          [149, 149, 149, 255],
#          ...,
#          [144, 144, 144, 255],
#          [160, 160, 160, 255],
#          [175, 175, 175, 255]]],
#
#
#        [[[182, 182, 182, 255],
#          [168, 168, 168, 255],
#          [153, 153, 153, 255],
#          ...,
#          [159, 159, 159, 255],
#          [174, 174, 174, 255],
#          [187, 187, 187, 255]],
#
#         [[172, 172, 172, 255],
#          [156, 156, 156, 255],
#          [141, 141, 141, 255],
#          ...,
#          [147, 147, 147, 255],
#          [164, 164, 164, 255],
#          [179, 179, 179, 255]],
#
#         [[162, 162, 162, 255],
#          [145, 145, 145, 255],
#          [129, 129, 129, 255],
#          ...,
#          [136, 136, 136, 255],
#          [152, 152, 152, 255],
#          [169, 169, 169, 255]],
#
#         ...,
#
#         [[160, 160, 160, 255],
#          [143, 143, 143, 255],
#          [126, 126, 126, 255],
#          ...,
#          [120, 120, 120, 255],
#          [138, 138, 138, 255],
#          [157, 157, 157, 255]],
#
#         [[168, 168, 168, 255],
#          [152, 152, 152, 255],
#          [137, 137, 137, 255],
#          ...,
#          [133, 133, 133, 255],
#          [150, 150, 150, 255],
#          [166, 166, 166, 255]],
#
#         [[179, 179, 179, 255],
#          [164, 164, 164, 255],
#          [149, 149, 149, 255],
#          ...,
#          [144, 144, 144, 255],
#          [160, 160, 160, 255],
#          [175, 175, 175, 255]]],
#
#
#        ...,
#
#
#        [[[182, 182, 182, 255],
#          [168, 168, 168, 255],
#          [153, 153, 153, 255],
#          ...,
#          [159, 159, 159, 255],
#          [174, 174, 174, 255],
#          [187, 187, 187, 255]],
#
#         [[172, 172, 172, 255],
#          [156, 156, 156, 255],
#          [141, 141, 141, 255],
#          ...,
#          [147, 147, 147, 255],
#          [164, 164, 164, 255],
#          [179, 179, 179, 255]],
#
#         [[162, 162, 162, 255],
#          [145, 145, 145, 255],
#          [129, 129, 129, 255],
#          ...,
#          [136, 136, 136, 255],
#          [152, 152, 152, 255],
#          [169, 169, 169, 255]],
#
#         ...,
#
#         [[160, 160, 160, 255],
#          [143, 143, 143, 255],
#          [126, 126, 126, 255],
#          ...,
#          [120, 120, 120, 255],
#          [138, 138, 138, 255],
#          [157, 157, 157, 255]],
#
#         [[168, 168, 168, 255],
#          [152, 152, 152, 255],
#          [137, 137, 137, 255],
#          ...,
#          [133, 133, 133, 255],
#          [150, 150, 150, 255],
#          [166, 166, 166, 255]],
#
#         [[179, 179, 179, 255],
#          [164, 164, 164, 255],
#          [149, 149, 149, 255],
#          ...,
#          [144, 144, 144, 255],
#          [160, 160, 160, 255],
#          [175, 175, 175, 255]]],
#
#
#        [[[182, 182, 182, 255],
#          [168, 168, 168, 255],
#          [153, 153, 153, 255],
#          ...,
#          [159, 159, 159, 255],
#          [174, 174, 174, 255],
#          [187, 187, 187, 255]],
#
#         [[172, 172, 172, 255],
#          [156, 156, 156, 255],
#          [141, 141, 141, 255],
#          ...,
#          [147, 147, 147, 255],
#          [164, 164, 164, 255],
#          [179, 179, 179, 255]],
#
#         [[162, 162, 162, 255],
#          [145, 145, 145, 255],
#          [129, 129, 129, 255],
#          ...,
#          [136, 136, 136, 255],
#          [152, 152, 152, 255],
#          [169, 169, 169, 255]],
#
#         ...,
#
#         [[160, 160, 160, 255],
#          [143, 143, 143, 255],
#          [126, 126, 126, 255],
#          ...,
#          [120, 120, 120, 255],
#          [138, 138, 138, 255],
#          [157, 157, 157, 255]],
#
#         [[168, 168, 168, 255],
#          [152, 152, 152, 255],
#          [137, 137, 137, 255],
#          ...,
#          [133, 133, 133, 255],
#          [150, 150, 150, 255],
#          [166, 166, 166, 255]],
#
#         [[179, 179, 179, 255],
#          [164, 164, 164, 255],
#          [149, 149, 149, 255],
#          ...,
#          [144, 144, 144, 255],
#          [160, 160, 160, 255],
#          [175, 175, 175, 255]]],
#
#
#        [[[182, 182, 182, 255],
#          [168, 168, 168, 255],
#          [153, 153, 153, 255],
#          ...,
#          [159, 159, 159, 255],
#          [174, 174, 174, 255],
#          [187, 187, 187, 255]],
#
#         [[172, 172, 172, 255],
#          [156, 156, 156, 255],
#          [141, 141, 141, 255],
#          ...,
#          [147, 147, 147, 255],
#          [164, 164, 164, 255],
#          [179, 179, 179, 255]],
#
#         [[162, 162, 162, 255],
#          [145, 145, 145, 255],
#          [129, 129, 129, 255],
#          ...,
#          [136, 136, 136, 255],
#          [152, 152, 152, 255],
#          [169, 169, 169, 255]],
#
#         ...,
#
#         [[160, 160, 160, 255],
#          [143, 143, 143, 255],
#          [126, 126, 126, 255],
#          ...,
#          [120, 120, 120, 255],
#          [138, 138, 138, 255],
#          [157, 157, 157, 255]],
#
#         [[168, 168, 168, 255],
#          [152, 152, 152, 255],
#          [137, 137, 137, 255],
#          ...,
#          [133, 133, 133, 255],
#          [150, 150, 150, 255],
#          [166, 166, 166, 255]],
#
#         [[179, 179, 179, 255],
#          [164, 164, 164, 255],
#          [149, 149, 149, 255],
#          ...,
#          [144, 144, 144, 255],
#          [160, 160, 160, 255],
#          [175, 175, 175, 255]]]], shape=(10, 20, 30, 4), dtype=uint8)

# %% [markdown]
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <center><span style="color:green; font-size:3em; font-weight:bold;">What to do with the data in Python?</span></center>

# %% [markdown]
# <center><span style="color:green; font-size:2.5em; font-weight:bold;">Process and visualise</span></center>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>

# %% [markdown]
# <span style="font-size:1.25em;">What to do with the data in Python</span><br>
# <span style="color:green; font-size:2em;">Process and visualise</span>

# %% [markdown]
# <span style="font-size:1.4em;">Array manipulation and array computation</span><br>
# * Use basic Python functions to sort, append and otherwise manipulate lists and dictionaries (please refer to the documentation)
# * __NumPy__ - Scientific computing for Python _(pip install numpy)_<br>Use the NumPy array class instead of lists and dictionaries. NumPy provides comprehensive functionality for array computing.<br>
# &emsp;&rarr; <a href="https://pypi.org/project/numpy/">Module page</a><br>
# &emsp;&rarr; <a href="https://numpy.org/">Homepage</a><br>
# &emsp;&rarr; <a href="https://numpy.org/doc/stable/">Documentation</a><br>
# &emsp;&rarr; <a href="https://mail.python.org/mailman3/lists/numpy-discussion.python.org/">Mailing list</a>

# %% [markdown]
# <span style="font-size:1.25em;">What to do with the data in Python</span><br>
# <span style="color:green; font-size:2em;">Process and visualise</span>

# %% [markdown]
# <span style="font-size:1.4em;">Calculation and computation</span><br>
# * __math__ - Mathematical functions as defined in the C standard.
# * __NumPy__ - Scientific computing for Python _(pip install numpy)_
# * __Pandas__ - Python Data Analysis Library _(pip install pandas)_<br>
# "Pandas is a Python package that provides fast, flexible, and expressive data structures ... high-level building block for doing practical, real world data analysis in Python." Pandas uses a specific data class (DataFrame) to manipulte data efficiently.<br>
# &emsp;&rarr; <a href="https://pypi.org/project/pandas/">Module page</a><br>
# &emsp;&rarr; <a href="https://pandas.pydata.org/">Homepage</a><br>
# &emsp;&rarr; <a href="https://pandas.pydata.org/docs/">Documentation</a><br>
# &emsp;&rarr; <a href="https://https://stackoverflow.com/questions/tagged/pandas">Forum</a>
# * See __"Python for Data Analysis, Open Edition"__ by Wes McKinney<br>
# &emsp;&rarr; <a href="https://wesmckinney.com/book/">3rd edition</a><br>
# * The thematic packages discussed before may implement processing functionality!

# %% [markdown]
# <span style="font-size:1.25em;">What to do with the data in Python</span><br>
# <span style="color:green; font-size:2em;">Process and visualise</span>

# %% [markdown]
# <span style="font-size:1.4em;">Visualisation</span><br>
# * __MatPlotLib__ - Static, animated, and interactive visualizations in Python _(pip install matplotlib)_<br>
# "Matplotlib produces publication-quality figures in a variety of hardcopy formats and interactive environments across platforms."<br>
# &emsp;&rarr; <a href="https://pypi.org/project/matplotlib/">Module page</a><br>
# &emsp;&rarr; <a href="https://matplotlib.org/">Homepage</a><br>
# &emsp;&rarr; <a href="https://matplotlib.org/stable/users/index">Documentation</a><br>
# &emsp;&rarr; <a href="https://discourse.matplotlib.org/">Forum</a>
# * __plotly__ - Interactive data visualisation for Python _(pip install plotly)_<br>
# Builds on JavaScript plotly.js.<br>
# &emsp;&rarr; <a href="https://pypi.org/project/plotly/">Module page</a><br>
# &emsp;&rarr; <a href="https://plotly.com/python/">Documentation</a><br>
# &emsp;&rarr; <a href="https://community.plotly.com/c/plotly-python">Forum</a>

# %% [markdown]
# <span style="font-size:1.25em;">What to do with the data in Python</span><br>
# <span style="color:green; font-size:2em;">Process and visualise</span>

# %% [markdown]
# <span style="font-size:1.4em;">Geospatial data</span><br>
# * __GeoPandas__ - Provides a high-level interface for geospatial data _(pip install geopandas)_<br>
# "GeoPandas is an open source project to make working with geospatial data in python easier. GeoPandas extends the datatypes used by pandas to allow spatial operations on geometric types."<br>
# &emsp;&rarr; <a href="https://pypi.org/project/geopandas/">Module page</a><br>
# &emsp;&rarr; <a href="https://geopandas.org/en/stable/">Homepage</a><br>
# &emsp;&rarr; <a href="https://geopandas.org/en/stable/docs.html">Documentation</a>
# * __folium__ - Webmapping with Python _(pip install folium)_<br>
# Builds on JavaScript Leaflet.js.<br>
# &emsp;&rarr; <a href="https://pypi.org/project/folium/">Module page</a><br>
# &emsp;&rarr; <a href="https://python-visualization.github.io/folium/latest/">Homepage</a><br>
# &emsp;&rarr; <a href="https://github.com/python-visualization/folium">GitHub</a><br>

# %% [markdown]
# <span style="font-size:1.25em;">What to do with the data in Python</span><br>
# <span style="color:green; font-size:2em;">Process and visualise</span>

# %% [markdown]
# <span style="font-size:1.4em;">Modelling</span><br>
# * __SimPEG__ - An open source python package for simulation and gradient based parameter estimation in geophysical applications. _(pip install simpeg)_<br>Geophysical methods, forward simulations, inversion.<br>
# &emsp;&rarr; <a href="https://pypi.org/project/simpeg/">Module page</a><br>
# &emsp;&rarr; <a href="https://simpeg.xyz/">Homepage</a><br>
# &emsp;&rarr; <a href="https://docs.simpeg.xyz/latest/">Documentation</a><br>
# &emsp;&rarr; <a href="https://github.com/simpeg/simpeg">GitHub</a><br>
# &emsp;&rarr; <a href="https://simpeg.discourse.group/">Forum</a><br>
# * __fatiando a terra__ - Open-source library for modeling and inversion in geophysics _(pip install fatiando)_<br>
# Data processing, modelling, and inversion across the Geosciences.<br>
# &emsp;&rarr; <a href="https://pypi.org/project/fatiando/">Module page</a><br>
# &emsp;&rarr; <a href="https://www.fatiando.org">Homepage</a><br>
# &emsp;&rarr; <a href="https://www.fatiando.org/learn/">Documentation</a><br>
# &emsp;&rarr; <a href="https://github.com/fatiando">GitHub</a><br>
# &emsp;&rarr; <a href="https://github.com/orgs/fatiando/discussions">Forum</a><br>

# %% [markdown]
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <center><span style="color:green; font-size:3em; font-weight:bold;">Interacting with services and data</span></center><br>

# %% [markdown]
# <center><span style="color:green; font-size:2.5em; font-weight:bold;">The basics</span></center>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>

# %% [markdown]
# <span style="font-size:1.25em;">Interacting with services and data</span><br>
# <span style="color:green; font-size:2em;">The basics</span>

# %% [markdown]
# <span style="font-size:1.4em;">Directly accessing content over HTTP and read the data</span><br>
# This could be a discrete file discovered through EPOS or any service response (whatever the HTTP request delivers, 1:1)

# %% [markdown]
# __requests__

# %%
# import the requests module
import requests

# load the file via HTTP to a variable and print it - here a specific geomagnetic field modelling result
target = "https://geomag.bgs.ac.uk/web_service/GMModels/igrf/13?latitude=0&longitude=0&altitude=0&date=2020-01-01&format=txt"
data = requests.get(target)

print(data.text) # this is content in a Python object
# --> work with the data in the Python object, use a suitable module for the data type
# Out:
# Geomagnetic field model result:
#     Model: igrf
#     Revision: 13
#     Date: 2020-01-01
#     Coordinates:
#         Latitude (deg north): 0
#         Longitude (deg east): 0
#         Altitude: 0.00 km
#     Field Value:
#         Total Intensity (nT):      31936
#         Declination (deg east):    -4.654
#         Inclination (deg down):    -30.093
#         North Intensity (nT):      27540
#         East Intensity (nT):       -2242
#         Vertical Intensity (nT):   -16012
#         Horizontal Intensity (nT): 27631
#     Secular Variation:
#         Total Intensity (nT/y):      -0.6
#         Declination (arcmin/y east): 10.1
#         Inclination (arcmin/y down): -3.0
#         North Intensity (nT/y):      -7.9
#         East Intensity (nT/y):       81.8
#         Vertical Intensity (nT/y):   -23.7
#         Horizontal Intensity (nT/y): -14.5

# %% [markdown]
# __urllib__

# %%
# import the urllib module
import urllib

# load the file via HTTP to a variable and print it - here a specific geomagnetic field modelling result
target = "https://geomag.bgs.ac.uk/web_service/GMModels/igrf/13?latitude=0&longitude=0&altitude=0&date=2020-01-01&format=txt"
with urllib.request.urlopen(target) as response:
    data = response.read()

print(data) # this is content of the variable
# --> work with the data in the variable, use a suitable module for the data type
# Out:
# b'Geomagnetic field model result:\n    Model: igrf\n    Revision: 13\n    Date: 2020-01-01\n    Coordinates:\n        Latitude (deg north): 0\n        Longitude (deg east): 0\n        Altitude: 0.00 km\n    Field Value:\n        Total Intensity (nT):      31936\n        Declination (deg east):    -4.654\n        Inclination (deg down):    -30.093\n        North Intensity (nT):      27540\n        East Intensity (nT):       -2242\n        Vertical Intensity (nT):   -16012\n        Horizontal Intensity (nT): 27631\n    Secular Variation:\n        Total Intensity (nT/y):      -0.6\n        Declination (arcmin/y east): 10.1\n        Inclination (arcmin/y down): -3.0\n        North Intensity (nT/y):      -7.9\n        East Intensity (nT/y):       81.8\n        Vertical Intensity (nT/y):   -23.7\n        Horizontal Intensity (nT/y): -14.5\n'

# %% [markdown]
# <span style="font-size:1.25em;">Interacting with services and data</span><br>
# <span style="color:green; font-size:2em;">The basics</span>

# %% [markdown]
# <span style="font-size:1.4em;">Directly accessing content over HTTP and read the data</span><br>
# What about compressed data, e.g zip-archives?

# %%
# import the zipfile and os modules
import zipfile
import os

# load the file via HTTP to a data directory - here a specific geomagnetic field modelling result
target = "https://download.pangaea.de/dataset/922705/files/Glacially-Induced_Faults.zip" # a data set on the PANGAEA data repository
urllib.request.urlretrieve(target, './data/Glacially-Induced_Faults.zip')

print(os.listdir('./data/'))
# Out:
# ['Glacially-Induced_Faults.zip', 'teststack', '.ipynb_checkpoints']

# %%
# unzip the file to disk
with zipfile.ZipFile('./data/Glacially-Induced_Faults.zip', 'r') as unzip:
    unzip.extractall(path='./data')

print(os.listdir('./data/'))

# --> access the content with a suitable module, e.g. geopandas
# or just read a file and print the content
with open('./data/GIF.prj', 'r') as content:
    print(content.read())
# Out:
# ['GIF.sbn', 'GIF.shp', '__MACOSX', 'Glacially-Induced_Faults.zip', 'GIF.shp.xml', 'teststack', 'GIF.prj', 'GIF.cpg', 'GIF.dbf', '.ipynb_checkpoints', 'GIF.shx', 'GIF.sbx']
# PROJCS["WGS_1984_World_Mercator",GEOGCS["GCS_WGS_1984",DATUM["D_WGS_1984",SPHEROID["WGS_1984",6378137.0,298.257223563]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Mercator"],PARAMETER["False_Easting",0.0],PARAMETER["False_Northing",0.0],PARAMETER["Central_Meridian",0.0],PARAMETER["Standard_Parallel_1",0.0],UNIT["Meter",1.0]]

# %%
# alternatively, do it without saving to files
import io

# load the zipped file as object and print the content
response = urllib.request.urlopen(target)
zipped = zipfile.ZipFile(io.BytesIO(response.read()))
zipped.namelist()

# access content (files) in the zip-object
with zipped.open('GIF.prj') as prj:
    print(prj.read())
# --> access the content with a suitable module, e.g. geopandas
# Out:
# b'PROJCS["WGS_1984_World_Mercator",GEOGCS["GCS_WGS_1984",DATUM["D_WGS_1984",SPHEROID["WGS_1984",6378137.0,298.257223563]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]],PROJECTION["Mercator"],PARAMETER["False_Easting",0.0],PARAMETER["False_Northing",0.0],PARAMETER["Central_Meridian",0.0],PARAMETER["Standard_Parallel_1",0.0],UNIT["Meter",1.0]]'

# %% [markdown]
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <center><span style="color:green; font-size:3em; font-weight:bold;">Interacting with services and data</span></center><br>

# %% [markdown]
# <span style="font-size:1.4em;">Demonstration case: Multidisciplinary data discovery and integration</span><br>
# In this demonstration case, we discover deep boreholes by using Open Geospatial Consortium (OGC) Web Services (OWS). Based on the borehole locations, we search for GNSS and seismological stations, utilising the GLASS framework and the EIDA API/ObsPy, respectively. After arranging the discovery data in a Python dictionary, we access the data and plot both discovery data and data on a map. Finally, we complement the plot with data from a local source.
#
# * Let's find all scientific boreholes that are deeper than 2000 m.
# * We want to know in what geological units the boreholes are located.
# * Find all GNSS stations that are up to 100 km from the boreholes.
# * Retrieve GNSS data, station velocity and time series.
# * Find seismic stations that are up to 150 km from the boreholes.
# * Retrieve seismic data
# * Visualise the data
#   * Plot boreholes, GNSS stations and seismic stations
#   * Plot GNSS and seismic data as pop-ups
#   * Plot local data

# %% [markdown]
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <center><span style="color:green; font-size:3em; font-weight:bold;">Interacting with services and data</span></center><br>

# %% [markdown]
# <center><span style="color:green; font-size:2.5em; font-weight:bold;">Open Geospatial Consortium (OGC) Web Services (OWS)</span></center>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>

# %% [markdown]
# <span style="font-size:1.25em;">Interacting with services and data</span><br>
# <span style="color:green; font-size:2em;">Open Geospatial Consortium (OGC) Web Services (OWS)</span>

# %% [markdown]
# <span style="font-size:1.4em;">Let's find all scientific boreholes that are deeper than 2000 m.</span>

# %% [markdown]
# &emsp;<span style="font-size:1.2em;">&rarr; How to interact with __Open Geospatial Consortium Web Services (OWS)__</span>
#
# _BoreholeIndex dataset:_
# * BoreholeView: Web Map Service (WMS) for viewing
# * BoreholeDownload: Web Feature Service (WFS) for data access<br>
#
# &emsp;<span style="font-size:1.2em;">&rarr; What we need is a WFS request that we filter according to our requirements</span>

# %%
# use OWSLib, import the required submodule
from owslib.wfs import WebFeatureService as WFS

# Explore the BoreholeIndex WFS service ("Borehole Download") by listing the FeatureTypes/layers
service_url = 'https://data.geoscience.earth/api/wxsBorehole?'
wfs = WFS(service_url, version='2.0.0')
list(wfs.contents)
# Out:
# ['epos-gsmlp:BoreholeView',
#  'epos-gsmlp:BoreholeView_Cluster',
#  'epos-gsmlp:BoreholeView_PointStacker']

# %%
# Explore the FeatureType/layer and list the available properties by examining the schema
target_layer = 'epos-gsmlp:BoreholeView_PointStacker' # select the layer

schema = wfs.get_schema(target_layer)
print(schema)
# Out:
# {'properties': {'boreholeid': 'string', 'gmlidentifier': 'string', 'gsmlpidentifier': 'string', 'purpose_href': 'string', 'purpose': 'string', 'boreholeuse': 'string', 'boreholeuse_href': 'string', 'status_href': 'string', 'status': 'string', 'drillingmethod_href': 'string', 'drillingmethod': 'string', 'operator': 'string', 'driller': 'string', 'drillstartdate': 'date', 'drillenddate': 'date', 'startpoint_href': 'string', 'startpoint': 'string', 'inclinationtype_href': 'string', 'inclinationtype': 'string', 'boreholematerialcustodian': 'string', 'boreholelength_m': 'float', 'elevation_m': 'float', 'elevation_srs': 'string', 'source': 'string', 'parentborehole_uri': 'string', 'metadata_uri': 'string', 'genericsymbolizer': 'string', 'cored': 'boolean', 'accesstophysicaldrillcore': 'boolean', 'detaileddescription': 'string', 'detaileddescription_href': 'string', 'geophysicallogs': 'string', 'geophysicallogs_href': 'string', 'geologicaldescription': 'string', 'geologicaldescription_href': 'string', 'groundwaterlevel': 'string', 'groundwaterlevel_href': 'string', 'groundwaterchemistry': 'string', 'groundwaterchemistry_href': 'string', 'rockgeochemistry': 'string', 'rockgeochemistry_href': 'string', 'poregaschemistry': 'string', 'poregaschemistry_href': 'string', 'geotechnicalinfo': 'string', 'geotechnicalinfo_href': 'string', 'positionalaccuracy': 'string', 'lastupdated': 'dateTime', 'provider': 'int'}, 'required': ['boreholeid'], 'geometry': 'GeometryCollection', 'geometry_column': 'location_wgs84'}

# %%
# Set up pretty printing and try again
import pprint
# define abbreviation and formatting
pp = pprint.PrettyPrinter(indent=4)

pp.pprint(schema)
# Out:
# {   'geometry': 'GeometryCollection',
#     'geometry_column': 'location_wgs84',
#     'properties': {   'accesstophysicaldrillcore': 'boolean',
#                       'boreholeid': 'string',
#                       'boreholelength_m': 'float',
#                       'boreholematerialcustodian': 'string',
#                       'boreholeuse': 'string',
#                       'boreholeuse_href': 'string',
#                       'cored': 'boolean',
#                       'detaileddescription': 'string',
#                       'detaileddescription_href': 'string',
#                       'drillenddate': 'date',
#                       'driller': 'string',
#                       'drillingmethod': 'string',
#                       'drillingmethod_href': 'string',
#                       'drillstartdate': 'date',
#                       'elevation_m': 'float',
#                       'elevation_srs': 'string',
#                       'genericsymbolizer': 'string',
#                       'geologicaldescription': 'string',
#                       'geologicaldescription_href': 'string',
#                       'geophysicallogs': 'string',
#                       'geophysicallogs_href': 'string',
#                       'geotechnicalinfo': 'string',
#                       'geotechnicalinfo_href': 'string',
#                       'gmlidentifier': 'string',
#                       'groundwaterchemistry': 'string',
#                       'groundwaterchemistry_href': 'string',
#                       'groundwaterlevel': 'string',
#                       'groundwaterlevel_href': 'string',
#                       'gsmlpidentifier': 'string',
#                       'inclinationtype': 'string',
#                       'inclinationtype_href': 'string',
#                       'lastupdated': 'dateTime',
#                       'metadata_uri': 'string',
#                       'operator': 'string',
#                       'parentborehole_uri': 'string',
#                       'poregaschemistry': 'string',
#                       'poregaschemistry_href': 'string',
#                       'positionalaccuracy': 'string',
#                       'provider': 'int',
#                       'purpose': 'string',
#                       'purpose_href': 'string',
#                       'rockgeochemistry': 'string',
#                       'rockgeochemistry_href': 'string',
#                       'source': 'string',
#                       'startpoint': 'string',
#                       'startpoint_href': 'string',
#                       'status': 'string',
#                       'status_href': 'string'},
#     'required': ['boreholeid']}

# %%
# or shorter, by using the pprintpp module
from pprintpp import pprint as pp
pp(schema)
# Out:
# {
#     'geometry': 'GeometryCollection',
#     'geometry_column': 'location_wgs84',
#     'properties': {
#         'accesstophysicaldrillcore': 'boolean',
#         'boreholeid': 'string',
#         'boreholelength_m': 'float',
#         'boreholematerialcustodian': 'string',
#         'boreholeuse': 'string',
#         'boreholeuse_href': 'string',
#         'cored': 'boolean',
#         'detaileddescription': 'string',
#         'detaileddescription_href': 'string',
#         'drillenddate': 'date',
#         'driller': 'string',
#         'drillingmethod': 'string',
#         'drillingmethod_href': 'string',
#         'drillstartdate': 'date',
#         'elevation_m': 'float',
#         'elevation_srs': 'string',
#         'genericsymbolizer': 'string',
#         'geologicaldescription': 'string',
#         'geologicaldescription_href': 'string',
#         'geophysicallogs': 'string',
#         'geophysicallogs_href': 'string',
#         'geotechnicalinfo': 'string',
#         'geotechnicalinfo_href': 'string',
#         'gmlidentifier': 'string',
#         'groundwaterchemistry': 'string',
#         'groundwaterchemistry_href': 'string',
#         'groundwaterlevel': 'string',
#         'groundwaterlevel_href': 'string',
#         'gsmlpidentifier': 'string',
#         'inclinationtype': 'string',
#         'inclinationtype_href': 'string',
#         'lastupdated': 'dateTime',
#         'metadata_uri': 'string',
#         'operator': 'string',
#         'parentborehole_uri': 'string',
#         'poregaschemistry': 'string',
#         'poregaschemistry_href': 'string',
#         'positionalaccuracy': 'string',
#         'provider': 'int',
#         'purpose': 'string',
#         'purpose_href': 'string',
#         'rockgeochemistry': 'string',
#         'rockgeochemistry_href': 'string',
#         'source': 'string',
#         'startpoint': 'string',
#         'startpoint_href': 'string',
#         'status': 'string',
#         'status_href': 'string',
#     },
#     'required': ['boreholeid'],
# }

# %% [markdown]
# <span style="font-size:1.2em;">_OWSLib_ only supports filtering for WFS 1.1. We use WFS 2.0 and build our query with _requests_

# %%
# define the method to interact with the service
API_method = 'GetFeature'
# set the format
format_option = 'gml32'
  # format_option = 'json'

# filter parameters
BBOX = 'BBOX(location_wgs84,53.37,-1.50,53.42,-1.42)'
depth = 'boreholelength_m>\'2000\''
purpose = 'purpose=\'multidisciplinary scientific research\''

# compose CQL filters (combine filter parameters for the query
filter = depth + ' AND ' + purpose
#filter = BBOX + ' AND ' + depth

# Configuration of the query
payload = {
    'service' : 'WFS',
    'request' : API_method,
    'srsName' : 'EPSG:4326',
    'version' : '2.0.0',
    'typenames' : [target_layer],
    'outputFormat' : format_option,
    'CQL_FILTER' : filter
}

response = requests.get(service_url, params=payload)

# print the request URL for information
print(urllib.parse.unquote(response.url))
# Out:
# https://data.geoscience.earth/api/wxsBorehole?service=WFS&request=GetFeature&srsName=EPSG:4326&version=2.0.0&typenames=epos-gsmlp:BoreholeView_PointStacker&outputFormat=gml32&CQL_FILTER=boreholelength_m>'2000'+AND+purpose='multidisciplinary+scientific+research'

# %% [markdown]
# Sometimes, the server does not return all features due to limits set in the server configuration (maximum features per request).<br>
# We check that all features discovered are returned.

# %%
# import element tree from libxml
from lxml import etree

xml = etree.fromstring(response.content)
if xml.attrib['numberMatched'] != xml.attrib['numberReturned']:
    print('Not all available features were returned by the server (',xml.attrib['numberReturned'],'of',xml.attrib['numberMatched'],').')
else:
    print('All available features (',xml.attrib['numberReturned'],') were returned by the server.')
# Out:
# All available features ( 13 ) were returned by the server.

# %%
# import element tree from xml
import xml.etree.ElementTree as ET
# xml minidom is needed as parser
import xml.dom.minidom as dom

xml = ET.fromstring(response.content)
if xml.attrib['numberMatched'] != xml.attrib['numberReturned']:
    print('Not all available features were returned by the server (',xml.attrib['numberReturned'],'of',xml.attrib['numberMatched'],').')
else:
    print('All available features (',xml.attrib['numberReturned'],') were returned by the server.')
# Out:
# All available features ( 13 ) were returned by the server.

# %% [markdown]
# List all attributes in the returned data

# %%
elemList = []

for elem in xml.iter():
    elemList.append(elem.tag)
    
elemSet = set(elemList) # set: a list with unique values

pp(elemSet)
# Out:
# set([
#     '{http://www.opengis.net/gml/3.2}Point',
#     '{http://www.opengis.net/gml/3.2}description',
#     '{http://www.opengis.net/gml/3.2}name',
#     '{http://www.opengis.net/gml/3.2}pos',
#     '{http://www.opengis.net/wfs/2.0}FeatureCollection',
#     '{http://www.opengis.net/wfs/2.0}member',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}BoreholeView_PointStacker',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}accesstophysicaldrillcore',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}boreholeid',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}boreholelength_m',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}boreholematerialcustodian',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}boreholeuse',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}boreholeuse_href',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}cored',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}detaileddescription',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}detaileddescription_href',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}drillenddate',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}driller',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}drillingmethod',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}drillingmethod_href',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}drillstartdate',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}elevation_m',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}elevation_srs',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}geologicaldescription',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}geologicaldescription_href',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}geophysicallogs',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}geophysicallogs_href',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}geotechnicalinfo',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}geotechnicalinfo_href',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}gmlidentifier',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}groundwaterchemistry',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}groundwaterchemistry_href',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}groundwaterlevel',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}groundwaterlevel_href',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}gsmlpidentifier',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}inclinationtype',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}inclinationtype_href',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}lastupdated',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}location_wgs84',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}metadata_uri',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}operator',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}poregaschemistry',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}poregaschemistry_href',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}positionalaccuracy',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}provider',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}purpose',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}purpose_href',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}rockgeochemistry',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}rockgeochemistry_href',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}source',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}startpoint',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}startpoint_href',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}status',
#     '{https://data.geoscience.earth/def/epos-geosciml-lite}status_href',
# ])

# %% [markdown]
# Print the returned data

# %%
print(dom.parseString(response.content).toprettyxml(indent="  ", newl='')) # or response.text
# Out:
# <?xml version="1.0" ?><wfs:FeatureCollection xmlns:xs="http://www.w3.org/2001/XMLSchema" xmlns:epos-gsmlp="https://data.geoscience.earth/def/epos-geosciml-lite" xmlns:wfs="http://www.opengis.net/wfs/2.0" xmlns:gml="http://www.opengis.net/gml/3.2" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" numberMatched="13" numberReturned="13" timeStamp="2025-06-16T10:43:22.030Z" xsi:schemaLocation="http://www.opengis.net/wfs/2.0 http://schemas.opengis.net/wfs/2.0/wfs.xsd https://data.geoscience.earth/def/epos-geosciml-lite https://data.geoscience.earth/api/wxsBorehole/epos-gsmlp/wfs?service=WFS&amp;version=2.0.0&amp;request=DescribeFeatureType&amp;typeName=epos-gsmlp%3ABoreholeView_PointStacker http://www.opengis.net/gml/3.2 http://schemas.opengis.net/gml/3.2.1/gml.xsd">
#   <wfs:member>
#     <epos-gsmlp:BoreholeView_PointStacker gml:id="BoreholeView_PointStacker.fid-2c3a8deb_197747fc4f7_50ba">
#       <gml:name>Chesapeake, CBIS Eyreville-1 Corehole 63G69 (A)</gml:name>
#       <epos-gsmlp:boreholeid>SD-5001_1_A</epos-gsmlp:boreholeid>
#       <epos-gsmlp:gmlidentifier>https://www.geodata.rocks/BoreholeView/SD-5001_1_A</epos-gsmlp:gmlidentifier>
#       <epos-gsmlp:gsmlpidentifier>https://www.geodata.rocks/Boreholes/SD-5001_1_A</epos-gsmlp:gsmlpidentifier>
#       <epos-gsmlp:purpose_href>https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch</epos-gsmlp:purpose_href>
#       <epos-gsmlp:purpose>multidisciplinary scientific research</epos-gsmlp:purpose>
#       <epos-gsmlp:boreholeuse>multidisciplinary scientific research</epos-gsmlp:boreholeuse>
#       <epos-gsmlp:boreholeuse_href>https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch</epos-gsmlp:boreholeuse_href>
#       <epos-gsmlp:status_href>https://data.geoscience.earth/ncl/BoreholeStatus/abandoned</epos-gsmlp:status_href>
#       <epos-gsmlp:status>abandoned</epos-gsmlp:status>
#       <epos-gsmlp:drillingmethod_href>https://data.geoscience.earth/ncl/DrillingMethod/coreDrilling</epos-gsmlp:drillingmethod_href>
#       <epos-gsmlp:drillingmethod>core drilling</epos-gsmlp:drillingmethod>
#       <epos-gsmlp:operator>DOSECC</epos-gsmlp:operator>
#       <epos-gsmlp:driller>DOSECC</epos-gsmlp:driller>
#       <epos-gsmlp:drillstartdate>2005-09-14Z</epos-gsmlp:drillstartdate>
#       <epos-gsmlp:drillenddate>2005-10-10Z</epos-gsmlp:drillenddate>
#       <epos-gsmlp:startpoint_href>https://data.geoscience.earth/ncl/StartPoint/seaFloor</epos-gsmlp:startpoint_href>
#       <epos-gsmlp:startpoint>sea floor</epos-gsmlp:startpoint>
#       <epos-gsmlp:inclinationtype_href>https://data.geoscience.earth/ncl/BoreholeInclinationType/vertical</epos-gsmlp:inclinationtype_href>
#       <epos-gsmlp:inclinationtype>vertical</epos-gsmlp:inclinationtype>
#       <epos-gsmlp:boreholelength_m>2142.7</epos-gsmlp:boreholelength_m>
#       <epos-gsmlp:elevation_m>3.0</epos-gsmlp:elevation_m>
#       <epos-gsmlp:elevation_srs>5613</epos-gsmlp:elevation_srs>
#       <epos-gsmlp:source>International Continental Scientific Drilling Program (ICDP), direct communication</epos-gsmlp:source>
#       <epos-gsmlp:metadata_uri>https://epos.brgm-rec.fr/geonetwork/srv/eng/catalog.search#/metadata/e435e013-944d-45e3-b2b7-a009889300d2</epos-gsmlp:metadata_uri>
#       <epos-gsmlp:cored>true</epos-gsmlp:cored>
#       <epos-gsmlp:accesstophysicaldrillcore>true</epos-gsmlp:accesstophysicaldrillcore>
#       <epos-gsmlp:detaileddescription>Borehole SD-5001_1_A</epos-gsmlp:detaileddescription>
#       <epos-gsmlp:detaileddescription_href>https://www.geodata.rocks/Boreholes/SD-5001_1_A</epos-gsmlp:detaileddescription_href>
#       <epos-gsmlp:geophysicallogs>unkown</epos-gsmlp:geophysicallogs>
#       <epos-gsmlp:geophysicallogs_href>http://www.opengis.net/def/nil/OGC/0/unkown</epos-gsmlp:geophysicallogs_href>
#       <epos-gsmlp:geologicaldescription>unkown</epos-gsmlp:geologicaldescription>
#       <epos-gsmlp:geologicaldescription_href>http://www.opengis.net/def/nil/OGC/0/unkown</epos-gsmlp:geologicaldescription_href>
#       <epos-gsmlp:groundwaterlevel>inapplicable</epos-gsmlp:groundwaterlevel>
#       <epos-gsmlp:groundwaterlevel_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:groundwaterlevel_href>
#       <epos-gsmlp:groundwaterchemistry>inapplicable</epos-gsmlp:groundwaterchemistry>
#       <epos-gsmlp:groundwaterchemistry_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:groundwaterchemistry_href>
#       <epos-gsmlp:rockgeochemistry>unknown</epos-gsmlp:rockgeochemistry>
#       <epos-gsmlp:rockgeochemistry_href>http://www.opengis.net/def/nil/OGC/0/unknown</epos-gsmlp:rockgeochemistry_href>
#       <epos-gsmlp:poregaschemistry>unknown</epos-gsmlp:poregaschemistry>
#       <epos-gsmlp:poregaschemistry_href>http://www.opengis.net/def/nil/OGC/0/unknown</epos-gsmlp:poregaschemistry_href>
#       <epos-gsmlp:geotechnicalinfo>inapplicable</epos-gsmlp:geotechnicalinfo>
#       <epos-gsmlp:geotechnicalinfo_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:geotechnicalinfo_href>
#       <epos-gsmlp:location_wgs84>
#         <gml:Point srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" srsDimension="2" gml:id="BoreholeView_PointStacker.fid-2c3a8deb_197747fc4f7_50ba.location_wgs84">
#           <gml:pos>-75.9757 37.3217</gml:pos>
#         </gml:Point>
#       </epos-gsmlp:location_wgs84>
#       <epos-gsmlp:lastupdated>2025-01-23T23:00:00Z</epos-gsmlp:lastupdated>
#       <epos-gsmlp:provider>6</epos-gsmlp:provider>
#     </epos-gsmlp:BoreholeView_PointStacker>
#   </wfs:member>
#   <wfs:member>
#     <epos-gsmlp:BoreholeView_PointStacker gml:id="BoreholeView_PointStacker.fid-2c3a8deb_197747fc4f7_50bb">
#       <gml:name>Donghai, CCSD-PH</gml:name>
#       <epos-gsmlp:boreholeid>SD-5004_4_A</epos-gsmlp:boreholeid>
#       <epos-gsmlp:gmlidentifier>https://www.geodata.rocks/BoreholeView/SD-5004_4_A</epos-gsmlp:gmlidentifier>
#       <epos-gsmlp:gsmlpidentifier>https://www.geodata.rocks/Boreholes/SD-5004_4_A</epos-gsmlp:gsmlpidentifier>
#       <epos-gsmlp:purpose_href>https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch</epos-gsmlp:purpose_href>
#       <epos-gsmlp:purpose>multidisciplinary scientific research</epos-gsmlp:purpose>
#       <epos-gsmlp:boreholeuse>multidisciplinary scientific research</epos-gsmlp:boreholeuse>
#       <epos-gsmlp:boreholeuse_href>https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch</epos-gsmlp:boreholeuse_href>
#       <epos-gsmlp:status_href>https://data.geoscience.earth/ncl/BoreholeStatus/drillingCompleted</epos-gsmlp:status_href>
#       <epos-gsmlp:status>drilling completed</epos-gsmlp:status>
#       <epos-gsmlp:drillingmethod_href>https://data.geoscience.earth/ncl/DrillingMethod/coreDrilling</epos-gsmlp:drillingmethod_href>
#       <epos-gsmlp:drillingmethod>core drilling</epos-gsmlp:drillingmethod>
#       <epos-gsmlp:operator>China Geological Survey</epos-gsmlp:operator>
#       <epos-gsmlp:startpoint_href>https://data.geoscience.earth/ncl/StartPoint/naturalLandSurface</epos-gsmlp:startpoint_href>
#       <epos-gsmlp:startpoint>natural land surface</epos-gsmlp:startpoint>
#       <epos-gsmlp:inclinationtype_href>https://data.geoscience.earth/ncl/BoreholeInclinationType/vertical</epos-gsmlp:inclinationtype_href>
#       <epos-gsmlp:inclinationtype>vertical</epos-gsmlp:inclinationtype>
#       <epos-gsmlp:boreholelength_m>2039.54</epos-gsmlp:boreholelength_m>
#       <epos-gsmlp:elevation_m>28.5</epos-gsmlp:elevation_m>
#       <epos-gsmlp:elevation_srs>5613</epos-gsmlp:elevation_srs>
#       <epos-gsmlp:source>International Continental Scientific Drilling Program (ICDP), direct communication</epos-gsmlp:source>
#       <epos-gsmlp:metadata_uri>https://epos.brgm-rec.fr/geonetwork/srv/eng/catalog.search#/metadata/e435e013-944d-45e3-b2b7-a009889300d2</epos-gsmlp:metadata_uri>
#       <epos-gsmlp:cored>true</epos-gsmlp:cored>
#       <epos-gsmlp:accesstophysicaldrillcore>false</epos-gsmlp:accesstophysicaldrillcore>
#       <epos-gsmlp:detaileddescription>Borehole SD-5004_4_A</epos-gsmlp:detaileddescription>
#       <epos-gsmlp:detaileddescription_href>https://www.geodata.rocks/Boreholes/SD-5004_4_A</epos-gsmlp:detaileddescription_href>
#       <epos-gsmlp:geophysicallogs>unkown</epos-gsmlp:geophysicallogs>
#       <epos-gsmlp:geophysicallogs_href>http://www.opengis.net/def/nil/OGC/0/unkown</epos-gsmlp:geophysicallogs_href>
#       <epos-gsmlp:geologicaldescription>unkown</epos-gsmlp:geologicaldescription>
#       <epos-gsmlp:geologicaldescription_href>http://www.opengis.net/def/nil/OGC/0/unkown</epos-gsmlp:geologicaldescription_href>
#       <epos-gsmlp:groundwaterlevel>inapplicable</epos-gsmlp:groundwaterlevel>
#       <epos-gsmlp:groundwaterlevel_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:groundwaterlevel_href>
#       <epos-gsmlp:groundwaterchemistry>inapplicable</epos-gsmlp:groundwaterchemistry>
#       <epos-gsmlp:groundwaterchemistry_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:groundwaterchemistry_href>
#       <epos-gsmlp:rockgeochemistry>missing</epos-gsmlp:rockgeochemistry>
#       <epos-gsmlp:rockgeochemistry_href>http://www.opengis.net/def/nil/OGC/0/missing</epos-gsmlp:rockgeochemistry_href>
#       <epos-gsmlp:poregaschemistry>missing</epos-gsmlp:poregaschemistry>
#       <epos-gsmlp:poregaschemistry_href>http://www.opengis.net/def/nil/OGC/0/missing</epos-gsmlp:poregaschemistry_href>
#       <epos-gsmlp:geotechnicalinfo>inapplicable</epos-gsmlp:geotechnicalinfo>
#       <epos-gsmlp:geotechnicalinfo_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:geotechnicalinfo_href>
#       <epos-gsmlp:location_wgs84>
#         <gml:Point srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" srsDimension="2" gml:id="BoreholeView_PointStacker.fid-2c3a8deb_197747fc4f7_50bb.location_wgs84">
#           <gml:pos>118.67 34.41</gml:pos>
#         </gml:Point>
#       </epos-gsmlp:location_wgs84>
#       <epos-gsmlp:lastupdated>2025-01-23T23:00:00Z</epos-gsmlp:lastupdated>
#       <epos-gsmlp:provider>6</epos-gsmlp:provider>
#     </epos-gsmlp:BoreholeView_PointStacker>
#   </wfs:member>
#   <wfs:member>
#     <epos-gsmlp:BoreholeView_PointStacker gml:id="BoreholeView_PointStacker.fid-2c3a8deb_197747fc4f7_50bc">
#       <gml:name>Donghai, CCSD-MH-2K</gml:name>
#       <epos-gsmlp:boreholeid>SD-5004_4_D</epos-gsmlp:boreholeid>
#       <epos-gsmlp:gmlidentifier>https://www.geodata.rocks/BoreholeView/SD-5004_4_D</epos-gsmlp:gmlidentifier>
#       <epos-gsmlp:gsmlpidentifier>https://www.geodata.rocks/Boreholes/SD-5004_4_D</epos-gsmlp:gsmlpidentifier>
#       <epos-gsmlp:purpose_href>https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch</epos-gsmlp:purpose_href>
#       <epos-gsmlp:purpose>multidisciplinary scientific research</epos-gsmlp:purpose>
#       <epos-gsmlp:boreholeuse>multidisciplinary scientific research</epos-gsmlp:boreholeuse>
#       <epos-gsmlp:boreholeuse_href>https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch</epos-gsmlp:boreholeuse_href>
#       <epos-gsmlp:status_href>https://data.geoscience.earth/ncl/BoreholeStatus/drillingCompleted</epos-gsmlp:status_href>
#       <epos-gsmlp:status>drilling completed</epos-gsmlp:status>
#       <epos-gsmlp:drillingmethod_href>https://data.geoscience.earth/ncl/DrillingMethod/coreDrilling</epos-gsmlp:drillingmethod_href>
#       <epos-gsmlp:drillingmethod>core drilling</epos-gsmlp:drillingmethod>
#       <epos-gsmlp:operator>China Geological Survey</epos-gsmlp:operator>
#       <epos-gsmlp:startpoint_href>https://data.geoscience.earth/ncl/StartPoint/naturalLandSurface</epos-gsmlp:startpoint_href>
#       <epos-gsmlp:startpoint>natural land surface</epos-gsmlp:startpoint>
#       <epos-gsmlp:inclinationtype_href>https://data.geoscience.earth/ncl/BoreholeInclinationType/vertical</epos-gsmlp:inclinationtype_href>
#       <epos-gsmlp:inclinationtype>vertical</epos-gsmlp:inclinationtype>
#       <epos-gsmlp:boreholelength_m>3525.18</epos-gsmlp:boreholelength_m>
#       <epos-gsmlp:elevation_m>28.5</epos-gsmlp:elevation_m>
#       <epos-gsmlp:elevation_srs>5613</epos-gsmlp:elevation_srs>
#       <epos-gsmlp:source>International Continental Scientific Drilling Program (ICDP), direct communication</epos-gsmlp:source>
#       <epos-gsmlp:metadata_uri>https://epos.brgm-rec.fr/geonetwork/srv/eng/catalog.search#/metadata/e435e013-944d-45e3-b2b7-a009889300d2</epos-gsmlp:metadata_uri>
#       <epos-gsmlp:cored>true</epos-gsmlp:cored>
#       <epos-gsmlp:accesstophysicaldrillcore>false</epos-gsmlp:accesstophysicaldrillcore>
#       <epos-gsmlp:detaileddescription>Borehole SD-5004_4_D</epos-gsmlp:detaileddescription>
#       <epos-gsmlp:detaileddescription_href>https://www.geodata.rocks/Boreholes/SD-5004_4_D</epos-gsmlp:detaileddescription_href>
#       <epos-gsmlp:geophysicallogs>unkown</epos-gsmlp:geophysicallogs>
#       <epos-gsmlp:geophysicallogs_href>http://www.opengis.net/def/nil/OGC/0/unkown</epos-gsmlp:geophysicallogs_href>
#       <epos-gsmlp:geologicaldescription>unkown</epos-gsmlp:geologicaldescription>
#       <epos-gsmlp:geologicaldescription_href>http://www.opengis.net/def/nil/OGC/0/unkown</epos-gsmlp:geologicaldescription_href>
#       <epos-gsmlp:groundwaterlevel>inapplicable</epos-gsmlp:groundwaterlevel>
#       <epos-gsmlp:groundwaterlevel_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:groundwaterlevel_href>
#       <epos-gsmlp:groundwaterchemistry>inapplicable</epos-gsmlp:groundwaterchemistry>
#       <epos-gsmlp:groundwaterchemistry_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:groundwaterchemistry_href>
#       <epos-gsmlp:rockgeochemistry>missing</epos-gsmlp:rockgeochemistry>
#       <epos-gsmlp:rockgeochemistry_href>http://www.opengis.net/def/nil/OGC/0/missing</epos-gsmlp:rockgeochemistry_href>
#       <epos-gsmlp:poregaschemistry>missing</epos-gsmlp:poregaschemistry>
#       <epos-gsmlp:poregaschemistry_href>http://www.opengis.net/def/nil/OGC/0/missing</epos-gsmlp:poregaschemistry_href>
#       <epos-gsmlp:geotechnicalinfo>inapplicable</epos-gsmlp:geotechnicalinfo>
#       <epos-gsmlp:geotechnicalinfo_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:geotechnicalinfo_href>
#       <epos-gsmlp:location_wgs84>
#         <gml:Point srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" srsDimension="2" gml:id="BoreholeView_PointStacker.fid-2c3a8deb_197747fc4f7_50bc.location_wgs84">
#           <gml:pos>118.67 34.41</gml:pos>
#         </gml:Point>
#       </epos-gsmlp:location_wgs84>
#       <epos-gsmlp:lastupdated>2025-01-23T23:00:00Z</epos-gsmlp:lastupdated>
#       <epos-gsmlp:provider>6</epos-gsmlp:provider>
#     </epos-gsmlp:BoreholeView_PointStacker>
#   </wfs:member>
#   <wfs:member>
#     <epos-gsmlp:BoreholeView_PointStacker gml:id="BoreholeView_PointStacker.fid-2c3a8deb_197747fc4f7_50bd">
#       <gml:name>Songliao 1A</gml:name>
#       <epos-gsmlp:boreholeid>SD-5012_1_A</epos-gsmlp:boreholeid>
#       <epos-gsmlp:gmlidentifier>https://www.geodata.rocks/BoreholeView/SD-5012_1_A</epos-gsmlp:gmlidentifier>
#       <epos-gsmlp:gsmlpidentifier>https://www.geodata.rocks/Boreholes/SD-5012_1_A</epos-gsmlp:gsmlpidentifier>
#       <epos-gsmlp:purpose_href>https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch</epos-gsmlp:purpose_href>
#       <epos-gsmlp:purpose>multidisciplinary scientific research</epos-gsmlp:purpose>
#       <epos-gsmlp:boreholeuse>multidisciplinary scientific research</epos-gsmlp:boreholeuse>
#       <epos-gsmlp:boreholeuse_href>https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch</epos-gsmlp:boreholeuse_href>
#       <epos-gsmlp:status_href>https://data.geoscience.earth/ncl/BoreholeStatus/drillingCompleted</epos-gsmlp:status_href>
#       <epos-gsmlp:status>drilling completed</epos-gsmlp:status>
#       <epos-gsmlp:drillingmethod_href>https://data.geoscience.earth/ncl/DrillingMethod/coreDrilling</epos-gsmlp:drillingmethod_href>
#       <epos-gsmlp:drillingmethod>core drilling</epos-gsmlp:drillingmethod>
#       <epos-gsmlp:startpoint_href>https://data.geoscience.earth/ncl/StartPoint/naturalLandSurface</epos-gsmlp:startpoint_href>
#       <epos-gsmlp:startpoint>natural land surface</epos-gsmlp:startpoint>
#       <epos-gsmlp:inclinationtype_href>https://data.geoscience.earth/ncl/BoreholeInclinationType/vertical</epos-gsmlp:inclinationtype_href>
#       <epos-gsmlp:inclinationtype>vertical</epos-gsmlp:inclinationtype>
#       <epos-gsmlp:boreholelength_m>4192.0</epos-gsmlp:boreholelength_m>
#       <epos-gsmlp:elevation_m>164.0</epos-gsmlp:elevation_m>
#       <epos-gsmlp:elevation_srs>5613</epos-gsmlp:elevation_srs>
#       <epos-gsmlp:source>International Continental Scientific Drilling Program (ICDP), direct communication</epos-gsmlp:source>
#       <epos-gsmlp:metadata_uri>https://epos.brgm-rec.fr/geonetwork/srv/eng/catalog.search#/metadata/e435e013-944d-45e3-b2b7-a009889300d2</epos-gsmlp:metadata_uri>
#       <epos-gsmlp:cored>true</epos-gsmlp:cored>
#       <epos-gsmlp:accesstophysicaldrillcore>true</epos-gsmlp:accesstophysicaldrillcore>
#       <epos-gsmlp:detaileddescription>Borehole SD-5012_1_A</epos-gsmlp:detaileddescription>
#       <epos-gsmlp:detaileddescription_href>https://www.geodata.rocks/Boreholes/SD-5012_1_A</epos-gsmlp:detaileddescription_href>
#       <epos-gsmlp:geophysicallogs>unkown</epos-gsmlp:geophysicallogs>
#       <epos-gsmlp:geophysicallogs_href>http://www.opengis.net/def/nil/OGC/0/unkown</epos-gsmlp:geophysicallogs_href>
#       <epos-gsmlp:geologicaldescription>unkown</epos-gsmlp:geologicaldescription>
#       <epos-gsmlp:geologicaldescription_href>http://www.opengis.net/def/nil/OGC/0/unkown</epos-gsmlp:geologicaldescription_href>
#       <epos-gsmlp:groundwaterlevel>inapplicable</epos-gsmlp:groundwaterlevel>
#       <epos-gsmlp:groundwaterlevel_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:groundwaterlevel_href>
#       <epos-gsmlp:groundwaterchemistry>inapplicable</epos-gsmlp:groundwaterchemistry>
#       <epos-gsmlp:groundwaterchemistry_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:groundwaterchemistry_href>
#       <epos-gsmlp:rockgeochemistry>missing</epos-gsmlp:rockgeochemistry>
#       <epos-gsmlp:rockgeochemistry_href>http://www.opengis.net/def/nil/OGC/0/missing</epos-gsmlp:rockgeochemistry_href>
#       <epos-gsmlp:poregaschemistry>missing</epos-gsmlp:poregaschemistry>
#       <epos-gsmlp:poregaschemistry_href>http://www.opengis.net/def/nil/OGC/0/missing</epos-gsmlp:poregaschemistry_href>
#       <epos-gsmlp:geotechnicalinfo>inapplicable</epos-gsmlp:geotechnicalinfo>
#       <epos-gsmlp:geotechnicalinfo_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:geotechnicalinfo_href>
#       <epos-gsmlp:location_wgs84>
#         <gml:Point srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" srsDimension="2" gml:id="BoreholeView_PointStacker.fid-2c3a8deb_197747fc4f7_50bd.location_wgs84">
#           <gml:pos>125.36307 46.2408</gml:pos>
#         </gml:Point>
#       </epos-gsmlp:location_wgs84>
#       <epos-gsmlp:lastupdated>2025-01-23T23:00:00Z</epos-gsmlp:lastupdated>
#       <epos-gsmlp:provider>6</epos-gsmlp:provider>
#     </epos-gsmlp:BoreholeView_PointStacker>
#   </wfs:member>
#   <wfs:member>
#     <epos-gsmlp:BoreholeView_PointStacker gml:id="BoreholeView_PointStacker.fid-2c3a8deb_197747fc4f7_50be">
#       <gml:name>Outokumpu</gml:name>
#       <epos-gsmlp:boreholeid>SD-5015_1_A</epos-gsmlp:boreholeid>
#       <epos-gsmlp:gmlidentifier>https://www.geodata.rocks/BoreholeView/SD-5015_1_A</epos-gsmlp:gmlidentifier>
#       <epos-gsmlp:gsmlpidentifier>https://www.geodata.rocks/Boreholes/SD-5015_1_A</epos-gsmlp:gsmlpidentifier>
#       <epos-gsmlp:purpose_href>https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch</epos-gsmlp:purpose_href>
#       <epos-gsmlp:purpose>multidisciplinary scientific research</epos-gsmlp:purpose>
#       <epos-gsmlp:boreholeuse>multidisciplinary scientific research</epos-gsmlp:boreholeuse>
#       <epos-gsmlp:boreholeuse_href>https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch</epos-gsmlp:boreholeuse_href>
#       <epos-gsmlp:status_href>https://data.geoscience.earth/ncl/BoreholeStatus/drillingCompleted</epos-gsmlp:status_href>
#       <epos-gsmlp:status>drilling completed</epos-gsmlp:status>
#       <epos-gsmlp:drillingmethod_href>https://data.geoscience.earth/ncl/DrillingMethod/coreDrilling</epos-gsmlp:drillingmethod_href>
#       <epos-gsmlp:drillingmethod>core drilling</epos-gsmlp:drillingmethod>
#       <epos-gsmlp:operator>Geological Suvery of Finland</epos-gsmlp:operator>
#       <epos-gsmlp:driller>NEDRA</epos-gsmlp:driller>
#       <epos-gsmlp:drillstartdate>2004-04-05Z</epos-gsmlp:drillstartdate>
#       <epos-gsmlp:drillenddate>2005-01-30Z</epos-gsmlp:drillenddate>
#       <epos-gsmlp:startpoint_href>https://data.geoscience.earth/ncl/StartPoint/naturalLandSurface</epos-gsmlp:startpoint_href>
#       <epos-gsmlp:startpoint>natural land surface</epos-gsmlp:startpoint>
#       <epos-gsmlp:inclinationtype_href>https://data.geoscience.earth/ncl/BoreholeInclinationType/vertical</epos-gsmlp:inclinationtype_href>
#       <epos-gsmlp:inclinationtype>vertical</epos-gsmlp:inclinationtype>
#       <epos-gsmlp:boreholelength_m>2516.0</epos-gsmlp:boreholelength_m>
#       <epos-gsmlp:elevation_m>99.04</epos-gsmlp:elevation_m>
#       <epos-gsmlp:elevation_srs>5613</epos-gsmlp:elevation_srs>
#       <epos-gsmlp:source>International Continental Scientific Drilling Program (ICDP), direct communication</epos-gsmlp:source>
#       <epos-gsmlp:metadata_uri>https://epos.brgm-rec.fr/geonetwork/srv/eng/catalog.search#/metadata/e435e013-944d-45e3-b2b7-a009889300d2</epos-gsmlp:metadata_uri>
#       <epos-gsmlp:cored>true</epos-gsmlp:cored>
#       <epos-gsmlp:accesstophysicaldrillcore>true</epos-gsmlp:accesstophysicaldrillcore>
#       <epos-gsmlp:detaileddescription>Borehole SD-5015_1_A</epos-gsmlp:detaileddescription>
#       <epos-gsmlp:detaileddescription_href>https://www.geodata.rocks/Boreholes/SD-5015_1_A</epos-gsmlp:detaileddescription_href>
#       <epos-gsmlp:geophysicallogs>unkown</epos-gsmlp:geophysicallogs>
#       <epos-gsmlp:geophysicallogs_href>http://www.opengis.net/def/nil/OGC/0/unkown</epos-gsmlp:geophysicallogs_href>
#       <epos-gsmlp:geologicaldescription>unkown</epos-gsmlp:geologicaldescription>
#       <epos-gsmlp:geologicaldescription_href>http://www.opengis.net/def/nil/OGC/0/unkown</epos-gsmlp:geologicaldescription_href>
#       <epos-gsmlp:groundwaterlevel>inapplicable</epos-gsmlp:groundwaterlevel>
#       <epos-gsmlp:groundwaterlevel_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:groundwaterlevel_href>
#       <epos-gsmlp:groundwaterchemistry>inapplicable</epos-gsmlp:groundwaterchemistry>
#       <epos-gsmlp:groundwaterchemistry_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:groundwaterchemistry_href>
#       <epos-gsmlp:rockgeochemistry>missing</epos-gsmlp:rockgeochemistry>
#       <epos-gsmlp:rockgeochemistry_href>http://www.opengis.net/def/nil/OGC/0/missing</epos-gsmlp:rockgeochemistry_href>
#       <epos-gsmlp:poregaschemistry>missing</epos-gsmlp:poregaschemistry>
#       <epos-gsmlp:poregaschemistry_href>http://www.opengis.net/def/nil/OGC/0/missing</epos-gsmlp:poregaschemistry_href>
#       <epos-gsmlp:geotechnicalinfo>inapplicable</epos-gsmlp:geotechnicalinfo>
#       <epos-gsmlp:geotechnicalinfo_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:geotechnicalinfo_href>
#       <epos-gsmlp:location_wgs84>
#         <gml:Point srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" srsDimension="2" gml:id="BoreholeView_PointStacker.fid-2c3a8deb_197747fc4f7_50be.location_wgs84">
#           <gml:pos>29.06199 62.71781</gml:pos>
#         </gml:Point>
#       </epos-gsmlp:location_wgs84>
#       <epos-gsmlp:lastupdated>2025-01-23T23:00:00Z</epos-gsmlp:lastupdated>
#       <epos-gsmlp:provider>6</epos-gsmlp:provider>
#     </epos-gsmlp:BoreholeView_PointStacker>
#   </wfs:member>
#   <wfs:member>
#     <epos-gsmlp:BoreholeView_PointStacker gml:id="BoreholeView_PointStacker.fid-2c3a8deb_197747fc4f7_50bf">
#       <gml:name>Kola SG-3</gml:name>
#       <epos-gsmlp:boreholeid>SD-5016_1_A</epos-gsmlp:boreholeid>
#       <epos-gsmlp:gmlidentifier>https://www.geodata.rocks/BoreholeView/SD-5016_1_A</epos-gsmlp:gmlidentifier>
#       <epos-gsmlp:gsmlpidentifier>https://www.geodata.rocks/Boreholes/SD-5016_1_A</epos-gsmlp:gsmlpidentifier>
#       <epos-gsmlp:purpose_href>https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch</epos-gsmlp:purpose_href>
#       <epos-gsmlp:purpose>multidisciplinary scientific research</epos-gsmlp:purpose>
#       <epos-gsmlp:boreholeuse>multidisciplinary scientific research</epos-gsmlp:boreholeuse>
#       <epos-gsmlp:boreholeuse_href>https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch</epos-gsmlp:boreholeuse_href>
#       <epos-gsmlp:status_href>https://data.geoscience.earth/ncl/BoreholeStatus/drillingCompleted</epos-gsmlp:status_href>
#       <epos-gsmlp:status>drilling completed</epos-gsmlp:status>
#       <epos-gsmlp:drillingmethod_href>https://data.geoscience.earth/ncl/DrillingMethod/coreDrilling</epos-gsmlp:drillingmethod_href>
#       <epos-gsmlp:drillingmethod>core drilling</epos-gsmlp:drillingmethod>
#       <epos-gsmlp:operator>Russian Academy of Sciences, Kola Science Centre, Geological Institute</epos-gsmlp:operator>
#       <epos-gsmlp:driller>NEDRA</epos-gsmlp:driller>
#       <epos-gsmlp:drillstartdate>1970-04-30Z</epos-gsmlp:drillstartdate>
#       <epos-gsmlp:drillenddate>1989-12-30Z</epos-gsmlp:drillenddate>
#       <epos-gsmlp:startpoint_href>https://data.geoscience.earth/ncl/StartPoint/naturalLandSurface</epos-gsmlp:startpoint_href>
#       <epos-gsmlp:startpoint>natural land surface</epos-gsmlp:startpoint>
#       <epos-gsmlp:inclinationtype_href>https://data.geoscience.earth/ncl/BoreholeInclinationType/vertical</epos-gsmlp:inclinationtype_href>
#       <epos-gsmlp:inclinationtype>vertical</epos-gsmlp:inclinationtype>
#       <epos-gsmlp:boreholematerialcustodian>Russian Academy of Sciences, Kola Science Centre, Geological Institute</epos-gsmlp:boreholematerialcustodian>
#       <epos-gsmlp:boreholelength_m>12261.0</epos-gsmlp:boreholelength_m>
#       <epos-gsmlp:elevation_m>346.0</epos-gsmlp:elevation_m>
#       <epos-gsmlp:elevation_srs>5613</epos-gsmlp:elevation_srs>
#       <epos-gsmlp:source>International Continental Scientific Drilling Program (ICDP), direct communication</epos-gsmlp:source>
#       <epos-gsmlp:metadata_uri>https://epos.brgm-rec.fr/geonetwork/srv/eng/catalog.search#/metadata/e435e013-944d-45e3-b2b7-a009889300d2</epos-gsmlp:metadata_uri>
#       <epos-gsmlp:cored>true</epos-gsmlp:cored>
#       <epos-gsmlp:accesstophysicaldrillcore>false</epos-gsmlp:accesstophysicaldrillcore>
#       <epos-gsmlp:detaileddescription>Borehole SD-5016_1_A</epos-gsmlp:detaileddescription>
#       <epos-gsmlp:detaileddescription_href>https://www.geodata.rocks/Boreholes/SD-5016_1_A</epos-gsmlp:detaileddescription_href>
#       <epos-gsmlp:geophysicallogs>unkown</epos-gsmlp:geophysicallogs>
#       <epos-gsmlp:geophysicallogs_href>http://www.opengis.net/def/nil/OGC/0/unkown</epos-gsmlp:geophysicallogs_href>
#       <epos-gsmlp:geologicaldescription>unkown</epos-gsmlp:geologicaldescription>
#       <epos-gsmlp:geologicaldescription_href>http://www.opengis.net/def/nil/OGC/0/unkown</epos-gsmlp:geologicaldescription_href>
#       <epos-gsmlp:groundwaterlevel>inapplicable</epos-gsmlp:groundwaterlevel>
#       <epos-gsmlp:groundwaterlevel_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:groundwaterlevel_href>
#       <epos-gsmlp:groundwaterchemistry>inapplicable</epos-gsmlp:groundwaterchemistry>
#       <epos-gsmlp:groundwaterchemistry_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:groundwaterchemistry_href>
#       <epos-gsmlp:rockgeochemistry>unknown</epos-gsmlp:rockgeochemistry>
#       <epos-gsmlp:rockgeochemistry_href>http://www.opengis.net/def/nil/OGC/0/unknown</epos-gsmlp:rockgeochemistry_href>
#       <epos-gsmlp:poregaschemistry>unknown</epos-gsmlp:poregaschemistry>
#       <epos-gsmlp:poregaschemistry_href>http://www.opengis.net/def/nil/OGC/0/unknown</epos-gsmlp:poregaschemistry_href>
#       <epos-gsmlp:geotechnicalinfo>inapplicable</epos-gsmlp:geotechnicalinfo>
#       <epos-gsmlp:geotechnicalinfo_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:geotechnicalinfo_href>
#       <epos-gsmlp:location_wgs84>
#         <gml:Point srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" srsDimension="2" gml:id="BoreholeView_PointStacker.fid-2c3a8deb_197747fc4f7_50bf.location_wgs84">
#           <gml:pos>29.28 69.17</gml:pos>
#         </gml:Point>
#       </epos-gsmlp:location_wgs84>
#       <epos-gsmlp:lastupdated>2025-01-23T23:00:00Z</epos-gsmlp:lastupdated>
#       <epos-gsmlp:provider>6</epos-gsmlp:provider>
#     </epos-gsmlp:BoreholeView_PointStacker>
#   </wfs:member>
#   <wfs:member>
#     <epos-gsmlp:BoreholeView_PointStacker gml:id="BoreholeView_PointStacker.fid-2c3a8deb_197747fc4f7_50c0">
#       <gml:name>SAFOD-PH</gml:name>
#       <epos-gsmlp:boreholeid>SD-5025_1_A</epos-gsmlp:boreholeid>
#       <epos-gsmlp:gmlidentifier>https://www.geodata.rocks/BoreholeView/SD-5025_1_A</epos-gsmlp:gmlidentifier>
#       <epos-gsmlp:gsmlpidentifier>https://www.geodata.rocks/Boreholes/SD-5025_1_A</epos-gsmlp:gsmlpidentifier>
#       <epos-gsmlp:purpose_href>https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch</epos-gsmlp:purpose_href>
#       <epos-gsmlp:purpose>multidisciplinary scientific research</epos-gsmlp:purpose>
#       <epos-gsmlp:boreholeuse>multidisciplinary scientific research</epos-gsmlp:boreholeuse>
#       <epos-gsmlp:boreholeuse_href>https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch</epos-gsmlp:boreholeuse_href>
#       <epos-gsmlp:status_href>https://data.geoscience.earth/ncl/BoreholeStatus/drillingCompleted</epos-gsmlp:status_href>
#       <epos-gsmlp:status>drilling completed</epos-gsmlp:status>
#       <epos-gsmlp:drillingmethod_href>https://data.geoscience.earth/ncl/DrillingMethod/hydraulicRotaryDrilling</epos-gsmlp:drillingmethod_href>
#       <epos-gsmlp:drillingmethod>hydraulic rotary drilling</epos-gsmlp:drillingmethod>
#       <epos-gsmlp:operator>DOSECC</epos-gsmlp:operator>
#       <epos-gsmlp:driller>DOSECC</epos-gsmlp:driller>
#       <epos-gsmlp:drillstartdate>2002-06-11Z</epos-gsmlp:drillstartdate>
#       <epos-gsmlp:drillenddate>2002-07-23Z</epos-gsmlp:drillenddate>
#       <epos-gsmlp:startpoint_href>https://data.geoscience.earth/ncl/StartPoint/naturalLandSurface</epos-gsmlp:startpoint_href>
#       <epos-gsmlp:startpoint>natural land surface</epos-gsmlp:startpoint>
#       <epos-gsmlp:inclinationtype_href>https://data.geoscience.earth/ncl/BoreholeInclinationType/vertical</epos-gsmlp:inclinationtype_href>
#       <epos-gsmlp:inclinationtype>vertical</epos-gsmlp:inclinationtype>
#       <epos-gsmlp:boreholelength_m>2154.94</epos-gsmlp:boreholelength_m>
#       <epos-gsmlp:elevation_m>667.5</epos-gsmlp:elevation_m>
#       <epos-gsmlp:elevation_srs>5613</epos-gsmlp:elevation_srs>
#       <epos-gsmlp:source>International Continental Scientific Drilling Program (ICDP), direct communication</epos-gsmlp:source>
#       <epos-gsmlp:metadata_uri>https://epos.brgm-rec.fr/geonetwork/srv/eng/catalog.search#/metadata/e435e013-944d-45e3-b2b7-a009889300d2</epos-gsmlp:metadata_uri>
#       <epos-gsmlp:cored>false</epos-gsmlp:cored>
#       <epos-gsmlp:accesstophysicaldrillcore>false</epos-gsmlp:accesstophysicaldrillcore>
#       <epos-gsmlp:detaileddescription>Borehole SD-5025_1_A</epos-gsmlp:detaileddescription>
#       <epos-gsmlp:detaileddescription_href>https://www.geodata.rocks/Boreholes/SD-5025_1_A</epos-gsmlp:detaileddescription_href>
#       <epos-gsmlp:geophysicallogs>unkown</epos-gsmlp:geophysicallogs>
#       <epos-gsmlp:geophysicallogs_href>http://www.opengis.net/def/nil/OGC/0/unkown</epos-gsmlp:geophysicallogs_href>
#       <epos-gsmlp:geologicaldescription>unkown</epos-gsmlp:geologicaldescription>
#       <epos-gsmlp:geologicaldescription_href>http://www.opengis.net/def/nil/OGC/0/unkown</epos-gsmlp:geologicaldescription_href>
#       <epos-gsmlp:groundwaterlevel>inapplicable</epos-gsmlp:groundwaterlevel>
#       <epos-gsmlp:groundwaterlevel_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:groundwaterlevel_href>
#       <epos-gsmlp:groundwaterchemistry>inapplicable</epos-gsmlp:groundwaterchemistry>
#       <epos-gsmlp:groundwaterchemistry_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:groundwaterchemistry_href>
#       <epos-gsmlp:rockgeochemistry>missing</epos-gsmlp:rockgeochemistry>
#       <epos-gsmlp:rockgeochemistry_href>http://www.opengis.net/def/nil/OGC/0/missing</epos-gsmlp:rockgeochemistry_href>
#       <epos-gsmlp:poregaschemistry>missing</epos-gsmlp:poregaschemistry>
#       <epos-gsmlp:poregaschemistry_href>http://www.opengis.net/def/nil/OGC/0/missing</epos-gsmlp:poregaschemistry_href>
#       <epos-gsmlp:geotechnicalinfo>inapplicable</epos-gsmlp:geotechnicalinfo>
#       <epos-gsmlp:geotechnicalinfo_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:geotechnicalinfo_href>
#       <epos-gsmlp:location_wgs84>
#         <gml:Point srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" srsDimension="2" gml:id="BoreholeView_PointStacker.fid-2c3a8deb_197747fc4f7_50c0.location_wgs84">
#           <gml:pos>-120.55211 35.97426</gml:pos>
#         </gml:Point>
#       </epos-gsmlp:location_wgs84>
#       <epos-gsmlp:lastupdated>2025-01-23T23:00:00Z</epos-gsmlp:lastupdated>
#       <epos-gsmlp:provider>6</epos-gsmlp:provider>
#     </epos-gsmlp:BoreholeView_PointStacker>
#   </wfs:member>
#   <wfs:member>
#     <epos-gsmlp:BoreholeView_PointStacker gml:id="BoreholeView_PointStacker.fid-2c3a8deb_197747fc4f7_50c1">
#       <gml:name>SAFOD-MH-ST1</gml:name>
#       <epos-gsmlp:boreholeid>SD-5025_1_C</epos-gsmlp:boreholeid>
#       <epos-gsmlp:gmlidentifier>https://www.geodata.rocks/BoreholeView/SD-5025_1_C</epos-gsmlp:gmlidentifier>
#       <epos-gsmlp:gsmlpidentifier>https://www.geodata.rocks/Boreholes/SD-5025_1_C</epos-gsmlp:gsmlpidentifier>
#       <epos-gsmlp:purpose_href>https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch</epos-gsmlp:purpose_href>
#       <epos-gsmlp:purpose>multidisciplinary scientific research</epos-gsmlp:purpose>
#       <epos-gsmlp:boreholeuse>multidisciplinary scientific research</epos-gsmlp:boreholeuse>
#       <epos-gsmlp:boreholeuse_href>https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch</epos-gsmlp:boreholeuse_href>
#       <epos-gsmlp:status_href>https://data.geoscience.earth/ncl/BoreholeStatus/drillingCompleted</epos-gsmlp:status_href>
#       <epos-gsmlp:status>drilling completed</epos-gsmlp:status>
#       <epos-gsmlp:drillingmethod_href>https://data.geoscience.earth/ncl/DrillingMethod/sidewallCoreBullet</epos-gsmlp:drillingmethod_href>
#       <epos-gsmlp:drillingmethod>sidewall core bullet</epos-gsmlp:drillingmethod>
#       <epos-gsmlp:operator>DOSECC</epos-gsmlp:operator>
#       <epos-gsmlp:driller>DOSECC</epos-gsmlp:driller>
#       <epos-gsmlp:drillstartdate>2004-07-19Z</epos-gsmlp:drillstartdate>
#       <epos-gsmlp:drillenddate>2005-08-08Z</epos-gsmlp:drillenddate>
#       <epos-gsmlp:startpoint_href>https://data.geoscience.earth/ncl/StartPoint/naturalLandSurface</epos-gsmlp:startpoint_href>
#       <epos-gsmlp:startpoint>natural land surface</epos-gsmlp:startpoint>
#       <epos-gsmlp:inclinationtype_href>https://data.geoscience.earth/ncl/BoreholeInclinationType/inclinedDown</epos-gsmlp:inclinationtype_href>
#       <epos-gsmlp:inclinationtype>inclined down</epos-gsmlp:inclinationtype>
#       <epos-gsmlp:boreholelength_m>2994.81</epos-gsmlp:boreholelength_m>
#       <epos-gsmlp:elevation_m>316.94</epos-gsmlp:elevation_m>
#       <epos-gsmlp:elevation_srs>5715</epos-gsmlp:elevation_srs>
#       <epos-gsmlp:source>International Continental Scientific Drilling Program (ICDP), direct communication</epos-gsmlp:source>
#       <epos-gsmlp:metadata_uri>https://epos.brgm-rec.fr/geonetwork/srv/eng/catalog.search#/metadata/e435e013-944d-45e3-b2b7-a009889300d2</epos-gsmlp:metadata_uri>
#       <epos-gsmlp:cored>true</epos-gsmlp:cored>
#       <epos-gsmlp:accesstophysicaldrillcore>false</epos-gsmlp:accesstophysicaldrillcore>
#       <epos-gsmlp:detaileddescription>Borehole SD-5025_1_C</epos-gsmlp:detaileddescription>
#       <epos-gsmlp:detaileddescription_href>https://www.geodata.rocks/Boreholes/SD-5025_1_C</epos-gsmlp:detaileddescription_href>
#       <epos-gsmlp:geophysicallogs>unkown</epos-gsmlp:geophysicallogs>
#       <epos-gsmlp:geophysicallogs_href>http://www.opengis.net/def/nil/OGC/0/unkown</epos-gsmlp:geophysicallogs_href>
#       <epos-gsmlp:geologicaldescription>unkown</epos-gsmlp:geologicaldescription>
#       <epos-gsmlp:geologicaldescription_href>http://www.opengis.net/def/nil/OGC/0/unkown</epos-gsmlp:geologicaldescription_href>
#       <epos-gsmlp:groundwaterlevel>inapplicable</epos-gsmlp:groundwaterlevel>
#       <epos-gsmlp:groundwaterlevel_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:groundwaterlevel_href>
#       <epos-gsmlp:groundwaterchemistry>inapplicable</epos-gsmlp:groundwaterchemistry>
#       <epos-gsmlp:groundwaterchemistry_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:groundwaterchemistry_href>
#       <epos-gsmlp:rockgeochemistry>missing</epos-gsmlp:rockgeochemistry>
#       <epos-gsmlp:rockgeochemistry_href>http://www.opengis.net/def/nil/OGC/0/missing</epos-gsmlp:rockgeochemistry_href>
#       <epos-gsmlp:poregaschemistry>missing</epos-gsmlp:poregaschemistry>
#       <epos-gsmlp:poregaschemistry_href>http://www.opengis.net/def/nil/OGC/0/missing</epos-gsmlp:poregaschemistry_href>
#       <epos-gsmlp:geotechnicalinfo>inapplicable</epos-gsmlp:geotechnicalinfo>
#       <epos-gsmlp:geotechnicalinfo_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:geotechnicalinfo_href>
#       <epos-gsmlp:location_wgs84>
#         <gml:Point srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" srsDimension="2" gml:id="BoreholeView_PointStacker.fid-2c3a8deb_197747fc4f7_50c1.location_wgs84">
#           <gml:pos>-120.55185 35.97417</gml:pos>
#         </gml:Point>
#       </epos-gsmlp:location_wgs84>
#       <epos-gsmlp:lastupdated>2025-01-23T23:00:00Z</epos-gsmlp:lastupdated>
#       <epos-gsmlp:provider>6</epos-gsmlp:provider>
#     </epos-gsmlp:BoreholeView_PointStacker>
#   </wfs:member>
#   <wfs:member>
#     <epos-gsmlp:BoreholeView_PointStacker gml:id="BoreholeView_PointStacker.fid-2c3a8deb_197747fc4f7_50c2">
#       <gml:name>Hawaii, HSDP-2a</gml:name>
#       <epos-gsmlp:boreholeid>SD-5027_1_A</epos-gsmlp:boreholeid>
#       <epos-gsmlp:gmlidentifier>https://www.geodata.rocks/BoreholeView/SD-5027_1_A</epos-gsmlp:gmlidentifier>
#       <epos-gsmlp:gsmlpidentifier>https://www.geodata.rocks/Boreholes/SD-5027_1_A</epos-gsmlp:gsmlpidentifier>
#       <epos-gsmlp:purpose_href>https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch</epos-gsmlp:purpose_href>
#       <epos-gsmlp:purpose>multidisciplinary scientific research</epos-gsmlp:purpose>
#       <epos-gsmlp:boreholeuse>multidisciplinary scientific research</epos-gsmlp:boreholeuse>
#       <epos-gsmlp:boreholeuse_href>https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch</epos-gsmlp:boreholeuse_href>
#       <epos-gsmlp:status_href>https://data.geoscience.earth/ncl/BoreholeStatus/drillingCompleted</epos-gsmlp:status_href>
#       <epos-gsmlp:status>drilling completed</epos-gsmlp:status>
#       <epos-gsmlp:drillingmethod_href>https://data.geoscience.earth/ncl/DrillingMethod/coreDrilling</epos-gsmlp:drillingmethod_href>
#       <epos-gsmlp:drillingmethod>core drilling</epos-gsmlp:drillingmethod>
#       <epos-gsmlp:startpoint_href>https://data.geoscience.earth/ncl/StartPoint/naturalLandSurface</epos-gsmlp:startpoint_href>
#       <epos-gsmlp:startpoint>natural land surface</epos-gsmlp:startpoint>
#       <epos-gsmlp:inclinationtype_href>https://data.geoscience.earth/ncl/BoreholeInclinationType/vertical</epos-gsmlp:inclinationtype_href>
#       <epos-gsmlp:inclinationtype>vertical</epos-gsmlp:inclinationtype>
#       <epos-gsmlp:boreholelength_m>3099.67</epos-gsmlp:boreholelength_m>
#       <epos-gsmlp:elevation_m>11.55</epos-gsmlp:elevation_m>
#       <epos-gsmlp:elevation_srs>5613</epos-gsmlp:elevation_srs>
#       <epos-gsmlp:source>International Continental Scientific Drilling Program (ICDP), direct communication</epos-gsmlp:source>
#       <epos-gsmlp:metadata_uri>https://epos.brgm-rec.fr/geonetwork/srv/eng/catalog.search#/metadata/e435e013-944d-45e3-b2b7-a009889300d2</epos-gsmlp:metadata_uri>
#       <epos-gsmlp:cored>true</epos-gsmlp:cored>
#       <epos-gsmlp:accesstophysicaldrillcore>true</epos-gsmlp:accesstophysicaldrillcore>
#       <epos-gsmlp:detaileddescription>Borehole SD-5027_1_A</epos-gsmlp:detaileddescription>
#       <epos-gsmlp:detaileddescription_href>https://www.geodata.rocks/Boreholes/SD-5027_1_A</epos-gsmlp:detaileddescription_href>
#       <epos-gsmlp:geophysicallogs>unkown</epos-gsmlp:geophysicallogs>
#       <epos-gsmlp:geophysicallogs_href>http://www.opengis.net/def/nil/OGC/0/unkown</epos-gsmlp:geophysicallogs_href>
#       <epos-gsmlp:geologicaldescription>unkown</epos-gsmlp:geologicaldescription>
#       <epos-gsmlp:geologicaldescription_href>http://www.opengis.net/def/nil/OGC/0/unkown</epos-gsmlp:geologicaldescription_href>
#       <epos-gsmlp:groundwaterlevel>inapplicable</epos-gsmlp:groundwaterlevel>
#       <epos-gsmlp:groundwaterlevel_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:groundwaterlevel_href>
#       <epos-gsmlp:groundwaterchemistry>inapplicable</epos-gsmlp:groundwaterchemistry>
#       <epos-gsmlp:groundwaterchemistry_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:groundwaterchemistry_href>
#       <epos-gsmlp:rockgeochemistry>missing</epos-gsmlp:rockgeochemistry>
#       <epos-gsmlp:rockgeochemistry_href>http://www.opengis.net/def/nil/OGC/0/missing</epos-gsmlp:rockgeochemistry_href>
#       <epos-gsmlp:poregaschemistry>missing</epos-gsmlp:poregaschemistry>
#       <epos-gsmlp:poregaschemistry_href>http://www.opengis.net/def/nil/OGC/0/missing</epos-gsmlp:poregaschemistry_href>
#       <epos-gsmlp:geotechnicalinfo>inapplicable</epos-gsmlp:geotechnicalinfo>
#       <epos-gsmlp:geotechnicalinfo_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:geotechnicalinfo_href>
#       <epos-gsmlp:location_wgs84>
#         <gml:Point srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" srsDimension="2" gml:id="BoreholeView_PointStacker.fid-2c3a8deb_197747fc4f7_50c2.location_wgs84">
#           <gml:pos>-155.05 19.74</gml:pos>
#         </gml:Point>
#       </epos-gsmlp:location_wgs84>
#       <epos-gsmlp:lastupdated>2025-01-23T23:00:00Z</epos-gsmlp:lastupdated>
#       <epos-gsmlp:provider>6</epos-gsmlp:provider>
#     </epos-gsmlp:BoreholeView_PointStacker>
#   </wfs:member>
#   <wfs:member>
#     <epos-gsmlp:BoreholeView_PointStacker gml:id="BoreholeView_PointStacker.fid-2c3a8deb_197747fc4f7_50c3">
#       <gml:name>Iceland, IDDP-1-A, RN-17</gml:name>
#       <epos-gsmlp:boreholeid>SD-5029_1_A</epos-gsmlp:boreholeid>
#       <epos-gsmlp:gmlidentifier>https://www.geodata.rocks/BoreholeView/SD-5029_1_A</epos-gsmlp:gmlidentifier>
#       <epos-gsmlp:gsmlpidentifier>https://www.geodata.rocks/Boreholes/SD-5029_1_A</epos-gsmlp:gsmlpidentifier>
#       <epos-gsmlp:purpose_href>https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch</epos-gsmlp:purpose_href>
#       <epos-gsmlp:purpose>multidisciplinary scientific research</epos-gsmlp:purpose>
#       <epos-gsmlp:boreholeuse>multidisciplinary scientific research</epos-gsmlp:boreholeuse>
#       <epos-gsmlp:boreholeuse_href>https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch</epos-gsmlp:boreholeuse_href>
#       <epos-gsmlp:status_href>https://data.geoscience.earth/ncl/BoreholeStatus/drillingCompleted</epos-gsmlp:status_href>
#       <epos-gsmlp:status>drilling completed</epos-gsmlp:status>
#       <epos-gsmlp:drillingmethod_href>https://data.geoscience.earth/ncl/DrillingMethod/hydraulicRotaryDrilling</epos-gsmlp:drillingmethod_href>
#       <epos-gsmlp:drillingmethod>hydraulic rotary drilling</epos-gsmlp:drillingmethod>
#       <epos-gsmlp:operator>Jarðboranir Hf. / Iceland Drilling Company Ltd.</epos-gsmlp:operator>
#       <epos-gsmlp:driller>Jarðboranir Hf. / Iceland Drilling Company Ltd.</epos-gsmlp:driller>
#       <epos-gsmlp:drillstartdate>2008-06-18Z</epos-gsmlp:drillstartdate>
#       <epos-gsmlp:drillenddate>2009-05-07Z</epos-gsmlp:drillenddate>
#       <epos-gsmlp:startpoint_href>https://data.geoscience.earth/ncl/StartPoint/naturalLandSurface</epos-gsmlp:startpoint_href>
#       <epos-gsmlp:startpoint>natural land surface</epos-gsmlp:startpoint>
#       <epos-gsmlp:inclinationtype_href>https://data.geoscience.earth/ncl/BoreholeInclinationType/vertical</epos-gsmlp:inclinationtype_href>
#       <epos-gsmlp:inclinationtype>vertical</epos-gsmlp:inclinationtype>
#       <epos-gsmlp:boreholelength_m>2100.0</epos-gsmlp:boreholelength_m>
# ...
#       <epos-gsmlp:startpoint>natural land surface</epos-gsmlp:startpoint>
#       <epos-gsmlp:inclinationtype_href>https://data.geoscience.earth/ncl/BoreholeInclinationType/vertical</epos-gsmlp:inclinationtype_href>
#       <epos-gsmlp:inclinationtype>vertical</epos-gsmlp:inclinationtype>
#       <epos-gsmlp:boreholematerialcustodian>Federal Institute for Geosciences and Natural Resources (BGR), Core archive for research drilling</epos-gsmlp:boreholematerialcustodian>
#       <epos-gsmlp:boreholelength_m>2495.8</epos-gsmlp:boreholelength_m>
#       <epos-gsmlp:elevation_m>522.51</epos-gsmlp:elevation_m>
#       <epos-gsmlp:elevation_srs>5613</epos-gsmlp:elevation_srs>
#       <epos-gsmlp:source>COSC-1 operational report - Operational data sets. Lorenz, Henning; Rosberg, Jan-Erik; Juhlin, Christopher; Bjelm, Leif; Almqvist, Bjarne; Berthet, Théo; Conze, Ronald; Gee, David G.; Klonowska, Iwona; Pascal, Christophe; Pedersen, Karsten; Roberts, Nick; Tsang, Chinfu (2015): COSC-1 operational report - Operational data sets. GFZ Data Services. https://doi.org/10.1594/GFZ.SDDB.ICDP.5054.2015</epos-gsmlp:source>
#       <epos-gsmlp:metadata_uri>https://epos.brgm-rec.fr/geonetwork/srv/eng/catalog.search#/metadata/e435e013-944d-45e3-b2b7-a009889300d2</epos-gsmlp:metadata_uri>
#       <epos-gsmlp:cored>true</epos-gsmlp:cored>
#       <epos-gsmlp:accesstophysicaldrillcore>true</epos-gsmlp:accesstophysicaldrillcore>
#       <epos-gsmlp:detaileddescription>Borehole SD-5054_1_A</epos-gsmlp:detaileddescription>
#       <epos-gsmlp:detaileddescription_href>https://www.geodata.rocks/Boreholes/SD-5054_1_A</epos-gsmlp:detaileddescription_href>
#       <epos-gsmlp:geophysicallogs>COSC-1 operational data sets</epos-gsmlp:geophysicallogs>
#       <epos-gsmlp:geophysicallogs_href>https://doi.org/10.5880/ICDP.5054.002</epos-gsmlp:geophysicallogs_href>
#       <epos-gsmlp:geologicaldescription>lithology</epos-gsmlp:geologicaldescription>
#       <epos-gsmlp:geologicaldescription_href>https://www.geodata.rocks/GeologyLogs/SD-5054_1_A_on-site_full</epos-gsmlp:geologicaldescription_href>
#       <epos-gsmlp:groundwaterlevel>inapplicable</epos-gsmlp:groundwaterlevel>
#       <epos-gsmlp:groundwaterlevel_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:groundwaterlevel_href>
#       <epos-gsmlp:groundwaterchemistry>inapplicable</epos-gsmlp:groundwaterchemistry>
#       <epos-gsmlp:groundwaterchemistry_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:groundwaterchemistry_href>
#       <epos-gsmlp:rockgeochemistry>XRF</epos-gsmlp:rockgeochemistry>
#       <epos-gsmlp:rockgeochemistry_href>https://doi.org/10.5880/ICDP.5054.002</epos-gsmlp:rockgeochemistry_href>
#       <epos-gsmlp:poregaschemistry>inapplicable</epos-gsmlp:poregaschemistry>
#       <epos-gsmlp:poregaschemistry_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:poregaschemistry_href>
#       <epos-gsmlp:geotechnicalinfo>inapplicable</epos-gsmlp:geotechnicalinfo>
#       <epos-gsmlp:geotechnicalinfo_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:geotechnicalinfo_href>
#       <epos-gsmlp:location_wgs84>
#         <gml:Point srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" srsDimension="2" gml:id="BoreholeView_PointStacker.fid-2c3a8deb_197747fc4f7_50c4.location_wgs84">
#           <gml:pos>13.20292 63.40163</gml:pos>
#         </gml:Point>
#       </epos-gsmlp:location_wgs84>
#       <epos-gsmlp:positionalaccuracy>0.1</epos-gsmlp:positionalaccuracy>
#       <epos-gsmlp:lastupdated>2025-01-23T23:00:00Z</epos-gsmlp:lastupdated>
#       <epos-gsmlp:provider>6</epos-gsmlp:provider>
#     </epos-gsmlp:BoreholeView_PointStacker>
#   </wfs:member>
#   <wfs:member>
#     <epos-gsmlp:BoreholeView_PointStacker gml:id="BoreholeView_PointStacker.fid-2c3a8deb_197747fc4f7_50c5">
#       <gml:description>The Collisional Orogeny in the Scandinavian Caledonides (COSC) scientific drilling project aims to characterise the structure and orogenic processes involved in a major collisional mountain belt by multi-disciplinary geoscientific research. Located in western central Sweden, the project has drilled two fully cored deep boreholes into the bedrock of the deeply eroded Early Paleozoic Caledonide Orogen. COSC-2 successfully recovered a continuous drill core to 2276 m depth from two boreholes (100 m to TD in COSC-2 A and 6 - 116 m in COSC-2 B). The retrieved geological section includes the lower part of the allochthons, the main décollement and basement rocks. Turbiditic greywackes were drilled from the bedrock surface at c. 5 m depth and down to c. 780 m (light blue in Fig. 2). Here, the borehole encountered a strongly sheared black shale formation, which is in accordance with the magnetotelluric site investigations. After c. 45 m, the black shales give way to a tectonically disturbed unit of sandstone, conglomerate and tuff, which extends downwards to c. 1250 m. At this depth, ignimbrites and volcanic porphyries were encountered for the first time in the borehole. They show only minor signs of deformation and are present in different varieties (green to reddish, different grain size) down to the total depth, interrupted by major (and some minor) dolerite intrusions between c. 1600 and c. 1930 m, which show clear signs of deformation (cataclasite, breccia). partially different from the expected geological section with respect to the depth to the main décollement and the expected rock types. COSC-2 was surveyed by a comprehensive post-drilling downhole logging campaign and a combined borehole/land seismic survey in autumn 2022.</gml:description>
#       <gml:name>COSC-2 A</gml:name>
#       <epos-gsmlp:boreholeid>SD-5054_2_A</epos-gsmlp:boreholeid>
#       <epos-gsmlp:gmlidentifier>https://www.geodata.rocks/BoreholeView/SD-5054_2_A</epos-gsmlp:gmlidentifier>
#       <epos-gsmlp:gsmlpidentifier>https://www.geodata.rocks/Boreholes/SD-5054_2_A</epos-gsmlp:gsmlpidentifier>
#       <epos-gsmlp:purpose_href>https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch</epos-gsmlp:purpose_href>
#       <epos-gsmlp:purpose>multidisciplinary scientific research</epos-gsmlp:purpose>
#       <epos-gsmlp:boreholeuse>multidisciplinary scientific research</epos-gsmlp:boreholeuse>
#       <epos-gsmlp:boreholeuse_href>https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch</epos-gsmlp:boreholeuse_href>
#       <epos-gsmlp:status_href>https://data.geoscience.earth/ncl/BoreholeStatus/drillingCompleted</epos-gsmlp:status_href>
#       <epos-gsmlp:status>drilling completed</epos-gsmlp:status>
#       <epos-gsmlp:drillingmethod_href>https://data.geoscience.earth/ncl/DrillingMethod/diamondCore</epos-gsmlp:drillingmethod_href>
#       <epos-gsmlp:drillingmethod>diamond core</epos-gsmlp:drillingmethod>
#       <epos-gsmlp:operator>Uppsala University, Sweden (for I-EDDA-TC)</epos-gsmlp:operator>
#       <epos-gsmlp:driller>Lund University, Sweden / Jämtborr AB</epos-gsmlp:driller>
#       <epos-gsmlp:drillstartdate>2020-04-16Z</epos-gsmlp:drillstartdate>
#       <epos-gsmlp:drillenddate>2020-08-07Z</epos-gsmlp:drillenddate>
#       <epos-gsmlp:startpoint_href>https://data.geoscience.earth/ncl/StartPoint/naturalLandSurface</epos-gsmlp:startpoint_href>
#       <epos-gsmlp:startpoint>natural land surface</epos-gsmlp:startpoint>
#       <epos-gsmlp:inclinationtype_href>https://data.geoscience.earth/ncl/BoreholeInclinationType/vertical</epos-gsmlp:inclinationtype_href>
#       <epos-gsmlp:inclinationtype>vertical</epos-gsmlp:inclinationtype>
#       <epos-gsmlp:boreholematerialcustodian>Federal Institute for Geosciences and Natural Resources (BGR), Core archive for research drilling</epos-gsmlp:boreholematerialcustodian>
#       <epos-gsmlp:boreholelength_m>2276.05</epos-gsmlp:boreholelength_m>
#       <epos-gsmlp:elevation_m>320.25</epos-gsmlp:elevation_m>
#       <epos-gsmlp:elevation_srs>5613</epos-gsmlp:elevation_srs>
#       <epos-gsmlp:metadata_uri>https://epos.brgm-rec.fr/geonetwork/srv/eng/catalog.search#/metadata/e435e013-944d-45e3-b2b7-a009889300d2</epos-gsmlp:metadata_uri>
#       <epos-gsmlp:cored>true</epos-gsmlp:cored>
#       <epos-gsmlp:accesstophysicaldrillcore>false</epos-gsmlp:accesstophysicaldrillcore>
#       <epos-gsmlp:detaileddescription>Borehole SD-5054_2_A</epos-gsmlp:detaileddescription>
#       <epos-gsmlp:detaileddescription_href>https://www.geodata.rocks/Boreholes/SD-5054_2_A</epos-gsmlp:detaileddescription_href>
#       <epos-gsmlp:geophysicallogs>COSC-2 operational data sets</epos-gsmlp:geophysicallogs>
#       <epos-gsmlp:geophysicallogs_href>https://doi.org/10.5880/ICDP.5054.003</epos-gsmlp:geophysicallogs_href>
#       <epos-gsmlp:geologicaldescription>lithology</epos-gsmlp:geologicaldescription>
#       <epos-gsmlp:geologicaldescription_href>https://www.geodata.rocks/GeologyLogs/SD-5054_2_A_full</epos-gsmlp:geologicaldescription_href>
#       <epos-gsmlp:groundwaterlevel>inapplicable</epos-gsmlp:groundwaterlevel>
#       <epos-gsmlp:groundwaterlevel_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:groundwaterlevel_href>
#       <epos-gsmlp:groundwaterchemistry>inapplicable</epos-gsmlp:groundwaterchemistry>
#       <epos-gsmlp:groundwaterchemistry_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:groundwaterchemistry_href>
#       <epos-gsmlp:rockgeochemistry>inapplicable</epos-gsmlp:rockgeochemistry>
#       <epos-gsmlp:rockgeochemistry_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:rockgeochemistry_href>
#       <epos-gsmlp:poregaschemistry>inapplicable</epos-gsmlp:poregaschemistry>
#       <epos-gsmlp:poregaschemistry_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:poregaschemistry_href>
#       <epos-gsmlp:geotechnicalinfo>inapplicable</epos-gsmlp:geotechnicalinfo>
#       <epos-gsmlp:geotechnicalinfo_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:geotechnicalinfo_href>
#       <epos-gsmlp:location_wgs84>
#         <gml:Point srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" srsDimension="2" gml:id="BoreholeView_PointStacker.fid-2c3a8deb_197747fc4f7_50c5.location_wgs84">
#           <gml:pos>13.52648 63.31245</gml:pos>
#         </gml:Point>
#       </epos-gsmlp:location_wgs84>
#       <epos-gsmlp:positionalaccuracy>0.1</epos-gsmlp:positionalaccuracy>
#       <epos-gsmlp:lastupdated>2025-01-23T23:00:00Z</epos-gsmlp:lastupdated>
#       <epos-gsmlp:provider>6</epos-gsmlp:provider>
#     </epos-gsmlp:BoreholeView_PointStacker>
#   </wfs:member>
#   <wfs:member>
#     <epos-gsmlp:BoreholeView_PointStacker gml:id="BoreholeView_PointStacker.fid-2c3a8deb_197747fc4f7_50c6">
#       <gml:name>Koyna, KFD1</gml:name>
#       <epos-gsmlp:boreholeid>SD-5058_1_A</epos-gsmlp:boreholeid>
#       <epos-gsmlp:gmlidentifier>https://www.geodata.rocks/BoreholeView/SD-5058_1_A</epos-gsmlp:gmlidentifier>
#       <epos-gsmlp:gsmlpidentifier>https://www.geodata.rocks/Boreholes/SD-5058_1_A</epos-gsmlp:gsmlpidentifier>
#       <epos-gsmlp:purpose_href>https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch</epos-gsmlp:purpose_href>
#       <epos-gsmlp:purpose>multidisciplinary scientific research</epos-gsmlp:purpose>
#       <epos-gsmlp:boreholeuse>multidisciplinary scientific research</epos-gsmlp:boreholeuse>
#       <epos-gsmlp:boreholeuse_href>https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch</epos-gsmlp:boreholeuse_href>
#       <epos-gsmlp:status_href>https://data.geoscience.earth/ncl/BoreholeStatus/drillingCompleted</epos-gsmlp:status_href>
#       <epos-gsmlp:status>drilling completed</epos-gsmlp:status>
#       <epos-gsmlp:drillingmethod_href>https://data.geoscience.earth/ncl/DrillingMethod/hydraulicRotaryDrilling</epos-gsmlp:drillingmethod_href>
#       <epos-gsmlp:drillingmethod>hydraulic rotary drilling</epos-gsmlp:drillingmethod>
#       <epos-gsmlp:startpoint_href>https://data.geoscience.earth/ncl/StartPoint/naturalLandSurface</epos-gsmlp:startpoint_href>
#       <epos-gsmlp:startpoint>natural land surface</epos-gsmlp:startpoint>
#       <epos-gsmlp:inclinationtype_href>https://data.geoscience.earth/ncl/BoreholeInclinationType/vertical</epos-gsmlp:inclinationtype_href>
#       <epos-gsmlp:inclinationtype>vertical</epos-gsmlp:inclinationtype>
#       <epos-gsmlp:boreholematerialcustodian>National Centre for Polar and Ocean Research, India</epos-gsmlp:boreholematerialcustodian>
#       <epos-gsmlp:boreholelength_m>3012.0</epos-gsmlp:boreholelength_m>
#       <epos-gsmlp:elevation_m>902.0</epos-gsmlp:elevation_m>
#       <epos-gsmlp:elevation_srs>5613</epos-gsmlp:elevation_srs>
#       <epos-gsmlp:source>International Continental Scientific Drilling Program (ICDP), direct communication</epos-gsmlp:source>
#       <epos-gsmlp:metadata_uri>https://epos.brgm-rec.fr/geonetwork/srv/eng/catalog.search#/metadata/e435e013-944d-45e3-b2b7-a009889300d2</epos-gsmlp:metadata_uri>
#       <epos-gsmlp:cored>true</epos-gsmlp:cored>
#       <epos-gsmlp:accesstophysicaldrillcore>true</epos-gsmlp:accesstophysicaldrillcore>
#       <epos-gsmlp:detaileddescription>Borehole SD-5058_1_A</epos-gsmlp:detaileddescription>
#       <epos-gsmlp:detaileddescription_href>https://www.geodata.rocks/Boreholes/SD-5058_1_A</epos-gsmlp:detaileddescription_href>
#       <epos-gsmlp:geophysicallogs>unkown</epos-gsmlp:geophysicallogs>
#       <epos-gsmlp:geophysicallogs_href>http://www.opengis.net/def/nil/OGC/0/unkown</epos-gsmlp:geophysicallogs_href>
#       <epos-gsmlp:geologicaldescription/>
#       <epos-gsmlp:geologicaldescription_href>http://www.opengis.net/def/nil/OGC/0/</epos-gsmlp:geologicaldescription_href>
#       <epos-gsmlp:groundwaterlevel>inapplicable</epos-gsmlp:groundwaterlevel>
#       <epos-gsmlp:groundwaterlevel_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:groundwaterlevel_href>
#       <epos-gsmlp:groundwaterchemistry>inapplicable</epos-gsmlp:groundwaterchemistry>
#       <epos-gsmlp:groundwaterchemistry_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:groundwaterchemistry_href>
#       <epos-gsmlp:rockgeochemistry>missing</epos-gsmlp:rockgeochemistry>
#       <epos-gsmlp:rockgeochemistry_href>http://www.opengis.net/def/nil/OGC/0/missing</epos-gsmlp:rockgeochemistry_href>
#       <epos-gsmlp:poregaschemistry>missing</epos-gsmlp:poregaschemistry>
#       <epos-gsmlp:poregaschemistry_href>http://www.opengis.net/def/nil/OGC/0/missing</epos-gsmlp:poregaschemistry_href>
#       <epos-gsmlp:geotechnicalinfo>inapplicable</epos-gsmlp:geotechnicalinfo>
#       <epos-gsmlp:geotechnicalinfo_href>http://www.opengis.net/def/nil/OGC/0/inapplicable</epos-gsmlp:geotechnicalinfo_href>
#       <epos-gsmlp:location_wgs84>
#         <gml:Point srsName="http://www.opengis.net/gml/srs/epsg.xml#4326" srsDimension="2" gml:id="BoreholeView_PointStacker.fid-2c3a8deb_197747fc4f7_50c6.location_wgs84">
#           <gml:pos>73.733 17.283</gml:pos>
#         </gml:Point>
#       </epos-gsmlp:location_wgs84>
#       <epos-gsmlp:lastupdated>2025-01-23T23:00:00Z</epos-gsmlp:lastupdated>
#       <epos-gsmlp:provider>6</epos-gsmlp:provider>
#     </epos-gsmlp:BoreholeView_PointStacker>
#   </wfs:member>
# </wfs:FeatureCollection>

# %% [markdown]
# <span style="font-size:1.25em;">Interacting with services and data</span><br>
# <span style="color:green; font-size:2em;">Open Geospatial Consortium (OGC) Web Services (OWS)</span>

# %% [markdown]
# <span style="font-size:1.4em;">Now we want to know in what geological units the boreholes are located.</span>

# %% [markdown]
# &emsp;<span style="font-size:1.2em;">&rarr; Extract relevant information from the borehole XML and save it to a dictionary for later use.</span>
#
# _Geological Feature dataset (OneGeology Europe):_
# * Geological Feature View: Web Map Service (WMS) for viewing
# * Geological Feature Download: Web Feature Service (WFS) for data access
#
# &emsp;<span style="font-size:1.2em;">&rarr; Query the Geological Feature layer with the positions of the boreholes.</span>

# %%
#Extract relevant information from the borehole XML and save it to a dictionary for later use.

# create the dictionary
boreholes = {}

# function to convert lonlat (GML pos) to a GML point feature
# regular expressions are needed
import re

def gmlpointfromlonlat(coordin):
    lonlat = re.match(r"(^\S+) (\S+$)", coordin)
    coordtrans = 'POINT(' + lonlat[2] + ' ' + lonlat[1] + ')'
    return(coordtrans)

# iter over the returned features and extract information
for feature in xml.findall(".//{http://www.opengis.net/wfs/2.0}member"):
    name = feature.find(".//{http://www.opengis.net/gml/3.2}name").text
    depth = feature.find(".//{https://data.geoscience.earth/def/epos-geosciml-lite}boreholelength_m").text
    linked_service = feature.find(".//{https://data.geoscience.earth/def/epos-geosciml-lite}gsmlpidentifier").text
    details = feature.find(".//{https://data.geoscience.earth/def/epos-geosciml-lite}detaileddescription_href").text
    location = feature.find(".//{http://www.opengis.net/gml/3.2}pos").text
    boreholes[name] = {}
    boreholes[name]['depth_m'] = depth
    boreholes[name]['linked_service'] = linked_service
    boreholes[name]['details'] = details
    boreholes[name]['GML_location'] = gmlpointfromlonlat(location)

pp(boreholes)
# Out:
# {
#     'COSC-1 A': {
#         'GML_location': 'POINT(63.40163 13.20292)',
#         'depth_m': '2495.8',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5054_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5054_1_A',
#     },
#     'COSC-2 A': {
#         'GML_location': 'POINT(63.31245 13.52648)',
#         'depth_m': '2276.05',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5054_2_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5054_2_A',
#     },
#     'Chesapeake, CBIS Eyreville-1 Corehole 63G69 (A)': {
#         'GML_location': 'POINT(37.3217 -75.9757)',
#         'depth_m': '2142.7',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5001_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5001_1_A',
#     },
#     'Donghai, CCSD-MH-2K': {
#         'GML_location': 'POINT(34.41 118.67)',
#         'depth_m': '3525.18',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5004_4_D',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5004_4_D',
#     },
#     'Donghai, CCSD-PH': {
#         'GML_location': 'POINT(34.41 118.67)',
#         'depth_m': '2039.54',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5004_4_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5004_4_A',
#     },
#     'Hawaii, HSDP-2a': {
#         'GML_location': 'POINT(19.74 -155.05)',
#         'depth_m': '3099.67',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5027_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5027_1_A',
#     },
#     'Iceland, IDDP-1-A, RN-17': {
#         'GML_location': 'POINT(65.71587 -16.76452)',
#         'depth_m': '2100.0',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5029_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5029_1_A',
#     },
#     'Kola SG-3': {
#         'GML_location': 'POINT(69.17 29.28)',
#         'depth_m': '12261.0',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5016_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5016_1_A',
#     },
#     'Koyna, KFD1': {
#         'GML_location': 'POINT(17.283 73.733)',
#         'depth_m': '3012.0',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5058_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5058_1_A',
#     },
#     'Outokumpu': {
#         'GML_location': 'POINT(62.71781 29.06199)',
#         'depth_m': '2516.0',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5015_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5015_1_A',
#     },
#     'SAFOD-MH-ST1': {
#         'GML_location': 'POINT(35.97417 -120.55185)',
#         'depth_m': '2994.81',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5025_1_C',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5025_1_C',
#     },
#     'SAFOD-PH': {
#         'GML_location': 'POINT(35.97426 -120.55211)',
#         'depth_m': '2154.94',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5025_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5025_1_A',
#     },
#     'Songliao 1A': {
#         'GML_location': 'POINT(46.2408 125.36307)',
#         'depth_m': '4192.0',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5012_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5012_1_A',
#     },
# }

# %% [markdown]
# &emsp;<span style="font-size:1.2em;">&rarr; In these examples, the linked services provide the detailed borehole information. For other boreholes, it might be different, e.g. linked services do not exist, but detailed information is available in a linked report.</span>

# %% [markdown]
# <span style="font-size:1.4em;">Sidestep: Accessing linked services.</span>

# %% [markdown]
# &emsp;<span style="font-size:1.2em;">&rarr; Linked "eposb" borehole service, access via "linked_service" (gsmlp:identifier in service response).</span>

# %%
for key, value in boreholes.items():
    for subkey, subvalue in value.items():
        if subkey == 'details':
            content = requests.get(subvalue)
            print(dom.parseString(content.content).toprettyxml())
# Out:
# <?xml version="1.0" ?>
# <wfs:FeatureCollection xmlns:wfs="http://www.opengis.net/wfs/2.0" xmlns:xs="http://www.w3.org/2001/XMLSchema" xmlns:gwml2="http://www.opengis.net/gwml-main/2.2" xmlns:swe="http://www.opengis.net/swe/2.0" xmlns:sams="http://www.opengis.net/samplingSpatial/2.0" xmlns:gsmlp="http://schemas.opengis.net/gsml/4.1" xmlns:gml="http://www.opengis.net/gml/3.2" xmlns:gwml2wc="http://www.opengis.net/gwml-wellconstruction/2.2" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:eposb="https://data.geoscience.earth/def/eposb" xmlns:gco="http://www.isotc211.org/2005/gco" xmlns:gwml2w="http://www.opengis.net/gwml-well/2.2" xmlns:om="http://www.opengis.net/om/2.0" xmlns:sam="http://www.opengis.net/sampling/2.0" xmlns:gmd="http://www.isotc211.org/2005/gmd" xmlns:xlink="http://www.w3.org/1999/xlink" numberMatched="0" numberReturned="1" timeStamp="2025-06-16T10:43:29.222Z" xsi:schemaLocation="http://www.opengis.net/wfs/2.0 http://schemas.opengis.net/wfs/2.0/wfs.xsd https://data.geoscience.earth/def/eposb https://data.geoscience.earth/def/eposb.xsd http://www.opengis.net/gml/3.2 http://schemas.opengis.net/gml/3.2.1/gml.xsd">
# 	<wfs:member>
# 		<eposb:Borehole gml:id="SD-5001_1_A">
# 			<gml:descriptionReference xlink:href="https://igsn.org/inapplicable" xlink:title="IGSN registry entry"/>
# 			<gml:identifier codeSpace="https://tools.ietf.org/html/rfc3629">https://www.geodata.rocks/Boreholes/SD-5001_1_A</gml:identifier>
# 			<sam:sampledFeature xlink:href="https://sweet.jpl.nasa.gov/2.3/realmEarthReference.owl#EarthLithosphere" xlink:title="Lithosphere"/>
# 			<sam:relatedSamplingFeature>
# 				<sam:SamplingFeatureComplex>
# 					<sam:role xlink:href="https://data.geoscience.earth/ncl/RelatedSamplingFeatureRole/boreholeSegment" xlink:title="borehole segment"/>
# 					<sam:relatedSamplingFeature xlink:href="https://www.geodata.rocks/Segments/SD-5001_1_A-1" xlink:title="SD-5001_1_A-1_0.00-2142.70"/>
# 				</sam:SamplingFeatureComplex>
# 			</sam:relatedSamplingFeature>
# 			<sams:shape>
# 				<gml:LineString gml:id="SD-5001_1_A-shape" srsDimension="3" srsName="http://www.opengis.net/gml/srs/epsg.xml#4979">
# 					<gml:posList>-75.9757 37.3217 3 -75.9757 37.3217 -2139.7</gml:posList>
# 				</gml:LineString>
# 			</sams:shape>
# 			<eposb:boreholeUse>
# 				<eposb:BoreholeUse>
# 					<eposb:use xlink:href="https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch" xlink:title="multidisciplinary scientific research"/>
# 					<eposb:usePeriod>
# 						<gml:TimePeriod>
# 							<gml:begin>
# 								<gml:TimeInstant>
# 									<gml:timePosition>2005-09-15Z</gml:timePosition>
# 								</gml:TimeInstant>
# 							</gml:begin>
# 							<gml:end>
# 								<gml:TimeInstant>
# 									<gml:timePosition indeterminatePosition="unknown"/>
# 								</gml:TimeInstant>
# 							</gml:end>
# 						</gml:TimePeriod>
# 					</eposb:usePeriod>
# 					<eposb:useStatus xlink:href="http://www.opengis.net/def/nil/ogc/0/unknown" xlink:title="unknown"/>
# 				</eposb:BoreholeUse>
# 			</eposb:boreholeUse>
# 			<eposb:custodian>
# 				<eposb:Custodian>
# 					<eposb:custodian>
# 						<gmd:CI_ResponsibleParty id="USGS-NC-0.041241862060043544">
# 							<gmd:organisationName>
# 								<gco:CharacterString>USGS National Center</gco:CharacterString>
# 							</gmd:organisationName>
# 							<gmd:contactInfo>
# 								<gmd:CI_Contact id="USGS-NC-0.34179828019116887">
# 									<gmd:phone>
# 										<gmd:CI_Telephone id="USGS-NC-PH-0.7066851405165852">
# 											<gmd:voice>
# 												<gco:CharacterString>+17036485953</gco:CharacterString>
# 											</gmd:voice>
# 											<gmd:facsimile>
# 												<gco:CharacterString>+</gco:CharacterString>
# 											</gmd:facsimile>
# 										</gmd:CI_Telephone>
# 									</gmd:phone>
# 									<gmd:address>
# 										<gmd:CI_Address id="USGS-NC-ADR-0.1508892474706096">
# 											<gmd:deliveryPoint>
# 												<gco:CharacterString>12201 Sunrise Valley Drive</gco:CharacterString>
# 											</gmd:deliveryPoint>
# 											<gmd:city>
# 												<gco:CharacterString>Reston</gco:CharacterString>
# 											</gmd:city>
# 											<gmd:administrativeArea>
# 												<gco:CharacterString>Virginia</gco:CharacterString>
# 											</gmd:administrativeArea>
# 											<gmd:postalCode>
# 												<gco:CharacterString>VA 20192</gco:CharacterString>
# 											</gmd:postalCode>
# 											<gmd:country>
# 												<gco:CharacterString>USA</gco:CharacterString>
# 											</gmd:country>
# 										</gmd:CI_Address>
# 									</gmd:address>
# 									<gmd:onlineResource>
# 										<gmd:CI_OnlineResource id="USGS-NC-OR-0.2540106381268894">
# 											<gmd:linkage>
# 												<gmd:URL>https://www.usgs.gov/connect/headquarters</gmd:URL>
# 											</gmd:linkage>
# 										</gmd:CI_OnlineResource>
# 									</gmd:onlineResource>
# 								</gmd:CI_Contact>
# 							</gmd:contactInfo>
# 							<gmd:role>
# 								<gmd:CI_RoleCode codeList="https://github.com/ISO-TC211/GOM/raw/master/isotc211_GOM_harmonizedOntology/19115/2006/iso19115CitationAndResponsiblePartyInformation.rdf" codeListValue="point Of Contact"/>
# 							</gmd:role>
# 						</gmd:CI_ResponsibleParty>
# 					</eposb:custodian>
# 					<eposb:custodianPeriod>
# 						<gml:TimePeriod>
# 							<gml:begin>
# 								<gml:TimeInstant>
# 									<gml:timePosition>2005-10-11Z</gml:timePosition>
# 								</gml:TimeInstant>
# 							</gml:begin>
# 							<gml:end>
# 								<gml:TimeInstant>
# 									<gml:timePosition indeterminatePosition="unknown"/>
# 								</gml:TimeInstant>
# 							</gml:end>
# 						</gml:TimePeriod>
# 					</eposb:custodianPeriod>
# 				</eposb:Custodian>
# 			</eposb:custodian>
# 			<eposb:legalAccessLevel>
# 				<gmd:MD_LegalConstraints>
# 					<gmd:accessConstraints>
# 						<gmd:MD_RestrictionCode codeList="http://registry.it.csiro.au/def/isotc211/MD_RestrictionCode/licenceUnrestricted" codeListValue="http://registry.it.csiro.au/def/isotc211/MD_RestrictionCode/licenceUnrestricted"/>
# 					</gmd:accessConstraints>
# 				</gmd:MD_LegalConstraints>
# 			</eposb:legalAccessLevel>
# 			<eposb:length uom="http://qudt.org/vocab/unit/M">2142.7</eposb:length>
# 			<eposb:operator>
# 				<eposb:Operator>
# 					<eposb:operator>
# 						<gmd:CI_ResponsibleParty id="DOSECC-0.3983092679320982">
# 							<gmd:organisationName>
# 								<gco:CharacterString>Consortium for Drilling, Observation and Sampling of the Earth's Continental Crust, now DOSECC Exploration Services, LLC</gco:CharacterString>
# 							</gmd:organisationName>
# 							<gmd:contactInfo>
# 								<gmd:CI_Contact id="DOSECC-0.7999784082362478">
# 									<gmd:phone>
# 										<gmd:CI_Telephone id="DOSECC-PH-0.23577256329524177">
# 											<gmd:voice>
# 												<gco:CharacterString>+18015832150</gco:CharacterString>
# 											</gmd:voice>
# 											<gmd:facsimile>
# 												<gco:CharacterString>+</gco:CharacterString>
# 											</gmd:facsimile>
# 										</gmd:CI_Telephone>
# 									</gmd:phone>
# 									<gmd:address>
# 										<gmd:CI_Address id="DOSECC-ADR-0.6961363466193528">
# 											<gmd:deliveryPoint>
# 												<gco:CharacterString>2075-B S. PIONEER RD.</gco:CharacterString>
# 											</gmd:deliveryPoint>
# 											<gmd:city>
# 												<gco:CharacterString>Salt Lake City</gco:CharacterString>
# 											</gmd:city>
# 											<gmd:administrativeArea>
# 												<gco:CharacterString>Utah</gco:CharacterString>
# 											</gmd:administrativeArea>
# 											<gmd:postalCode>
# 												<gco:CharacterString>UT 84104</gco:CharacterString>
# 											</gmd:postalCode>
# 											<gmd:country>
# 												<gco:CharacterString>USA</gco:CharacterString>
# 											</gmd:country>
# 										</gmd:CI_Address>
# 									</gmd:address>
# 									<gmd:onlineResource>
# 										<gmd:CI_OnlineResource id="DOSECC-OR-0.3457844377901098">
# 											<gmd:linkage>
# 												<gmd:URL>https://dosecc.com/</gmd:URL>
# 											</gmd:linkage>
# 										</gmd:CI_OnlineResource>
# 									</gmd:onlineResource>
# 								</gmd:CI_Contact>
# 							</gmd:contactInfo>
# 							<gmd:role>
# 								<gmd:CI_RoleCode codeList="https://github.com/ISO-TC211/GOM/raw/master/isotc211_GOM_harmonizedOntology/19115/2006/iso19115CitationAndResponsiblePartyInformation.rdf" codeListValue="point Of Contact"/>
# 							</gmd:role>
# 						</gmd:CI_ResponsibleParty>
# 					</eposb:operator>
# 					<eposb:operatorPeriod>
# 						<gml:TimePeriod>
# 							<gml:begin>
# 								<gml:TimeInstant>
# 									<gml:timePosition>2005-09-15Z</gml:timePosition>
# 								</gml:TimeInstant>
# 							</gml:begin>
# 							<gml:end>
# 								<gml:TimeInstant>
# 									<gml:timePosition>2005-10-11Z</gml:timePosition>
# 								</gml:TimeInstant>
# 							</gml:end>
# 						</gml:TimePeriod>
# 					</eposb:operatorPeriod>
# 				</eposb:Operator>
# 			</eposb:operator>
# 			<eposb:purpose>
# 				<eposb:Purpose>
# 					<eposb:purpose xlink:href="https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch" xlink:title="multidisciplinary scientific research"/>
# 					<eposb:purposePeriod>
# 						<gml:TimePeriod>
# 							<gml:begin>
# 								<gml:TimeInstant>
# 									<gml:timePosition>2005-09-15Z</gml:timePosition>
# 								</gml:TimeInstant>
# 							</gml:begin>
# 							<gml:end>
# 								<gml:TimeInstant>
# 									<gml:timePosition indeterminatePosition="unknown"/>
# 								</gml:TimeInstant>
# 							</gml:end>
# 						</gml:TimePeriod>
# 					</eposb:purposePeriod>
# 					<eposb:purposeStatus xlink:href="http://www.opengis.net/def/nil/ogc/0/unknown" xlink:title="unknown"/>
# 				</eposb:Purpose>
# 			</eposb:purpose>
# 			<eposb:referenceElevation>
# 				<eposb:Elevation>
# 					<eposb:elevation axisLabels="elevation above sea level" srsDimension="3" srsName="https://epsg.io/4979" uomLabels="m">3.0</eposb:elevation>
# 					<eposb:elevationAccuracy>
# 						<gmd:DQ_AbsoluteExternalPositionalAccuracy id="SD-5001_1_A_collar-PosAcc">
# 							<gmd:measureDescription>
# 								<gco:CharacterString>The correct value is not known to, or not computable by, the sender of this data. However, the correct value probably exists.</gco:CharacterString>
# 							</gmd:measureDescription>
# 							<gmd:result>
# 								<gmd:DQ_ConformanceResult>
# 									<gmd:specification xlink:href="http://www.opengis.net/def/nil/OGC/0/unknown" xlink:title="unknown"/>
# 									<gmd:explanation>
# 										<gco:CharacterString>Evaluation of accuracy not implemented or not known.</gco:CharacterString>
# 									</gmd:explanation>
# 									<gmd:pass>
# 										<gco:Boolean>true</gco:Boolean>
# 									</gmd:pass>
# 								</gmd:DQ_ConformanceResult>
# 							</gmd:result>
# 						</gmd:DQ_AbsoluteExternalPositionalAccuracy>
# 					</eposb:elevationAccuracy>
# 					<eposb:elevationMeasurementMethod xlink:href="http://www.opengis.net/def/nil/OGC/0/unknown" xlink:title="unknown"/>
# 					<eposb:elevationType xlink:href="https://data.geoscience.earth/ncl/ElevationType/naturalGroundSurface" xlink:title="natural ground surface"/>
# 				</eposb:Elevation>
# 			</eposb:referenceElevation>
# 			<eposb:startPoint xlink:href="sea floor" xlink:title="https://data.geoscience.earth/ncl/StartPoint/seaFloor"/>
# 			<eposb:status xlink:href="https://data.geoscience.earth/ncl/BoreholeStatus/abandoned" xlink:title="abandoned"/>
# 			<eposb:locationMeasurementMethod xlink:href="http://www.opengis.net/def/nil/OGC/0/unknown" xlink:title="unknown"/>
# 			<eposb:locatedOnAdminUnit xlink:href="http://www.opengis.net/def/nil/ogc/0/unknown" xlink:title="unknown"/>
# 			<eposb:bholeHeadworks>
# 				<gwml2wc:BoreCollar gml:id="SD-5001_1_A_collar">
# 					<gml:name>5001_1_A_collar</gml:name>
# 					<gwml2wc:collarElevation axisLabels="elevation-depth" srsDimension="1" srsName="5613" uomLabels="m">3.000</gwml2wc:collarElevation>
# 					<gwml2wc:collarElevationType xlink:href="http://resource.gwml.org/def/collarElevationType/originElevation"/>
# 					<gwml2wc:collarHeadworkType xlink:href="http://www.opengis.net/def/nil/OGC/0/unknown" xlink:title="unknown"/>
# 					<gwml2wc:collarLocation>
# 						<gml:Point gml:id="SD-5001_1_A-collarlocation" srsDimension="3" srsName="http://www.opengis.net/gml/srs/epsg.xml#4979">
# 							<gml:pos>-75.9757 37.3217 3</gml:pos>
# 						</gml:Point>
# 					</gwml2wc:collarLocation>
# 					<gwml2wc:collarSeal>
# 						<gwml2wc:SealingComponent>
# 							<gwml2wc:sealingMaterial xlink:href="http://www.opengis.net/def/nil/ogc/0/missing" xlink:title="missing"/>
# 							<gwml2wc:sealingType xlink:href="http://www.opengis.net/def/nil/ogc/0/missing" xlink:title="missing"/>
# 						</gwml2wc:SealingComponent>
# 					</gwml2wc:collarSeal>
# 				</gwml2wc:BoreCollar>
# 			</eposb:bholeHeadworks>
# 			<eposb:boreholeGeology xlink:href="http://www.opengis.net/def/nil/OGC/0/missing" xlink:title="missing"/>
# 		</eposb:Borehole>
# 	</wfs:member>
# </wfs:FeatureCollection>
#
# <?xml version="1.0" ?>
# <wfs:FeatureCollection xmlns:wfs="http://www.opengis.net/wfs/2.0" xmlns:xs="http://www.w3.org/2001/XMLSchema" xmlns:gwml2="http://www.opengis.net/gwml-main/2.2" xmlns:swe="http://www.opengis.net/swe/2.0" xmlns:sams="http://www.opengis.net/samplingSpatial/2.0" xmlns:gsmlp="http://schemas.opengis.net/gsml/4.1" xmlns:gml="http://www.opengis.net/gml/3.2" xmlns:gwml2wc="http://www.opengis.net/gwml-wellconstruction/2.2" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:eposb="https://data.geoscience.earth/def/eposb" xmlns:gco="http://www.isotc211.org/2005/gco" xmlns:gwml2w="http://www.opengis.net/gwml-well/2.2" xmlns:om="http://www.opengis.net/om/2.0" xmlns:sam="http://www.opengis.net/sampling/2.0" xmlns:gmd="http://www.isotc211.org/2005/gmd" xmlns:xlink="http://www.w3.org/1999/xlink" numberMatched="0" numberReturned="1" timeStamp="2025-06-16T10:43:33.473Z" xsi:schemaLocation="http://www.opengis.net/wfs/2.0 http://schemas.opengis.net/wfs/2.0/wfs.xsd https://data.geoscience.earth/def/eposb https://data.geoscience.earth/def/eposb.xsd http://www.opengis.net/gml/3.2 http://schemas.opengis.net/gml/3.2.1/gml.xsd">
# 	<wfs:member>
# 		<eposb:Borehole gml:id="SD-5004_4_A">
# 			<gml:descriptionReference xlink:href="https://igsn.org/inapplicable" xlink:title="IGSN registry entry"/>
# 			<gml:identifier codeSpace="https://tools.ietf.org/html/rfc3629">https://www.geodata.rocks/Boreholes/SD-5004_4_A</gml:identifier>
# 			<sam:sampledFeature xlink:href="https://sweet.jpl.nasa.gov/2.3/realmEarthReference.owl#EarthLithosphere" xlink:title="Lithosphere"/>
# 			<sam:relatedSamplingFeature>
# 				<sam:SamplingFeatureComplex>
# 					<sam:role xlink:href="https://data.geoscience.earth/ncl/RelatedSamplingFeatureRole/boreholeSegment" xlink:title="borehole segment"/>
# 					<sam:relatedSamplingFeature xlink:href="https://www.geodata.rocks/Segments/SD-5004_4_A-1" xlink:title="SD-5004_4_A-1_0.00-2039.54"/>
# 				</sam:SamplingFeatureComplex>
# 			</sam:relatedSamplingFeature>
# 			<sams:shape>
# 				<gml:LineString gml:id="SD-5004_4_A-shape" srsDimension="3" srsName="http://www.opengis.net/gml/srs/epsg.xml#4979">
# 					<gml:posList>118.67 34.41 28.5 118.67 34.41 -2011.04</gml:posList>
# 				</gml:LineString>
# 			</sams:shape>
# 			<eposb:boreholeUse>
# 				<eposb:BoreholeUse>
# 					<eposb:use xlink:href="https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch" xlink:title="multidisciplinary scientific research"/>
# 					<eposb:usePeriod>
# 						<gml:TimePeriod>
# 							<gml:begin>
# 								<gml:TimeInstant>
# 									<gml:timePosition>2001-06-25Z</gml:timePosition>
# 								</gml:TimeInstant>
# 							</gml:begin>
# 							<gml:end>
# 								<gml:TimeInstant>
# 									<gml:timePosition indeterminatePosition="unknown"/>
# 								</gml:TimeInstant>
# 							</gml:end>
# 						</gml:TimePeriod>
# 					</eposb:usePeriod>
# 					<eposb:useStatus xlink:href="http://www.opengis.net/def/nil/ogc/0/unknown" xlink:title="unknown"/>
# 				</eposb:BoreholeUse>
# 			</eposb:boreholeUse>
# 			<eposb:custodian>
# 				<eposb:Custodian>
# 					<eposb:custodian>
# 						<gmd:CI_ResponsibleParty id="CGS-0.30997093537672726">
# 							<gmd:organisationName>
# 								<gco:CharacterString>China Geological Survey</gco:CharacterString>
# 							</gmd:organisationName>
# 							<gmd:contactInfo>
# 								<gmd:CI_Contact id="CGS-0.3214023822148617">
# 									<gmd:phone>
# 										<gmd:CI_Telephone id="CGS-PH-0.05591540717438004">
# 											<gmd:voice>
# 												<gco:CharacterString>+861058584620</gco:CharacterString>
# 											</gmd:voice>
# 											<gmd:facsimile>
# 												<gco:CharacterString>+861058584621</gco:CharacterString>
# 											</gmd:facsimile>
# 										</gmd:CI_Telephone>
# 									</gmd:phone>
# 									<gmd:address>
# 										<gmd:CI_Address id="CGS-ADR-0.023750809440961862">
# 											<gmd:deliveryPoint>
# 												<gco:CharacterString>No. 45 Fuwai Street, Xicheng District</gco:CharacterString>
# 											</gmd:deliveryPoint>
# 											<gmd:city>
# 												<gco:CharacterString>Beijing</gco:CharacterString>
# 											</gmd:city>
# 											<gmd:postalCode>
# 												<gco:CharacterString>100037</gco:CharacterString>
# 											</gmd:postalCode>
# 											<gmd:country>
# 												<gco:CharacterString>China</gco:CharacterString>
# 											</gmd:country>
# 											<gmd:electronicMailAddress>
# 												<gco:CharacterString>55282999@qq.com</gco:CharacterString>
# 											</gmd:electronicMailAddress>
# 										</gmd:CI_Address>
# 									</gmd:address>
# 									<gmd:onlineResource>
# 										<gmd:CI_OnlineResource id="CGS-OR-0.6183256849993748">
# 											<gmd:linkage>
# 												<gmd:URL>https://en.cgs.gov.cn/</gmd:URL>
# 											</gmd:linkage>
# 										</gmd:CI_OnlineResource>
# 									</gmd:onlineResource>
# 								</gmd:CI_Contact>
# 							</gmd:contactInfo>
# 							<gmd:role>
# 								<gmd:CI_RoleCode codeList="https://github.com/ISO-TC211/GOM/raw/master/isotc211_GOM_harmonizedOntology/19115/2006/iso19115CitationAndResponsiblePartyInformation.rdf" codeListValue="point Of Contact"/>
# 							</gmd:role>
# 						</gmd:CI_ResponsibleParty>
# 					</eposb:custodian>
# 					<eposb:custodianPeriod>
# 						<gml:TimePeriod>
# 							<gml:begin>
# 								<gml:TimeInstant>
# 									<gml:timePosition>2002-04-09Z</gml:timePosition>
# 								</gml:TimeInstant>
# 							</gml:begin>
# 							<gml:end>
# 								<gml:TimeInstant>
# 									<gml:timePosition indeterminatePosition="unknown"/>
# 								</gml:TimeInstant>
# 							</gml:end>
# 						</gml:TimePeriod>
# 					</eposb:custodianPeriod>
# 				</eposb:Custodian>
# 			</eposb:custodian>
# 			<eposb:legalAccessLevel>
# 				<gmd:MD_LegalConstraints>
# 					<gmd:accessConstraints>
# 						<gmd:MD_RestrictionCode codeList="http://registry.it.csiro.au/def/isotc211/MD_RestrictionCode/licenceUnrestricted" codeListValue="http://registry.it.csiro.au/def/isotc211/MD_RestrictionCode/licenceUnrestricted"/>
# 					</gmd:accessConstraints>
# 				</gmd:MD_LegalConstraints>
# 			</eposb:legalAccessLevel>
# 			<eposb:length uom="http://qudt.org/vocab/unit/M">2039.54</eposb:length>
# 			<eposb:operator>
# 				<eposb:Operator>
# 					<eposb:operator>
# 						<gmd:CI_ResponsibleParty id="CGS-0.6990079099678482">
# 							<gmd:organisationName>
# 								<gco:CharacterString>China Geological Survey</gco:CharacterString>
# 							</gmd:organisationName>
# 							<gmd:contactInfo>
# 								<gmd:CI_Contact id="CGS-0.8816428652136796">
# 									<gmd:phone>
# 										<gmd:CI_Telephone id="CGS-PH-0.8570120604162664">
# 											<gmd:voice>
# 												<gco:CharacterString>+861058584620</gco:CharacterString>
# 											</gmd:voice>
# 											<gmd:facsimile>
# 												<gco:CharacterString>+861058584621</gco:CharacterString>
# 											</gmd:facsimile>
# 										</gmd:CI_Telephone>
# 									</gmd:phone>
# 									<gmd:address>
# 										<gmd:CI_Address id="CGS-ADR-0.36720588994154213">
# 											<gmd:deliveryPoint>
# 												<gco:CharacterString>No. 45 Fuwai Street, Xicheng District</gco:CharacterString>
# 											</gmd:deliveryPoint>
# 											<gmd:city>
# 												<gco:CharacterString>Beijing</gco:CharacterString>
# 											</gmd:city>
# 											<gmd:postalCode>
# 												<gco:CharacterString>100037</gco:CharacterString>
# 											</gmd:postalCode>
# 											<gmd:country>
# 												<gco:CharacterString>China</gco:CharacterString>
# 											</gmd:country>
# 											<gmd:electronicMailAddress>
# 												<gco:CharacterString>55282999@qq.com</gco:CharacterString>
# 											</gmd:electronicMailAddress>
# 										</gmd:CI_Address>
# 									</gmd:address>
# 									<gmd:onlineResource>
# 										<gmd:CI_OnlineResource id="CGS-OR-0.005137753649762322">
# 											<gmd:linkage>
# 												<gmd:URL>https://en.cgs.gov.cn/</gmd:URL>
# 											</gmd:linkage>
# 										</gmd:CI_OnlineResource>
# 									</gmd:onlineResource>
# 								</gmd:CI_Contact>
# 							</gmd:contactInfo>
# 							<gmd:role>
# 								<gmd:CI_RoleCode codeList="https://github.com/ISO-TC211/GOM/raw/master/isotc211_GOM_harmonizedOntology/19115/2006/iso19115CitationAndResponsiblePartyInformation.rdf" codeListValue="point Of Contact"/>
# 							</gmd:role>
# 						</gmd:CI_ResponsibleParty>
# 					</eposb:operator>
# 					<eposb:operatorPeriod>
# 						<gml:TimePeriod>
# 							<gml:begin>
# 								<gml:TimeInstant>
# 									<gml:timePosition>2001-06-25Z</gml:timePosition>
# 								</gml:TimeInstant>
# 							</gml:begin>
# 							<gml:end>
# 								<gml:TimeInstant>
# 									<gml:timePosition>2002-04-09Z</gml:timePosition>
# 								</gml:TimeInstant>
# 							</gml:end>
# 						</gml:TimePeriod>
# 					</eposb:operatorPeriod>
# 				</eposb:Operator>
# 			</eposb:operator>
# 			<eposb:purpose>
# 				<eposb:Purpose>
# 					<eposb:purpose xlink:href="https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch" xlink:title="multidisciplinary scientific research"/>
# 					<eposb:purposePeriod>
# 						<gml:TimePeriod>
# 							<gml:begin>
# 								<gml:TimeInstant>
# 									<gml:timePosition>2001-06-25Z</gml:timePosition>
# 								</gml:TimeInstant>
# 							</gml:begin>
# 							<gml:end>
# 								<gml:TimeInstant>
# 									<gml:timePosition indeterminatePosition="unknown"/>
# 								</gml:TimeInstant>
# 							</gml:end>
# 						</gml:TimePeriod>
# 					</eposb:purposePeriod>
# 					<eposb:purposeStatus xlink:href="http://www.opengis.net/def/nil/ogc/0/unknown" xlink:title="unknown"/>
# 				</eposb:Purpose>
# 			</eposb:purpose>
# 			<eposb:referenceElevation>
# 				<eposb:Elevation>
# 					<eposb:elevation axisLabels="elevation above sea level" srsDimension="3" srsName="https://epsg.io/4979" uomLabels="m">28.5</eposb:elevation>
# 					<eposb:elevationAccuracy>
# 						<gmd:DQ_AbsoluteExternalPositionalAccuracy id="SD-5004_4_A_collar-PosAcc">
# 							<gmd:measureDescription>
# 								<gco:CharacterString>The correct value is not known to, or not computable by, the sender of this data. However, the correct value probably exists.</gco:CharacterString>
# 							</gmd:measureDescription>
# 							<gmd:result>
# 								<gmd:DQ_ConformanceResult>
# 									<gmd:specification xlink:href="http://www.opengis.net/def/nil/OGC/0/unknown" xlink:title="unknown"/>
# 									<gmd:explanation>
# 										<gco:CharacterString>Evaluation of accuracy not implemented or not known.</gco:CharacterString>
# 									</gmd:explanation>
# 									<gmd:pass>
# 										<gco:Boolean>true</gco:Boolean>
# 									</gmd:pass>
# 								</gmd:DQ_ConformanceResult>
# 							</gmd:result>
# 						</gmd:DQ_AbsoluteExternalPositionalAccuracy>
# 					</eposb:elevationAccuracy>
# 					<eposb:elevationMeasurementMethod xlink:href="http://www.opengis.net/def/nil/OGC/0/unknown" xlink:title="unknown"/>
# 					<eposb:elevationType xlink:href="https://data.geoscience.earth/ncl/ElevationType/naturalGroundSurface" xlink:title="natural ground surface"/>
# 				</eposb:Elevation>
# 			</eposb:referenceElevation>
# 			<eposb:startPoint xlink:href="natural land surface" xlink:title="https://data.geoscience.earth/ncl/StartPoint/naturalLandSurface"/>
# 			<eposb:status xlink:href="https://data.geoscience.earth/ncl/BoreholeStatus/drillingCompleted" xlink:title="drilling completed"/>
# 			<eposb:locationMeasurementMethod xlink:href="http://www.opengis.net/def/nil/OGC/0/unknown" xlink:title="unknown"/>
# 			<eposb:locatedOnAdminUnit xlink:href="http://www.opengis.net/def/nil/ogc/0/unknown" xlink:title="unknown"/>
# 			<eposb:bholeHeadworks>
# 				<gwml2wc:BoreCollar gml:id="SD-5004_4_A_collar">
# 					<gml:name>5004_4_A_collar</gml:name>
# 					<gwml2wc:collarElevation axisLabels="elevation-depth" srsDimension="1" srsName="5613" uomLabels="m">28.500</gwml2wc:collarElevation>
# 					<gwml2wc:collarElevationType xlink:href="http://resource.gwml.org/def/collarElevationType/originElevation"/>
# 					<gwml2wc:collarHeadworkType xlink:href="http://www.opengis.net/def/nil/OGC/0/unknown" xlink:title="unknown"/>
# 					<gwml2wc:collarLocation>
# 						<gml:Point gml:id="SD-5004_4_A-collarlocation" srsDimension="3" srsName="http://www.opengis.net/gml/srs/epsg.xml#4979">
# 							<gml:pos>118.67 34.41 28.5</gml:pos>
# 						</gml:Point>
# 					</gwml2wc:collarLocation>
# 					<gwml2wc:collarSeal>
# 						<gwml2wc:SealingComponent>
# 							<gwml2wc:sealingMaterial xlink:href="http://www.opengis.net/def/nil/ogc/0/missing" xlink:title="missing"/>
# 							<gwml2wc:sealingType xlink:href="http://www.opengis.net/def/nil/ogc/0/missing" xlink:title="missing"/>
# 						</gwml2wc:SealingComponent>
# 					</gwml2wc:collarSeal>
# 				</gwml2wc:BoreCollar>
# 			</eposb:bholeHeadworks>
# 			<eposb:boreholeGeology xlink:href="http://www.opengis.net/def/nil/OGC/0/missing" xlink:title="missing"/>
# 		</eposb:Borehole>
# 	</wfs:member>
# </wfs:FeatureCollection>
#
# <?xml version="1.0" ?>
# <wfs:FeatureCollection xmlns:wfs="http://www.opengis.net/wfs/2.0" xmlns:xs="http://www.w3.org/2001/XMLSchema" xmlns:gwml2="http://www.opengis.net/gwml-main/2.2" xmlns:swe="http://www.opengis.net/swe/2.0" xmlns:sams="http://www.opengis.net/samplingSpatial/2.0" xmlns:gsmlp="http://schemas.opengis.net/gsml/4.1" xmlns:gml="http://www.opengis.net/gml/3.2" xmlns:gwml2wc="http://www.opengis.net/gwml-wellconstruction/2.2" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:eposb="https://data.geoscience.earth/def/eposb" xmlns:gco="http://www.isotc211.org/2005/gco" xmlns:gwml2w="http://www.opengis.net/gwml-well/2.2" xmlns:om="http://www.opengis.net/om/2.0" xmlns:sam="http://www.opengis.net/sampling/2.0" xmlns:gmd="http://www.isotc211.org/2005/gmd" xmlns:xlink="http://www.w3.org/1999/xlink" numberMatched="0" numberReturned="1" timeStamp="2025-06-16T10:43:36.968Z" xsi:schemaLocation="http://www.opengis.net/wfs/2.0 http://schemas.opengis.net/wfs/2.0/wfs.xsd https://data.geoscience.earth/def/eposb https://data.geoscience.earth/def/eposb.xsd http://www.opengis.net/gml/3.2 http://schemas.opengis.net/gml/3.2.1/gml.xsd">
# 	<wfs:member>
# 		<eposb:Borehole gml:id="SD-5004_4_D">
# 			<gml:descriptionReference xlink:href="https://igsn.org/inapplicable" xlink:title="IGSN registry entry"/>
# 			<gml:identifier codeSpace="https://tools.ietf.org/html/rfc3629">https://www.geodata.rocks/Boreholes/SD-5004_4_D</gml:identifier>
# 			<sam:sampledFeature xlink:href="https://sweet.jpl.nasa.gov/2.3/realmEarthReference.owl#EarthLithosphere" xlink:title="Lithosphere"/>
# 			<sam:relatedSamplingFeature>
# 				<sam:SamplingFeatureComplex>
# 					<sam:role xlink:href="https://data.geoscience.earth/ncl/RelatedSamplingFeatureRole/boreholeSegment" xlink:title="borehole segment"/>
# 					<sam:relatedSamplingFeature xlink:href="https://www.geodata.rocks/Segments/SD-5004_4_D-1" xlink:title="SD-5004_4_D-1_0.00-3525.18"/>
# 				</sam:SamplingFeatureComplex>
# 			</sam:relatedSamplingFeature>
# 			<sams:shape>
# 				<gml:LineString gml:id="SD-5004_4_D-shape" srsDimension="3" srsName="http://www.opengis.net/gml/srs/epsg.xml#4979">
# 					<gml:posList>118.67 34.41 28.5 118.67 34.41 -3496.68</gml:posList>
# 				</gml:LineString>
# 			</sams:shape>
# 			<eposb:boreholeUse>
# 				<eposb:BoreholeUse>
# 					<eposb:use xlink:href="https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch" xlink:title="multidisciplinary scientific research"/>
# 					<eposb:usePeriod>
# 						<gml:TimePeriod>
# 							<gml:begin>
# 								<gml:TimeInstant>
# 									<gml:timePosition>2003-10-30Z</gml:timePosition>
# 								</gml:TimeInstant>
# 							</gml:begin>
# 							<gml:end>
# 								<gml:TimeInstant>
# 									<gml:timePosition indeterminatePosition="unknown"/>
# 								</gml:TimeInstant>
# 							</gml:end>
# 						</gml:TimePeriod>
# 					</eposb:usePeriod>
# 					<eposb:useStatus xlink:href="http://www.opengis.net/def/nil/ogc/0/unknown" xlink:title="unknown"/>
# 				</eposb:BoreholeUse>
# 			</eposb:boreholeUse>
# 			<eposb:custodian>
# 				<eposb:Custodian>
# 					<eposb:custodian>
# 						<gmd:CI_ResponsibleParty id="CGS-0.2838920808869534">
# 							<gmd:organisationName>
# 								<gco:CharacterString>China Geological Survey</gco:CharacterString>
# 							</gmd:organisationName>
# 							<gmd:contactInfo>
# 								<gmd:CI_Contact id="CGS-0.14243023853236791">
# 									<gmd:phone>
# 										<gmd:CI_Telephone id="CGS-PH-0.5876032808112565">
# 											<gmd:voice>
# 												<gco:CharacterString>+861058584620</gco:CharacterString>
# 											</gmd:voice>
# 											<gmd:facsimile>
# 												<gco:CharacterString>+861058584621</gco:CharacterString>
# 											</gmd:facsimile>
# 										</gmd:CI_Telephone>
# 									</gmd:phone>
# 									<gmd:address>
# 										<gmd:CI_Address id="CGS-ADR-0.49124645876840844">
# 											<gmd:deliveryPoint>
# 												<gco:CharacterString>No. 45 Fuwai Street, Xicheng District</gco:CharacterString>
# 											</gmd:deliveryPoint>
# 											<gmd:city>
# 												<gco:CharacterString>Beijing</gco:CharacterString>
# 											</gmd:city>
# 											<gmd:postalCode>
# 												<gco:CharacterString>100037</gco:CharacterString>
# 											</gmd:postalCode>
# 											<gmd:country>
# 												<gco:CharacterString>China</gco:CharacterString>
# 											</gmd:country>
# 											<gmd:electronicMailAddress>
# 												<gco:CharacterString>55282999@qq.com</gco:CharacterString>
# 											</gmd:electronicMailAddress>
# 										</gmd:CI_Address>
# 									</gmd:address>
# 									<gmd:onlineResource>
# 										<gmd:CI_OnlineResource id="CGS-OR-0.252356898717662">
# 											<gmd:linkage>
# 												<gmd:URL>https://en.cgs.gov.cn/</gmd:URL>
# 											</gmd:linkage>
# 										</gmd:CI_OnlineResource>
# 									</gmd:onlineResource>
# 								</gmd:CI_Contact>
# 							</gmd:contactInfo>
# 							<gmd:role>
# 								<gmd:CI_RoleCode codeList="https://github.com/ISO-TC211/GOM/raw/master/isotc211_GOM_harmonizedOntology/19115/2006/iso19115CitationAndResponsiblePartyInformation.rdf" codeListValue="point Of Contact"/>
# 							</gmd:role>
# 						</gmd:CI_ResponsibleParty>
# 					</eposb:custodian>
# 					<eposb:custodianPeriod>
# 						<gml:TimePeriod>
# 							<gml:begin>
# 								<gml:TimeInstant>
# 									<gml:timePosition>2005-08-21Z</gml:timePosition>
# 								</gml:TimeInstant>
# 							</gml:begin>
# 							<gml:end>
# 								<gml:TimeInstant>
# 									<gml:timePosition indeterminatePosition="unknown"/>
# 								</gml:TimeInstant>
# 							</gml:end>
# 						</gml:TimePeriod>
# 					</eposb:custodianPeriod>
# 				</eposb:Custodian>
# 			</eposb:custodian>
# 			<eposb:legalAccessLevel>
# 				<gmd:MD_LegalConstraints>
# 					<gmd:accessConstraints>
# 						<gmd:MD_RestrictionCode codeList="http://registry.it.csiro.au/def/isotc211/MD_RestrictionCode/licenceUnrestricted" codeListValue="http://registry.it.csiro.au/def/isotc211/MD_RestrictionCode/licenceUnrestricted"/>
# 					</gmd:accessConstraints>
# 				</gmd:MD_LegalConstraints>
# 			</eposb:legalAccessLevel>
# 			<eposb:length uom="http://qudt.org/vocab/unit/M">3525.18</eposb:length>
# 			<eposb:operator>
# 				<eposb:Operator>
# 					<eposb:operator>
# 						<gmd:CI_ResponsibleParty id="CGS-0.8871139196699558">
# 							<gmd:organisationName>
# 								<gco:CharacterString>China Geological Survey</gco:CharacterString>
# 							</gmd:organisationName>
# 							<gmd:contactInfo>
# 								<gmd:CI_Contact id="CGS-0.8216931227333707">
# 									<gmd:phone>
# 										<gmd:CI_Telephone id="CGS-PH-0.6500082721207255">
# 											<gmd:voice>
# 												<gco:CharacterString>+861058584620</gco:CharacterString>
# 											</gmd:voice>
# 											<gmd:facsimile>
# 												<gco:CharacterString>+861058584621</gco:CharacterString>
# 											</gmd:facsimile>
# 										</gmd:CI_Telephone>
# 									</gmd:phone>
# 									<gmd:address>
# 										<gmd:CI_Address id="CGS-ADR-0.29574992924927146">
# 											<gmd:deliveryPoint>
# 												<gco:CharacterString>No. 45 Fuwai Street, Xicheng District</gco:CharacterString>
# 											</gmd:deliveryPoint>
# 											<gmd:city>
# 												<gco:CharacterString>Beijing</gco:CharacterString>
# 											</gmd:city>
# 											<gmd:postalCode>
# 												<gco:CharacterString>100037</gco:CharacterString>
# 											</gmd:postalCode>
# 											<gmd:country>
# 												<gco:CharacterString>China</gco:CharacterString>
# 											</gmd:country>
# 											<gmd:electronicMailAddress>
# 												<gco:CharacterString>55282999@qq.com</gco:CharacterString>
# 											</gmd:electronicMailAddress>
# 										</gmd:CI_Address>
# 									</gmd:address>
# 									<gmd:onlineResource>
# 										<gmd:CI_OnlineResource id="CGS-OR-0.6051804783094019">
# 											<gmd:linkage>
# 												<gmd:URL>https://en.cgs.gov.cn/</gmd:URL>
# 											</gmd:linkage>
# 										</gmd:CI_OnlineResource>
# 									</gmd:onlineResource>
# 								</gmd:CI_Contact>
# 							</gmd:contactInfo>
# 							<gmd:role>
# 								<gmd:CI_RoleCode codeList="https://github.com/ISO-TC211/GOM/raw/master/isotc211_GOM_harmonizedOntology/19115/2006/iso19115CitationAndResponsiblePartyInformation.rdf" codeListValue="point Of Contact"/>
# 							</gmd:role>
# 						</gmd:CI_ResponsibleParty>
# 					</eposb:operator>
# 					<eposb:operatorPeriod>
# 						<gml:TimePeriod>
# 							<gml:begin>
# 								<gml:TimeInstant>
# 									<gml:timePosition>2003-10-30Z</gml:timePosition>
# 								</gml:TimeInstant>
# 							</gml:begin>
# 							<gml:end>
# 								<gml:TimeInstant>
# 									<gml:timePosition>2005-08-21Z</gml:timePosition>
# 								</gml:TimeInstant>
# 							</gml:end>
# 						</gml:TimePeriod>
# 					</eposb:operatorPeriod>
# 				</eposb:Operator>
# 			</eposb:operator>
# 			<eposb:purpose>
# 				<eposb:Purpose>
# 					<eposb:purpose xlink:href="https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch" xlink:title="multidisciplinary scientific research"/>
# 					<eposb:purposePeriod>
# 						<gml:TimePeriod>
# 							<gml:begin>
# 								<gml:TimeInstant>
# 									<gml:timePosition>2003-10-30Z</gml:timePosition>
# 								</gml:TimeInstant>
# 							</gml:begin>
# 							<gml:end>
# 								<gml:TimeInstant>
# 									<gml:timePosition indeterminatePosition="unknown"/>
# 								</gml:TimeInstant>
# 							</gml:end>
# 						</gml:TimePeriod>
# 					</eposb:purposePeriod>
# 					<eposb:purposeStatus xlink:href="http://www.opengis.net/def/nil/ogc/0/unknown" xlink:title="unknown"/>
# 				</eposb:Purpose>
# 			</eposb:purpose>
# 			<eposb:referenceElevation>
# 				<eposb:Elevation>
# 					<eposb:elevation axisLabels="elevation above sea level" srsDimension="3" srsName="https://epsg.io/4979" uomLabels="m">28.5</eposb:elevation>
# 					<eposb:elevationAccuracy>
# 						<gmd:DQ_AbsoluteExternalPositionalAccuracy id="SD-5004_4_D_collar-PosAcc">
# 							<gmd:measureDescription>
# 								<gco:CharacterString>The correct value is not known to, or not computable by, the sender of this data. However, the correct value probably exists.</gco:CharacterString>
# 							</gmd:measureDescription>
# 							<gmd:result>
# 								<gmd:DQ_ConformanceResult>
# 									<gmd:specification xlink:href="http://www.opengis.net/def/nil/OGC/0/unknown" xlink:title="unknown"/>
# 									<gmd:explanation>
# 										<gco:CharacterString>Evaluation of accuracy not implemented or not known.</gco:CharacterString>
# 									</gmd:explanation>
# 									<gmd:pass>
# 										<gco:Boolean>true</gco:Boolean>
# 									</gmd:pass>
# 								</gmd:DQ_ConformanceResult>
# 							</gmd:result>
# 						</gmd:DQ_AbsoluteExternalPositionalAccuracy>
# 					</eposb:elevationAccuracy>
# 					<eposb:elevationMeasurementMethod xlink:href="http://www.opengis.net/def/nil/OGC/0/unknown" xlink:title="unknown"/>
# 					<eposb:elevationType xlink:href="https://data.geoscience.earth/ncl/ElevationType/naturalGroundSurface" xlink:title="natural ground surface"/>
# 				</eposb:Elevation>
# 			</eposb:referenceElevation>
# 			<eposb:startPoint xlink:href="natural land surface" xlink:title="https://data.geoscience.earth/ncl/StartPoint/naturalLandSurface"/>
# 			<eposb:status xlink:href="https://data.geoscience.earth/ncl/BoreholeStatus/drillingCompleted" xlink:title="drilling completed"/>
# 			<eposb:locationMeasurementMethod xlink:href="http://www.opengis.net/def/nil/OGC/0/unknown" xlink:title="unknown"/>
# 			<eposb:locatedOnAdminUnit xlink:href="http://www.opengis.net/def/nil/ogc/0/unknown" xlink:title="unknown"/>
# 			<eposb:bholeHeadworks>
# 				<gwml2wc:BoreCollar gml:id="SD-5004_4_D_collar">
# 					<gml:name>5004_4_D_collar</gml:name>
# 					<gwml2wc:collarElevation axisLabels="elevation-depth" srsDimension="1" srsName="5613" uomLabels="m">28.500</gwml2wc:collarElevation>
# 					<gwml2wc:collarElevationType xlink:href="http://resource.gwml.org/def/collarElevationType/originElevation"/>
# 					<gwml2wc:collarHeadworkType xlink:href="http://www.opengis.net/def/nil/OGC/0/unknown" xlink:title="unknown"/>
# 					<gwml2wc:collarLocation>
# 						<gml:Point gml:id="SD-5004_4_D-collarlocation" srsDimension="3" srsName="http://www.opengis.net/gml/srs/epsg.xml#4979">
# 							<gml:pos>118.67 34.41 28.5</gml:pos>
# 						</gml:Point>
# 					</gwml2wc:collarLocation>
# 					<gwml2wc:collarSeal>
# 						<gwml2wc:SealingComponent>
# 							<gwml2wc:sealingMaterial xlink:href="http://www.opengis.net/def/nil/ogc/0/missing" xlink:title="missing"/>
# 							<gwml2wc:sealingType xlink:href="http://www.opengis.net/def/nil/ogc/0/missing" xlink:title="missing"/>
# 						</gwml2wc:SealingComponent>
# 					</gwml2wc:collarSeal>
# 				</gwml2wc:BoreCollar>
# 			</eposb:bholeHeadworks>
# 			<eposb:boreholeGeology xlink:href="http://www.opengis.net/def/nil/OGC/0/missing" xlink:title="missing"/>
# 		</eposb:Borehole>
# 	</wfs:member>
# </wfs:FeatureCollection>
#
# <?xml version="1.0" ?>
# <wfs:FeatureCollection xmlns:wfs="http://www.opengis.net/wfs/2.0" xmlns:xs="http://www.w3.org/2001/XMLSchema" xmlns:gwml2="http://www.opengis.net/gwml-main/2.2" xmlns:swe="http://www.opengis.net/swe/2.0" xmlns:sams="http://www.opengis.net/samplingSpatial/2.0" xmlns:gsmlp="http://schemas.opengis.net/gsml/4.1" xmlns:gml="http://www.opengis.net/gml/3.2" xmlns:gwml2wc="http://www.opengis.net/gwml-wellconstruction/2.2" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:eposb="https://data.geoscience.earth/def/eposb" xmlns:gco="http://www.isotc211.org/2005/gco" xmlns:gwml2w="http://www.opengis.net/gwml-well/2.2" xmlns:om="http://www.opengis.net/om/2.0" xmlns:sam="http://www.opengis.net/sampling/2.0" xmlns:gmd="http://www.isotc211.org/2005/gmd" xmlns:xlink="http://www.w3.org/1999/xlink" numberMatched="0" numberReturned="1" timeStamp="2025-06-16T10:43:40.969Z" xsi:schemaLocation="http://www.opengis.net/wfs/2.0 http://schemas.opengis.net/wfs/2.0/wfs.xsd https://data.geoscience.earth/def/eposb https://data.geoscience.earth/def/eposb.xsd http://www.opengis.net/gml/3.2 http://schemas.opengis.net/gml/3.2.1/gml.xsd">
# 	<wfs:member>
# 		<eposb:Borehole gml:id="SD-5012_1_A">
# 			<gml:descriptionReference xlink:href="https://igsn.org/ICDP5012EHZ1001" xlink:title="IGSN registry entry"/>
# 			<gml:identifier codeSpace="https://tools.ietf.org/html/rfc3629">https://www.geodata.rocks/Boreholes/SD-5012_1_A</gml:identifier>
# 			<sam:sampledFeature xlink:href="https://sweet.jpl.nasa.gov/2.3/realmEarthReference.owl#EarthLithosphere" xlink:title="Lithosphere"/>
# 			<sam:relatedSamplingFeature>
# 				<sam:SamplingFeatureComplex>
# 					<sam:role xlink:href="https://data.geoscience.earth/ncl/RelatedSamplingFeatureRole/boreholeSegment" xlink:title="borehole segment"/>
# 					<sam:relatedSamplingFeature xlink:href="https://www.geodata.rocks/Segments/SD-5012_1_A-1" xlink:title="SD-5012_1_A-1_0.00-4192.00"/>
# 				</sam:SamplingFeatureComplex>
# 			</sam:relatedSamplingFeature>
# 			<sams:shape>
# 				<gml:LineString gml:id="SD-5012_1_A-shape" srsDimension="3" srsName="http://www.opengis.net/gml/srs/epsg.xml#4979">
# 					<gml:posList>125.36307 46.2408 164 125.36307 46.2408 -4028</gml:posList>
# 				</gml:LineString>
# 			</sams:shape>
# 			<eposb:boreholeUse>
# 				<eposb:BoreholeUse>
# 					<eposb:use xlink:href="https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch" xlink:title="multidisciplinary scientific research"/>
# 					<eposb:usePeriod>
# 						<gml:TimePeriod>
# 							<gml:begin>
# 								<gml:TimeInstant>
# 									<gml:timePosition>2014-04-13Z</gml:timePosition>
# 								</gml:TimeInstant>
# 							</gml:begin>
# 							<gml:end>
# 								<gml:TimeInstant>
# 									<gml:timePosition indeterminatePosition="unknown"/>
# 								</gml:TimeInstant>
# 							</gml:end>
# 						</gml:TimePeriod>
# 					</eposb:usePeriod>
# 					<eposb:useStatus xlink:href="http://www.opengis.net/def/nil/ogc/0/unknown" xlink:title="unknown"/>
# 				</eposb:BoreholeUse>
# 			</eposb:boreholeUse>
# 			<eposb:custodian>
# 				<eposb:Custodian>
# 					<eposb:custodian>
# 						<gmd:CI_ResponsibleParty id="CGS-0.7499286653626006">
# 							<gmd:organisationName>
# 								<gco:CharacterString>China Geological Survey</gco:CharacterString>
# 							</gmd:organisationName>
# 							<gmd:contactInfo>
# 								<gmd:CI_Contact id="CGS-0.34774250078532687">
# 									<gmd:phone>
# 										<gmd:CI_Telephone id="CGS-PH-0.5090151614323355">
# 											<gmd:voice>
# 												<gco:CharacterString>+861058584620</gco:CharacterString>
# 											</gmd:voice>
# 											<gmd:facsimile>
# 												<gco:CharacterString>+861058584621</gco:CharacterString>
# 											</gmd:facsimile>
# 										</gmd:CI_Telephone>
# 									</gmd:phone>
# 									<gmd:address>
# 										<gmd:CI_Address id="CGS-ADR-0.38025547029991524">
# 											<gmd:deliveryPoint>
# 												<gco:CharacterString>No. 45 Fuwai Street, Xicheng District</gco:CharacterString>
# 											</gmd:deliveryPoint>
# 											<gmd:city>
# 												<gco:CharacterString>Beijing</gco:CharacterString>
# 											</gmd:city>
# 											<gmd:postalCode>
# 												<gco:CharacterString>100037</gco:CharacterString>
# 											</gmd:postalCode>
# 											<gmd:country>
# 												<gco:CharacterString>China</gco:CharacterString>
# 											</gmd:country>
# 											<gmd:electronicMailAddress>
# 												<gco:CharacterString>55282999@qq.com</gco:CharacterString>
# 											</gmd:electronicMailAddress>
# 										</gmd:CI_Address>
# 									</gmd:address>
# 									<gmd:onlineResource>
# 										<gmd:CI_OnlineResource id="CGS-OR-0.14420171902598078">
# 											<gmd:linkage>
# 												<gmd:URL>https://en.cgs.gov.cn/</gmd:URL>
# 											</gmd:linkage>
# 										</gmd:CI_OnlineResource>
# 									</gmd:onlineResource>
# 								</gmd:CI_Contact>
# 							</gmd:contactInfo>
# 							<gmd:role>
# 								<gmd:CI_RoleCode codeList="https://github.com/ISO-TC211/GOM/raw/master/isotc211_GOM_harmonizedOntology/19115/2006/iso19115CitationAndResponsiblePartyInformation.rdf" codeListValue="point Of Contact"/>
# 							</gmd:role>
# 						</gmd:CI_ResponsibleParty>
# 					</eposb:custodian>
# 					<eposb:custodianPeriod>
# 						<gml:TimePeriod>
# 							<gml:begin>
# 								<gml:TimeInstant>
# 									<gml:timePosition>2014-12-31Z</gml:timePosition>
# 								</gml:TimeInstant>
# 							</gml:begin>
# 							<gml:end>
# 								<gml:TimeInstant>
# 									<gml:timePosition indeterminatePosition="unknown"/>
# 								</gml:TimeInstant>
# 							</gml:end>
# 						</gml:TimePeriod>
# 					</eposb:custodianPeriod>
# 				</eposb:Custodian>
# 			</eposb:custodian>
# 			<eposb:legalAccessLevel>
# 				<gmd:MD_LegalConstraints>
# 					<gmd:accessConstraints>
# 						<gmd:MD_RestrictionCode codeList="http://registry.it.csiro.au/def/isotc211/MD_RestrictionCode/licenceUnrestricted" codeListValue="http://registry.it.csiro.au/def/isotc211/MD_RestrictionCode/licenceUnrestricted"/>
# 					</gmd:accessConstraints>
# 				</gmd:MD_LegalConstraints>
# 			</eposb:legalAccessLevel>
# 			<eposb:length uom="http://qudt.org/vocab/unit/M">4192.0</eposb:length>
# 			<eposb:purpose>
# 				<eposb:Purpose>
# 					<eposb:purpose xlink:href="https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch" xlink:title="multidisciplinary scientific research"/>
# 					<eposb:purposePeriod>
# 						<gml:TimePeriod>
# 							<gml:begin>
# 								<gml:TimeInstant>
# 									<gml:timePosition>2014-04-13Z</gml:timePosition>
# 								</gml:TimeInstant>
# 							</gml:begin>
# 							<gml:end>
# 								<gml:TimeInstant>
# 									<gml:timePosition indeterminatePosition="unknown"/>
# 								</gml:TimeInstant>
# 							</gml:end>
# 						</gml:TimePeriod>
# 					</eposb:purposePeriod>
# 					<eposb:purposeStatus xlink:href="http://www.opengis.net/def/nil/ogc/0/unknown" xlink:title="unknown"/>
# 				</eposb:Purpose>
# 			</eposb:purpose>
# 			<eposb:referenceElevation>
# 				<eposb:Elevation>
# 					<eposb:elevation axisLabels="elevation above sea level" srsDimension="3" srsName="https://epsg.io/4979" uomLabels="m">164.0</eposb:elevation>
# 					<eposb:elevationAccuracy>
# 						<gmd:DQ_AbsoluteExternalPositionalAccuracy id="SD-5012_1_A_collar-PosAcc">
# 							<gmd:measureDescription>
# 								<gco:CharacterString>The correct value is not known to, or not computable by, the sender of this data. However, the correct value probably exists.</gco:CharacterString>
# 							</gmd:measureDescription>
# 							<gmd:result>
# 								<gmd:DQ_ConformanceResult>
# 									<gmd:specification xlink:href="http://www.opengis.net/def/nil/OGC/0/unknown" xlink:title="unknown"/>
# 									<gmd:explanation>
# 										<gco:CharacterString>Evaluation of accuracy not implemented or not known.</gco:CharacterString>
# 									</gmd:explanation>
# 									<gmd:pass>
# 										<gco:Boolean>true</gco:Boolean>
# 									</gmd:pass>
# 								</gmd:DQ_ConformanceResult>
# 							</gmd:result>
# 						</gmd:DQ_AbsoluteExternalPositionalAccuracy>
# 					</eposb:elevationAccuracy>
# 					<eposb:elevationMeasurementMethod xlink:href="http://www.opengis.net/def/nil/OGC/0/unknown" xlink:title="unknown"/>
# 					<eposb:elevationType xlink:href="https://data.geoscience.earth/ncl/ElevationType/naturalGroundSurface" xlink:title="natural ground surface"/>
# 				</eposb:Elevation>
# 			</eposb:referenceElevation>
# 			<eposb:startPoint xlink:href="natural land surface" xlink:title="https://data.geoscience.earth/ncl/StartPoint/naturalLandSurface"/>
# 			<eposb:status xlink:href="https://data.geoscience.earth/ncl/BoreholeStatus/drillingCompleted" xlink:title="drilling completed"/>
# 			<eposb:locationMeasurementMethod xlink:href="http://www.opengis.net/def/nil/OGC/0/unknown" xlink:title="unknown"/>
# 			<eposb:locatedOnAdminUnit xlink:href="http://www.opengis.net/def/nil/ogc/0/unknown" xlink:title="unknown"/>
# 			<eposb:bholeHeadworks>
# 				<gwml2wc:BoreCollar gml:id="SD-5012_1_A_collar">
# 					<gml:name>5012_1_A_collar</gml:name>
# 					<gwml2wc:collarElevation axisLabels="elevation-depth" srsDimension="1" srsName="5613" uomLabels="m">164.000</gwml2wc:collarElevation>
# 					<gwml2wc:collarElevationType xlink:href="http://resource.gwml.org/def/collarElevationType/originElevation"/>
# 					<gwml2wc:collarHeadworkType xlink:href="http://www.opengis.net/def/nil/OGC/0/unknown" xlink:title="unknown"/>
# 					<gwml2wc:collarLocation>
# 						<gml:Point gml:id="SD-5012_1_A-collarlocation" srsDimension="3" srsName="http://www.opengis.net/gml/srs/epsg.xml#4979">
# 							<gml:pos>125.36307 46.2408 164</gml:pos>
# 						</gml:Point>
# 					</gwml2wc:collarLocation>
# 					<gwml2wc:collarSeal>
# 						<gwml2wc:SealingComponent>
# 							<gwml2wc:sealingMaterial xlink:href="http://www.opengis.net/def/nil/ogc/0/missing" xlink:title="missing"/>
# 							<gwml2wc:sealingType xlink:href="http://www.opengis.net/def/nil/ogc/0/missing" xlink:title="missing"/>
# 						</gwml2wc:SealingComponent>
# 					</gwml2wc:collarSeal>
# 				</gwml2wc:BoreCollar>
# 			</eposb:bholeHeadworks>
# 			<eposb:boreholeGeology xlink:href="http://www.opengis.net/def/nil/OGC/0/missing" xlink:title="missing"/>
# 		</eposb:Borehole>
# 	</wfs:member>
# </wfs:FeatureCollection>
#
# <?xml version="1.0" ?>
# ...
# 							<gmd:individualName>
# 								<gco:CharacterString>Henning Lorenz</gco:CharacterString>
# 							</gmd:individualName>
# 							<gmd:organisationName>
# 								<gco:CharacterString>Uppsala University, Department of Earth Sciences</gco:CharacterString>
# 							</gmd:organisationName>
# 							<gmd:positionName>
# 								<gco:CharacterString>Coordinator scientific drilling</gco:CharacterString>
# 							</gmd:positionName>
# 							<gmd:contactInfo>
# 								<gmd:CI_Contact id="UU-hl-0.4514207842015422">
# 									<gmd:phone>
# 										<gmd:CI_Telephone id="UU-hl-PH-0.5423454292670269">
# 											<gmd:voice>
# 												<gco:CharacterString>+464712324</gco:CharacterString>
# 											</gmd:voice>
# 										</gmd:CI_Telephone>
# 									</gmd:phone>
# 									<gmd:address>
# 										<gmd:CI_Address id="UU-hl-ADR-0.15661606140213846">
# 											<gmd:deliveryPoint>
# 												<gco:CharacterString>Villavägen 16</gco:CharacterString>
# 											</gmd:deliveryPoint>
# 											<gmd:city>
# 												<gco:CharacterString>Uppsala</gco:CharacterString>
# 											</gmd:city>
# 											<gmd:postalCode>
# 												<gco:CharacterString>753 26</gco:CharacterString>
# 											</gmd:postalCode>
# 											<gmd:country>
# 												<gco:CharacterString>Sweden</gco:CharacterString>
# 											</gmd:country>
# 											<gmd:electronicMailAddress>
# 												<gco:CharacterString>henning.lorenz@geo.uu.se</gco:CharacterString>
# 											</gmd:electronicMailAddress>
# 										</gmd:CI_Address>
# 									</gmd:address>
# 									<gmd:onlineResource>
# 										<gmd:CI_OnlineResource id="UU-hl-OR-0.9809598355652225">
# 											<gmd:linkage>
# 												<gmd:URL>https://katalog.uu.se/profile/?id=N0-558</gmd:URL>
# 											</gmd:linkage>
# 										</gmd:CI_OnlineResource>
# 									</gmd:onlineResource>
# 									<gmd:hoursOfService>
# 										<gco:CharacterString>Office hours for phone contact</gco:CharacterString>
# 									</gmd:hoursOfService>
# 									<gmd:contactInstructions>
# 										<gco:CharacterString>In case of problems, contact the organisation</gco:CharacterString>
# 									</gmd:contactInstructions>
# 								</gmd:CI_Contact>
# 							</gmd:contactInfo>
# 							<gmd:role>
# 								<gmd:CI_RoleCode codeList="https://github.com/ISO-TC211/GOM/raw/master/isotc211_GOM_harmonizedOntology/19115/2006/iso19115CitationAndResponsiblePartyInformation.rdf" codeListValue="point Of Contact"/>
# 							</gmd:role>
# 						</gmd:CI_ResponsibleParty>
# 					</eposb:origin>
# 					<eposb:aliasValidityPeriod>
# 						<gml:TimePeriod>
# 							<gml:begin>
# 								<gml:TimeInstant>
# 									<gml:timePosition>2017-01-15Z</gml:timePosition>
# 								</gml:TimeInstant>
# 							</gml:begin>
# 							<gml:end>
# 								<gml:TimeInstant>
# 									<gml:timePosition indeterminatePosition="unknown"/>
# 								</gml:TimeInstant>
# 							</gml:end>
# 						</gml:TimePeriod>
# 					</eposb:aliasValidityPeriod>
# 					<eposb:borehole/>
# 				</eposb:Alias>
# 			</eposb:alias>
# 		</eposb:Borehole>
# 	</wfs:member>
# </wfs:FeatureCollection>
#
# <?xml version="1.0" ?>
# <wfs:FeatureCollection xmlns:wfs="http://www.opengis.net/wfs/2.0" xmlns:xs="http://www.w3.org/2001/XMLSchema" xmlns:gwml2="http://www.opengis.net/gwml-main/2.2" xmlns:swe="http://www.opengis.net/swe/2.0" xmlns:sams="http://www.opengis.net/samplingSpatial/2.0" xmlns:gsmlp="http://schemas.opengis.net/gsml/4.1" xmlns:gml="http://www.opengis.net/gml/3.2" xmlns:gwml2wc="http://www.opengis.net/gwml-wellconstruction/2.2" xmlns:xsi="http://www.w3.org/2001/XMLSchema-instance" xmlns:eposb="https://data.geoscience.earth/def/eposb" xmlns:gco="http://www.isotc211.org/2005/gco" xmlns:gwml2w="http://www.opengis.net/gwml-well/2.2" xmlns:om="http://www.opengis.net/om/2.0" xmlns:sam="http://www.opengis.net/sampling/2.0" xmlns:gmd="http://www.isotc211.org/2005/gmd" xmlns:xlink="http://www.w3.org/1999/xlink" numberMatched="0" numberReturned="1" timeStamp="2025-06-16T10:44:18.649Z" xsi:schemaLocation="http://www.opengis.net/wfs/2.0 http://schemas.opengis.net/wfs/2.0/wfs.xsd https://data.geoscience.earth/def/eposb https://data.geoscience.earth/def/eposb.xsd http://www.opengis.net/gml/3.2 http://schemas.opengis.net/gml/3.2.1/gml.xsd">
# 	<wfs:member>
# 		<eposb:Borehole gml:id="SD-5058_1_A">
# 			<gml:descriptionReference xlink:href="https://igsn.org/ICDP5058EHJ2001" xlink:title="IGSN registry entry"/>
# 			<gml:identifier codeSpace="https://tools.ietf.org/html/rfc3629">https://www.geodata.rocks/Boreholes/SD-5058_1_A</gml:identifier>
# 			<sam:sampledFeature xlink:href="https://sweet.jpl.nasa.gov/2.3/realmEarthReference.owl#EarthLithosphere" xlink:title="Lithosphere"/>
# 			<sam:relatedSamplingFeature>
# 				<sam:SamplingFeatureComplex>
# 					<sam:role xlink:href="https://data.geoscience.earth/ncl/RelatedSamplingFeatureRole/boreholeSegment" xlink:title="borehole segment"/>
# 					<sam:relatedSamplingFeature xlink:href="https://www.geodata.rocks/Segments/SD-5058_1_A-1" xlink:title="SD-5058_1_A-1_0.00-3012.00"/>
# 				</sam:SamplingFeatureComplex>
# 			</sam:relatedSamplingFeature>
# 			<sams:shape>
# 				<gml:LineString gml:id="SD-5058_1_A-shape" srsDimension="3" srsName="http://www.opengis.net/gml/srs/epsg.xml#4979">
# 					<gml:posList>73.733 17.283 902 73.733 17.283 -2110</gml:posList>
# 				</gml:LineString>
# 			</sams:shape>
# 			<eposb:boreholeUse>
# 				<eposb:BoreholeUse>
# 					<eposb:use xlink:href="https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch" xlink:title="multidisciplinary scientific research"/>
# 					<eposb:usePeriod>
# 						<gml:TimePeriod>
# 							<gml:begin>
# 								<gml:TimeInstant>
# 									<gml:timePosition>2017-02-01Z</gml:timePosition>
# 								</gml:TimeInstant>
# 							</gml:begin>
# 							<gml:end>
# 								<gml:TimeInstant>
# 									<gml:timePosition indeterminatePosition="unknown"/>
# 								</gml:TimeInstant>
# 							</gml:end>
# 						</gml:TimePeriod>
# 					</eposb:usePeriod>
# 					<eposb:useStatus xlink:href="http://www.opengis.net/def/nil/ogc/0/unknown" xlink:title="unknown"/>
# 				</eposb:BoreholeUse>
# 			</eposb:boreholeUse>
# 			<eposb:custodian>
# 				<eposb:Custodian>
# 					<eposb:custodian>
# 						<gmd:CI_ResponsibleParty id="NCPOR-0.5651027633529765">
# 							<gmd:organisationName>
# 								<gco:CharacterString>National Centre for Polar and Ocean Research, India</gco:CharacterString>
# 							</gmd:organisationName>
# 							<gmd:contactInfo>
# 								<gmd:CI_Contact id="NCPOR-0.6264670340708733">
# 									<gmd:phone>
# 										<gmd:CI_Telephone id="NCPOR-PH-0.573496395315247">
# 											<gmd:voice>
# 												<gco:CharacterString>+918322520876</gco:CharacterString>
# 											</gmd:voice>
# 											<gmd:facsimile>
# 												<gco:CharacterString>+918322520877</gco:CharacterString>
# 											</gmd:facsimile>
# 										</gmd:CI_Telephone>
# 									</gmd:phone>
# 									<gmd:address>
# 										<gmd:CI_Address id="NCPOR-ADR-0.4216651751090469">
# 											<gmd:deliveryPoint>
# 												<gco:CharacterString>Headland Sada, Vasco-da-Gama</gco:CharacterString>
# 											</gmd:deliveryPoint>
# 											<gmd:city>
# 												<gco:CharacterString>Goa</gco:CharacterString>
# 											</gmd:city>
# 											<gmd:postalCode>
# 												<gco:CharacterString>403 804</gco:CharacterString>
# 											</gmd:postalCode>
# 											<gmd:country>
# 												<gco:CharacterString>India</gco:CharacterString>
# 											</gmd:country>
# 											<gmd:electronicMailAddress>
# 												<gco:CharacterString>info@ncpor.res.in</gco:CharacterString>
# 											</gmd:electronicMailAddress>
# 										</gmd:CI_Address>
# 									</gmd:address>
# 									<gmd:onlineResource>
# 										<gmd:CI_OnlineResource id="NCPOR-OR-0.5047674282058796">
# 											<gmd:linkage>
# 												<gmd:URL>https://ncpor.res.in</gmd:URL>
# 											</gmd:linkage>
# 										</gmd:CI_OnlineResource>
# 									</gmd:onlineResource>
# 								</gmd:CI_Contact>
# 							</gmd:contactInfo>
# 							<gmd:role>
# 								<gmd:CI_RoleCode codeList="https://github.com/ISO-TC211/GOM/raw/master/isotc211_GOM_harmonizedOntology/19115/2006/iso19115CitationAndResponsiblePartyInformation.rdf" codeListValue="point Of Contact"/>
# 							</gmd:role>
# 						</gmd:CI_ResponsibleParty>
# 					</eposb:custodian>
# 					<eposb:custodianPeriod>
# 						<gml:TimePeriod>
# 							<gml:begin>
# 								<gml:TimeInstant>
# 									<gml:timePosition>2017-06-30Z</gml:timePosition>
# 								</gml:TimeInstant>
# 							</gml:begin>
# 							<gml:end>
# 								<gml:TimeInstant>
# 									<gml:timePosition indeterminatePosition="unknown"/>
# 								</gml:TimeInstant>
# 							</gml:end>
# 						</gml:TimePeriod>
# 					</eposb:custodianPeriod>
# 				</eposb:Custodian>
# 			</eposb:custodian>
# 			<eposb:custodian>
# 				<eposb:Custodian>
# 					<eposb:custodian>
# 						<gmd:CI_ResponsibleParty id="GFZ-ICDP-0.8986847155627484">
# 							<gmd:individualName>
# 								<gco:CharacterString>Ronald Conze</gco:CharacterString>
# 							</gmd:individualName>
# 							<gmd:organisationName>
# 								<gco:CharacterString>International Continental Scientific Drilling Program (ICDP), GFZ German Research Centre for Geosciences</gco:CharacterString>
# 							</gmd:organisationName>
# 							<gmd:positionName>
# 								<gco:CharacterString>Data Management</gco:CharacterString>
# 							</gmd:positionName>
# 							<gmd:contactInfo>
# 								<gmd:CI_Contact id="GFZ-ICDP-0.9198997711068615">
# 									<gmd:phone>
# 										<gmd:CI_Telephone id="GFZ-ICDP-PH-0.5580709268649383">
# 											<gmd:voice>
# 												<gco:CharacterString>+493312881082</gco:CharacterString>
# 											</gmd:voice>
# 										</gmd:CI_Telephone>
# 									</gmd:phone>
# 									<gmd:address>
# 										<gmd:CI_Address id="GFZ-ICDP-ADR-0.3197948110306297">
# 											<gmd:deliveryPoint>
# 												<gco:CharacterString> Telegrafenberg 69A</gco:CharacterString>
# 											</gmd:deliveryPoint>
# 											<gmd:city>
# 												<gco:CharacterString>Potsdam</gco:CharacterString>
# 											</gmd:city>
# 											<gmd:postalCode>
# 												<gco:CharacterString>14473</gco:CharacterString>
# 											</gmd:postalCode>
# 											<gmd:country>
# 												<gco:CharacterString>Germany</gco:CharacterString>
# 											</gmd:country>
# 											<gmd:electronicMailAddress>
# 												<gco:CharacterString>dm@icdp-online.org</gco:CharacterString>
# 											</gmd:electronicMailAddress>
# 										</gmd:CI_Address>
# 									</gmd:address>
# 									<gmd:onlineResource>
# 										<gmd:CI_OnlineResource id="GFZ-ICDP-OR-0.25491691864390553">
# 											<gmd:linkage>
# 												<gmd:URL>https://www.icdp-online.org/contact/</gmd:URL>
# 											</gmd:linkage>
# 										</gmd:CI_OnlineResource>
# 									</gmd:onlineResource>
# 									<gmd:hoursOfService>
# 										<gco:CharacterString>Office hours for phone contact</gco:CharacterString>
# 									</gmd:hoursOfService>
# 								</gmd:CI_Contact>
# 							</gmd:contactInfo>
# 							<gmd:role>
# 								<gmd:CI_RoleCode codeList="https://github.com/ISO-TC211/GOM/raw/master/isotc211_GOM_harmonizedOntology/19115/2006/iso19115CitationAndResponsiblePartyInformation.rdf" codeListValue="point Of Contact"/>
# 							</gmd:role>
# 						</gmd:CI_ResponsibleParty>
# 					</eposb:custodian>
# 					<eposb:custodianPeriod>
# 						<gml:TimePeriod>
# 							<gml:begin>
# 								<gml:TimeInstant>
# 									<gml:timePosition>2023-01-01Z</gml:timePosition>
# 								</gml:TimeInstant>
# 							</gml:begin>
# 							<gml:end>
# 								<gml:TimeInstant>
# 									<gml:timePosition indeterminatePosition="unknown"/>
# 								</gml:TimeInstant>
# 							</gml:end>
# 						</gml:TimePeriod>
# 					</eposb:custodianPeriod>
# 				</eposb:Custodian>
# 			</eposb:custodian>
# 			<eposb:legalAccessLevel>
# 				<gmd:MD_LegalConstraints>
# 					<gmd:accessConstraints>
# 						<gmd:MD_RestrictionCode codeList="http://registry.it.csiro.au/def/isotc211/MD_RestrictionCode/licenceUnrestricted" codeListValue="http://registry.it.csiro.au/def/isotc211/MD_RestrictionCode/licenceUnrestricted"/>
# 					</gmd:accessConstraints>
# 				</gmd:MD_LegalConstraints>
# 			</eposb:legalAccessLevel>
# 			<eposb:length uom="http://qudt.org/vocab/unit/M">3012.0</eposb:length>
# 			<eposb:purpose>
# 				<eposb:Purpose>
# 					<eposb:purpose xlink:href="https://data.geoscience.earth/ncl/BoreholePurpose/multiDisciplinaryScientificResearch" xlink:title="multidisciplinary scientific research"/>
# 					<eposb:purposePeriod>
# 						<gml:TimePeriod>
# 							<gml:begin>
# 								<gml:TimeInstant>
# 									<gml:timePosition>2017-02-01Z</gml:timePosition>
# 								</gml:TimeInstant>
# 							</gml:begin>
# 							<gml:end>
# 								<gml:TimeInstant>
# 									<gml:timePosition indeterminatePosition="unknown"/>
# 								</gml:TimeInstant>
# 							</gml:end>
# 						</gml:TimePeriod>
# 					</eposb:purposePeriod>
# 					<eposb:purposeStatus xlink:href="http://www.opengis.net/def/nil/ogc/0/unknown" xlink:title="unknown"/>
# 				</eposb:Purpose>
# 			</eposb:purpose>
# 			<eposb:referenceElevation>
# 				<eposb:Elevation>
# 					<eposb:elevation axisLabels="elevation above sea level" srsDimension="3" srsName="https://epsg.io/4979" uomLabels="m">902.0</eposb:elevation>
# 					<eposb:elevationAccuracy>
# 						<gmd:DQ_AbsoluteExternalPositionalAccuracy id="SD-5058_1_A_collar-PosAcc">
# 							<gmd:measureDescription>
# 								<gco:CharacterString>The correct value is not known to, or not computable by, the sender of this data. However, the correct value probably exists.</gco:CharacterString>
# 							</gmd:measureDescription>
# 							<gmd:result>
# 								<gmd:DQ_ConformanceResult>
# 									<gmd:specification xlink:href="http://www.opengis.net/def/nil/OGC/0/unknown" xlink:title="unknown"/>
# 									<gmd:explanation>
# 										<gco:CharacterString>Evaluation of accuracy not implemented or not known.</gco:CharacterString>
# 									</gmd:explanation>
# 									<gmd:pass>
# 										<gco:Boolean>true</gco:Boolean>
# 									</gmd:pass>
# 								</gmd:DQ_ConformanceResult>
# 							</gmd:result>
# 						</gmd:DQ_AbsoluteExternalPositionalAccuracy>
# 					</eposb:elevationAccuracy>
# 					<eposb:elevationMeasurementMethod xlink:href="http://www.opengis.net/def/nil/OGC/0/unknown" xlink:title="unknown"/>
# 					<eposb:elevationType xlink:href="https://data.geoscience.earth/ncl/ElevationType/naturalGroundSurface" xlink:title="natural ground surface"/>
# 				</eposb:Elevation>
# 			</eposb:referenceElevation>
# 			<eposb:startPoint xlink:href="natural land surface" xlink:title="https://data.geoscience.earth/ncl/StartPoint/naturalLandSurface"/>
# 			<eposb:status xlink:href="https://data.geoscience.earth/ncl/BoreholeStatus/drillingCompleted" xlink:title="drilling completed"/>
# 			<eposb:locationMeasurementMethod xlink:href="http://www.opengis.net/def/nil/OGC/0/unknown" xlink:title="unknown"/>
# 			<eposb:locatedOnAdminUnit xlink:href="http://www.opengis.net/def/nil/ogc/0/unknown" xlink:title="unknown"/>
# 			<eposb:bholeHeadworks>
# 				<gwml2wc:BoreCollar gml:id="SD-5058_1_A_collar">
# 					<gml:name>5058_1_A_collar</gml:name>
# 					<gwml2wc:collarElevation axisLabels="elevation-depth" srsDimension="1" srsName="5613" uomLabels="m">902.000</gwml2wc:collarElevation>
# 					<gwml2wc:collarElevationType xlink:href="http://resource.gwml.org/def/collarElevationType/originElevation"/>
# 					<gwml2wc:collarHeadworkType xlink:href="http://www.opengis.net/def/nil/OGC/0/unknown" xlink:title="unknown"/>
# 					<gwml2wc:collarLocation>
# 						<gml:Point gml:id="SD-5058_1_A-collarlocation" srsDimension="3" srsName="http://www.opengis.net/gml/srs/epsg.xml#4979">
# 							<gml:pos>73.733 17.283 902</gml:pos>
# 						</gml:Point>
# 					</gwml2wc:collarLocation>
# 					<gwml2wc:collarSeal>
# 						<gwml2wc:SealingComponent>
# 							<gwml2wc:sealingMaterial xlink:href="http://www.opengis.net/def/nil/ogc/0/missing" xlink:title="missing"/>
# 							<gwml2wc:sealingType xlink:href="http://www.opengis.net/def/nil/ogc/0/missing" xlink:title="missing"/>
# 						</gwml2wc:SealingComponent>
# 					</gwml2wc:collarSeal>
# 				</gwml2wc:BoreCollar>
# 			</eposb:bholeHeadworks>
# 			<eposb:boreholeGeology xlink:href="http://www.opengis.net/def/nil/OGC/0/missing" xlink:title="missing"/>
# 		</eposb:Borehole>
# 	</wfs:member>
# </wfs:FeatureCollection>

# %% [markdown]
# <span style="font-size:1.4em;">Get geological features (units)</span>

# %%
service_url = 'https://data.geoscience.earth/api/wmsGeologicUnit?'
wfs = WFS(service_url, version='2.0.0')
list(wfs.contents)
# Out:
# ['epos-gsmlp:GeologicUnitView']

# %%
target_layer = 'epos-gsmlp:GeologicUnitView'

# %% [markdown]
# Query the GeologicUnitView Service and add the data to the 'boreholes' dictionary

# %%
# Select format
format_option = 'application/xml'

for key, value in boreholes.items():
# CQL filters
    filter = 'Contains(shape,' + str(boreholes[key]['GML_location']) + ')'
    payload = {
        'service' : 'WFS',
        'request' : API_method,
        'srsName' : 'EPSG:4326',
        'version' : '2.0.0',
        'typenames' : [target_layer],
        'CQL_FILTER' : filter,
        'format' : format_option
    }
    # Retrieve response content and read it as string to variable
    response = requests.get(service_url, params=payload)
    strcontent = ET.fromstring(response.content)

    # Extract the value
    for elem in strcontent.iter():
        for feature in elem.findall(".//{http://www.opengis.net/wfs/2.0}member"):
            lithology = feature.find(".//{https://data.geoscience.earth/def/epos-geosciml-lite}lithology").attrib['{http://www.w3.org/1999/xlink}href']
            age = feature.find(".//{https://data.geoscience.earth/def/epos-geosciml-lite}representativeAge_uri").attrib['{http://www.w3.org/1999/xlink}href']
            boreholes[key]['lithology_geologic_unit'] = lithology
            boreholes[key]['age_surface_lithology'] = age

pp(boreholes)
# Out:
# {
#     'COSC-1 A': {
#         'GML_location': 'POINT(63.40163 13.20292)',
#         'age_surface_lithology': 'http://inspire.ec.europa.eu/codelist/GeochronologicEraValue/tonian2',
#         'depth_m': '2495.8',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5054_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5054_1_A',
#         'lithology_geologic_unit': 'http://inspire.ec.europa.eu/codelist/LithologyValue/micaSchist',
#     },
#     'COSC-2 A': {
#         'GML_location': 'POINT(63.31245 13.52648)',
#         'age_surface_lithology': 'http://inspire.ec.europa.eu/codelist/GeochronologicEraValue/floian',
#         'depth_m': '2276.05',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5054_2_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5054_2_A',
#         'lithology_geologic_unit': 'http://inspire.ec.europa.eu/codelist/LithologyValue/wacke',
#     },
#     'Chesapeake, CBIS Eyreville-1 Corehole 63G69 (A)': {
#         'GML_location': 'POINT(37.3217 -75.9757)',
#         'depth_m': '2142.7',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5001_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5001_1_A',
#     },
#     'Donghai, CCSD-MH-2K': {
#         'GML_location': 'POINT(34.41 118.67)',
#         'depth_m': '3525.18',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5004_4_D',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5004_4_D',
#     },
#     'Donghai, CCSD-PH': {
#         'GML_location': 'POINT(34.41 118.67)',
#         'depth_m': '2039.54',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5004_4_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5004_4_A',
#     },
#     'Hawaii, HSDP-2a': {
#         'GML_location': 'POINT(19.74 -155.05)',
#         'depth_m': '3099.67',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5027_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5027_1_A',
#     },
#     'Iceland, IDDP-1-A, RN-17': {
#         'GML_location': 'POINT(65.71587 -16.76452)',
#         'age_surface_lithology': 'http://inspire.ec.europa.eu/codelist/GeochronologicEraValue/pleistocene',
#         'depth_m': '2100.0',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5029_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5029_1_A',
#         'lithology_geologic_unit': 'http://inspire.ec.europa.eu/codelist/LithologyValue/tuffBrecciaAgglomerateOrPyroclasticBreccia',
#     },
#     'Kola SG-3': {
#         'GML_location': 'POINT(69.17 29.28)',
#         'depth_m': '12261.0',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5016_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5016_1_A',
#     },
#     'Koyna, KFD1': {
#         'GML_location': 'POINT(17.283 73.733)',
#         'depth_m': '3012.0',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5058_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5058_1_A',
#     },
#     'Outokumpu': {
#         'GML_location': 'POINT(62.71781 29.06199)',
#         'age_surface_lithology': 'http://inspire.ec.europa.eu/codelist/GeochronologicEraValue/upperPleistocene',
#         'depth_m': '2516.0',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5015_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5015_1_A',
#         'lithology_geologic_unit': 'http://inspire.ec.europa.eu/codelist/LithologyValue/clay',
#     },
#     'SAFOD-MH-ST1': {
#         'GML_location': 'POINT(35.97417 -120.55185)',
#         'depth_m': '2994.81',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5025_1_C',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5025_1_C',
#     },
#     'SAFOD-PH': {
#         'GML_location': 'POINT(35.97426 -120.55211)',
#         'depth_m': '2154.94',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5025_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5025_1_A',
#     },
#     'Songliao 1A': {
#         'GML_location': 'POINT(46.2408 125.36307)',
#         'depth_m': '4192.0',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5012_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5012_1_A',
#     },
# }

# %% [markdown]
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <center><span style="color:green; font-size:3em; font-weight:bold;">Interacting with services and data</span></center><br>

# %% [markdown]
# <center><span style="color:green; font-size:2.5em; font-weight:bold;">GNSS data and services</span></center>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>

# %% [markdown]
# <span style="font-size:1.25em;">Interacting with services and data</span><br>
# <span style="color:green; font-size:2em;">GNSS data and services</span>

# %% [markdown]
# <span style="font-size:1.4em;">Find GNSS stations that are up to 100 km from the boreholes</span>

# %% [markdown]
# Community standards for data format (e.g. RINEX) and a data transfer (GlassFramework). The latter supports a rectangular bounding box and is used here for spatial filtering.

# %%
import json
import math
from datetime import date, datetime
from dateutil.relativedelta import relativedelta

# target URL (from EPOS portal): https://gnssproducts.epos.ubi.pt/GlassFramework/webresources/stations/v2/station/bbox/<lonmin>/<latmin>/<lonmax>/<latmax>
# alternatively, use pyglass: pyglass.py stations -u https://gnssproducts.epos.ubi.pt/GlassFramework -ltmin <latmin> -ltmax <latmax> -lgmin <lonmin> -lgmax <longmax> 
distance = 100 # km
baseURL = 'https://gnssproducts.epos.ubi.pt/GlassFramework/webresources/stations/v2/station/'

# function to calculate the bounding box from the borehole location (as GML point) and the search distance
def gnssbboxfromgmlpoint(gmlpoint, distancekm):
    calc = re.search(r"(\d{1,2}.\d{1,})\s(-{0,1}\d{1,2}.\d{1,})", gmlpoint)
    distancedeglat = distancekm/111.1 # 40000/360=111.111
    distancedeglon = distancekm/111.1*math.cos(float(calc[2])*(2*math.pi)/360)
    latmin = float(calc[1]) - distancedeglat
    latmax = float(calc[1]) + distancedeglat
    lonmin = float(calc[2]) - distancedeglon
    lonmax = float(calc[2]) + distancedeglon
    return('bbox/' + str(lonmin) + '/' + str(latmin) + '/' + str(lonmax) + '/' + str(latmax))

# create a dictionary to hold the retrieved information
GNSS = {}

for key, value in boreholes.items():
    for subkey, subvalue in value.items():
        if subkey == 'GML_location':
            bbox = gnssbboxfromgmlpoint(subvalue, distance)
            content = requests.get(baseURL + bbox)
            # print(content.url)
            json_content = content.json()
            if not json_content['features']:
                print('No GNSS stations found for', key)
            else:
                GNSS[key] = json_content

print('GNSS dictionary:')
pp(GNSS)
# Out:
# No GNSS stations found for Chesapeake, CBIS Eyreville-1 Corehole 63G69 (A)
# No GNSS stations found for Donghai, CCSD-PH
# No GNSS stations found for Donghai, CCSD-MH-2K
# No GNSS stations found for Songliao 1A
# No GNSS stations found for Kola SG-3
# No GNSS stations found for SAFOD-PH
# No GNSS stations found for SAFOD-MH-ST1
# No GNSS stations found for Hawaii, HSDP-2a
# No GNSS stations found for Koyna, KFD1
# GNSS dictionary:
# {
#     'COSC-1 A': {
#         '@epos_style': {
#             'station': {
#                 'label': 'GNSS Station',
#                 'marker': {
#                     'character': 'S',
#                     'clustering': 'false',
#                     'pin': 'true',
#                 },
#             },
#         },
#         'features': [
#             {
#                 'geometry': {'coordinates': [13.9679, 63.0414], 'type': 'Point'},
#                 'properties': {
#                     '@epos_data_keys': [
#                         'GNSS Station ID',
#                         'GNSS Station Marker',
#                         'Country',
#                         'Installed at',
#                         'Data Providers',
#                         'Networks',
#                         'longitude , latitude',
#                         'City',
#                         'Altitude',
#                         'x',
#                         'y',
#                         'z',
#                         'Longitude',
#                         'Latitude',
#                     ],
#                     '@epos_label_key': ['Title'],
#                     '@epos_links': [
#                         {
#                             'href': 'https://gnssproducts.epos.ubi.pt/glass/products/timeseries-plot/GRN000SWE/SGO-EPND/POSI/',
#                             'label': 'GRN000SWE TS Image SGO-EPND',
#                             'type': 'image/png',
#                         },
#                     ],
#                     '@epos_map_keys': [
#                         'GNSS Station ID',
#                         'Country',
#                         'City',
#                         'Latitude',
#                         'Longitude',
#                         'Altitude',
#                         'x',
#                         'y',
#                         'z',
#                         'Installed at',
#                         'Data Providers',
#                         'Networks',
#                         '@epos_links',
#                     ],
#                     '@epos_type': 'station',
#                     'Altitude': 605.96,
#                     'City': 'Gräftåvallen',
#                     'Country': 'Sweden',
#                     'Data Providers': 'LMV',
#                     'GNSS Station ID': 'GRN000SWE',
#                     'GNSS Station Marker': 'GRN000SWE',
#                     'Installed at': '2008-03-03 00:00:00',
#                     'Latitude': 63.0414,
#                     'Links TimeSeries': {
#                         'Link TimeSeries SGO-EPND': 'https://gnssproducts.epos.ubi.pt/GlassFramework/webresources/products/timeseries/GRN000SWE/SGO-EPND/xyz/covjson/',
#                     },
#                     'Links Velocities': {
#                         'Link Velocities SGO-EPND': 'https://gnssproducts.epos.ubi.pt/GlassFramework/webresources/products/velocities/GRN000SWE/SGO-EPND/xyz/json',
#                     },
#                     'Longitude': 13.9679,
#                     'Networks': 'EPN densification & E-GVAP',
#                     'TimeSeries and Velocities Data Providers': 'SGO-EPND',
#                     'Title': 'GRN000SWE',
#                     'x': 2813762.8160487,
#                     'y': 699874.2040121,
#                     'z': 5662613.7180981,
#                 },
#                 'type': 'Feature',
#             },
#         ],
#         'type': 'FeatureCollection',
#     },
#     'COSC-2 A': {
#         '@epos_style': {
#             'station': {
#                 'label': 'GNSS Station',
#                 'marker': {
#                     'character': 'S',
#                     'clustering': 'false',
#                     'pin': 'true',
#                 },
#             },
#         },
#         'features': [
#             {
#                 'geometry': {'coordinates': [13.9679, 63.0414], 'type': 'Point'},
#                 'properties': {
#                     '@epos_data_keys': [
#                         'GNSS Station ID',
#                         'GNSS Station Marker',
#                         'Country',
#                         'Installed at',
#                         'Data Providers',
#                         'Networks',
#                         'longitude , latitude',
#                         'City',
#                         'Altitude',
#                         'x',
#                         'y',
#                         'z',
#                         'Longitude',
#                         'Latitude',
#                     ],
#                     '@epos_label_key': ['Title'],
#                     '@epos_links': [
#                         {
#                             'href': 'https://gnssproducts.epos.ubi.pt/glass/products/timeseries-plot/GRN000SWE/SGO-EPND/POSI/',
#                             'label': 'GRN000SWE TS Image SGO-EPND',
#                             'type': 'image/png',
#                         },
#                     ],
#                     '@epos_map_keys': [
#                         'GNSS Station ID',
#                         'Country',
#                         'City',
#                         'Latitude',
#                         'Longitude',
#                         'Altitude',
#                         'x',
#                         'y',
#                         'z',
#                         'Installed at',
#                         'Data Providers',
#                         'Networks',
#                         '@epos_links',
#                     ],
#                     '@epos_type': 'station',
#                     'Altitude': 605.96,
#                     'City': 'Gräftåvallen',
#                     'Country': 'Sweden',
#                     'Data Providers': 'LMV',
#                     'GNSS Station ID': 'GRN000SWE',
#                     'GNSS Station Marker': 'GRN000SWE',
#                     'Installed at': '2008-03-03 00:00:00',
#                     'Latitude': 63.0414,
#                     'Links TimeSeries': {
#                         'Link TimeSeries SGO-EPND': 'https://gnssproducts.epos.ubi.pt/GlassFramework/webresources/products/timeseries/GRN000SWE/SGO-EPND/xyz/covjson/',
#                     },
#                     'Links Velocities': {
#                         'Link Velocities SGO-EPND': 'https://gnssproducts.epos.ubi.pt/GlassFramework/webresources/products/velocities/GRN000SWE/SGO-EPND/xyz/json',
#                     },
#                     'Longitude': 13.9679,
#                     'Networks': 'EPN densification & E-GVAP',
#                     'TimeSeries and Velocities Data Providers': 'SGO-EPND',
#                     'Title': 'GRN000SWE',
#                     'x': 2813762.8160487,
#                     'y': 699874.2040121,
#                     'z': 5662613.7180981,
#                 },
#                 'type': 'Feature',
#             },
#             {
#                 'geometry': {'coordinates': [13.5132, 62.4195], 'type': 'Point'},
#                 'properties': {
#                     '@epos_data_keys': [
#                         'GNSS Station ID',
#                         'GNSS Station Marker',
#                         'Country',
#                         'Installed at',
#                         'Data Providers',
#                         'Networks',
#                         'longitude , latitude',
#                         'City',
#                         'Altitude',
#                         'x',
#                         'y',
#                         'z',
#                         'Longitude',
#                         'Latitude',
#                     ],
#                     '@epos_label_key': ['Title'],
#                     '@epos_links': [
#                         {
#                             'href': 'https://gnssproducts.epos.ubi.pt/glass/products/timeseries-plot/HED000SWE/SGO-EPND/POSI/',
#                             'label': 'HED000SWE TS Image SGO-EPND',
#                             'type': 'image/png',
#                         },
#                     ],
#                     '@epos_map_keys': [
#                         'GNSS Station ID',
#                         'Country',
#                         'City',
#                         'Latitude',
#                         'Longitude',
#                         'Altitude',
#                         'x',
#                         'y',
#                         'z',
#                         'Installed at',
#                         'Data Providers',
#                         'Networks',
#                         '@epos_links',
#                     ],
#                     '@epos_type': 'station',
#                     'Altitude': 470.06,
#                     'City': 'Hede',
#                     'Country': 'Sweden',
#                     'Data Providers': 'LMV',
#                     'GNSS Station ID': 'HED000SWE',
#                     'GNSS Station Marker': 'HED000SWE',
#                     'Installed at': '2007-08-20 00:00:00',
#                     'Latitude': 62.4195,
#                     'Links TimeSeries': {
#                         'Link TimeSeries SGO-EPND': 'https://gnssproducts.epos.ubi.pt/GlassFramework/webresources/products/timeseries/HED000SWE/SGO-EPND/xyz/covjson/',
#                     },
#                     'Links Velocities': {
#                         'Link Velocities SGO-EPND': 'https://gnssproducts.epos.ubi.pt/GlassFramework/webresources/products/velocities/HED000SWE/SGO-EPND/xyz/json',
#                     },
#                     'Longitude': 13.5132,
#                     'Networks': 'EPN densification & E-GVAP',
#                     'TimeSeries and Velocities Data Providers': 'SGO-EPND',
#                     'Title': 'HED000SWE',
#                     'x': 2879086.4359246,
#                     'y': 691909.31498186,
#                     'z': 5630727.3408518,
#                 },
#                 'type': 'Feature',
#             },
#         ],
#         'type': 'FeatureCollection',
#     },
#     'Iceland, IDDP-1-A, RN-17': {
#         '@epos_style': {
#             'station': {
#                 'label': 'GNSS Station',
#                 'marker': {
#                     'character': 'S',
#                     'clustering': 'false',
#                     'pin': 'true',
#                 },
#             },
#         },
#         'features': [
#             {
#                 'geometry': {'coordinates': [-16.924, 64.9504], 'type': 'Point'},
#                 'properties': {
#                     '@epos_data_keys': [
#                         'GNSS Station ID',
#                         'GNSS Station Marker',
#                         'Country',
#                         'Installed at',
#                         'Data Providers',
#                         'Networks',
#                         'longitude , latitude',
#                         'City',
#                         'Altitude',
#                         'x',
#                         'y',
#                         'z',
#                         'Longitude',
#                         'Latitude',
#                     ],
#                     '@epos_label_key': ['Title'],
#                     '@epos_links': [],
#                     '@epos_map_keys': [
#                         'GNSS Station ID',
#                         'Country',
#                         'City',
#                         'Latitude',
#                         'Longitude',
#                         'Altitude',
#                         'x',
#                         'y',
#                         'z',
#                         'Installed at',
#                         'Data Providers',
#                         'Networks',
#                         '@epos_links',
#                     ],
#                     '@epos_type': 'station',
#                     'Altitude': 899.48,
#                     'City': 'Hrímalda',
#                     'Country': 'Iceland',
#                     'Data Providers': 'IMO',
#                     'GNSS Station ID': 'HRIC00ISL',
#                     'GNSS Station Marker': 'HRIC00ISL',
#                     'Installed at': '2014-08-23 00:00:00',
#                     'Latitude': 64.9504,
#                     'Links TimeSeries': {},
#                     'Links Velocities': {},
#                     'Longitude': -16.924,
#                     'Networks': '',
#                     'TimeSeries and Velocities Data Providers': 'No Data set provider found',
#                     'Title': 'HRIC00ISL',
#                     'x': 2591057.1,
#                     'y': -788410.6,
#                     'z': 5756185.0,
#                 },
#                 'type': 'Feature',
#             },
#             {
#                 'geometry': {'coordinates': [-16.7749, 65.6945], 'type': 'Point'},
#                 'properties': {
#                     '@epos_data_keys': [
#                         'GNSS Station ID',
#                         'GNSS Station Marker',
#                         'Country',
#                         'Installed at',
#                         'Data Providers',
#                         'Networks',
#                         'longitude , latitude',
#                         'City',
#                         'Altitude',
#                         'x',
#                         'y',
#                         'z',
#                         'Longitude',
#                         'Latitude',
#                     ],
#                     '@epos_label_key': ['Title'],
#                     '@epos_links': [],
#                     '@epos_map_keys': [
#                         'GNSS Station ID',
#                         'Country',
#                         'City',
#                         'Latitude',
#                         'Longitude',
#                         'Altitude',
#                         'x',
#                         'y',
#                         'z',
#                         'Installed at',
#                         'Data Providers',
#                         'Networks',
#                         '@epos_links',
#                     ],
#                     '@epos_type': 'station',
#                     'Altitude': 521.91,
#                     'City': 'Krafla',
#                     'Country': 'Iceland',
#                     'Data Providers': 'UI',
#                     'GNSS Station ID': 'KRAC00ISL',
#                     'GNSS Station Marker': 'KRAC00ISL',
#                     'Installed at': '2011-11-08 00:00:00',
#                     'Latitude': 65.6945,
#                     'Links TimeSeries': {},
#                     'Links Velocities': {},
#                     'Longitude': -16.7749,
#                     'Networks': '',
#                     'TimeSeries and Velocities Data Providers': 'No Data set provider found',
#                     'Title': 'KRAC00ISL',
#                     'x': 2520760.7,
#                     'y': -759858.4,
#                     'z': 5790484.9,
#                 },
#                 'type': 'Feature',
#             },
#             {
#                 'geometry': {'coordinates': [-15.9467, 66.4611], 'type': 'Point'},
#                 'properties': {
#                     '@epos_data_keys': [
#                         'GNSS Station ID',
#                         'GNSS Station Marker',
#                         'Country',
#                         'Installed at',
#                         'Data Providers',
#                         'Networks',
#                         'longitude , latitude',
#                         'City',
#                         'Altitude',
#                         'x',
#                         'y',
#                         'z',
#                         'Longitude',
#                         'Latitude',
#                     ],
#                     '@epos_label_key': ['Title'],
#                     '@epos_links': [],
#                     '@epos_map_keys': [
#                         'GNSS Station ID',
#                         'Country',
#                         'City',
#                         'Latitude',
#                         'Longitude',
#                         'Altitude',
#                         'x',
#                         'y',
#                         'z',
#                         'Installed at',
#                         'Data Providers',
#                         'Networks',
#                         '@epos_links',
#                     ],
#                     '@epos_type': 'station',
#                     'Altitude': 76.87,
#                     'City': 'Raufarhöfn',
#                     'Country': 'Iceland',
#                     'Data Providers': 'IMO',
#                     'GNSS Station ID': 'RHOF00ISL',
#                     'GNSS Station Marker': 'RHOF00ISL',
#                     'Installed at': '2001-07-19 00:00:00',
#                     'Latitude': 66.4611,
#                     'Links TimeSeries': {},
#                     'Links Velocities': {},
#                     'Longitude': -15.9467,
#                     'Networks': '',
#                     'TimeSeries and Velocities Data Providers': 'No Data set provider found',
#                     'Title': 'RHOF00ISL',
#                     'x': 2456169.8,
#                     'y': -701823.6,
#                     'z': 5824743.2,
#                 },
#                 'type': 'Feature',
#             },
#         ],
#         'type': 'FeatureCollection',
#     },
#     'Outokumpu': {
#         '@epos_style': {
#             'station': {
#                 'label': 'GNSS Station',
#                 'marker': {
#                     'character': 'S',
#                     'clustering': 'false',
#                     'pin': 'true',
#                 },
#             },
#         },
#         'features': [
#             {
#                 'geometry': {
#                     'coordinates': [29.12036122650406, 63.513508262634765],
#                     'type': 'Point',
#                 },
#                 'properties': {
#                     '@epos_data_keys': [
#                         'GNSS Station ID',
#                         'GNSS Station Marker',
#                         'Country',
#                         'Installed at',
#                         'Data Providers',
#                         'Networks',
#                         'longitude , latitude',
#                         'City',
#                         'Altitude',
#                         'x',
#                         'y',
#                         'z',
#                         'Longitude',
#                         'Latitude',
#                     ],
#                     '@epos_label_key': ['Title'],
#                     '@epos_links': [],
#                     '@epos_map_keys': [
#                         'GNSS Station ID',
#                         'Country',
#                         'City',
#                         'Latitude',
#                         'Longitude',
#                         'Altitude',
#                         'x',
#                         'y',
#                         'z',
#                         'Installed at',
#                         'Data Providers',
#                         'Networks',
#                         '@epos_links',
#                     ],
#                     '@epos_type': 'station',
#                     'Altitude': 143.739,
#                     'City': 'Nurmes',
#                     'Country': 'Finland (FIN)',
#                     'Data Providers': 'FGI',
#                     'GNSS Station ID': 'NUR200FIN',
#                     'GNSS Station Marker': 'NUR200FIN',
#                     'Installed at': '2018-08-15 12:00:00',
#                     'Latitude': 63.513508262634765,
#                     'Links TimeSeries': {},
#                     'Links Velocities': {},
#                     'Longitude': 29.12036122650406,
#                     'Networks': 'EPN densification',
#                     'TimeSeries and Velocities Data Providers': 'No Data set provider found',
#                     'Title': 'NUR200FIN',
#                     'x': 2491756.347,
#                     'y': 1388053.84,
#                     'z': 5685863.652,
#                 },
#                 'type': 'Feature',
#             },
#             {
#                 'geometry': {
#                     'coordinates': [28.725577291922274, 61.87355658240056],
#                     'type': 'Point',
#                 },
#                 'properties': {
#                     '@epos_data_keys': [
#                         'GNSS Station ID',
#                         'GNSS Station Marker',
#                         'Country',
#                         'Installed at',
#                         'Data Providers',
#                         'Networks',
#                         'longitude , latitude',
#                         'City',
#                         'Altitude',
#                         'x',
#                         'y',
#                         'z',
#                         'Longitude',
#                         'Latitude',
#                     ],
#                     '@epos_label_key': ['Title'],
#                     '@epos_links': [],
#                     '@epos_map_keys': [
#                         'GNSS Station ID',
#                         'Country',
#                         'City',
#                         'Latitude',
#                         'Longitude',
#                         'Altitude',
#                         'x',
#                         'y',
#                         'z',
#                         'Installed at',
#                         'Data Providers',
#                         'Networks',
#                         '@epos_links',
#                     ],
#                     '@epos_type': 'station',
#                     'Altitude': 149.467,
#                     'City': 'Savonlinna',
#                     'Country': 'Finland (FIN)',
#                     'Data Providers': 'FGI',
#                     'GNSS Station ID': 'SLIN00FIN',
#                     'GNSS Station Marker': 'SLIN00FIN',
#                     'Installed at': '2018-09-09 00:00:00',
#                     'Latitude': 61.87355658240056,
#                     'Links TimeSeries': {},
#                     'Links Velocities': {},
#                     'Longitude': 28.725577291922274,
#                     'Networks': 'EPN densification',
#                     'TimeSeries and Velocities Data Providers': 'No Data set provider found',
#                     'Title': 'SLIN00FIN',
#                     'x': 2643689.021,
#                     'y': 1448911.741,
#                     'z': 5602017.798,
#                 },
#                 'type': 'Feature',
#             },
#         ],
#         'type': 'FeatureCollection',
#     },
# }

# %% [markdown]
# <span style="font-size:1.25em;">Interacting with services and data</span><br>
# <span style="color:green; font-size:2em;">GNSS data and services</span>

# %% [markdown]
# <span style="font-size:1.4em;">Add the GNSS stations to the boreholes dictionary, including their location as GML point</span>

# %%
for key in GNSS.keys():
    count=0
    for items in GNSS[key]['features']:
        if count == 0:
            dict = {}
        count = count + 1
        newkey = items['properties']['GNSS Station Marker']
        location = 'POINT(' + str(items['properties']['Latitude']) + ' ' + str(items['properties']['Longitude']) + ')'
        dict[newkey] = location
    boreholes[key]['GNSS'] = dict

pp(boreholes)
# Out:
# {
#     'COSC-1 A': {
#         'GML_location': 'POINT(63.40163 13.20292)',
#         'GNSS': {'GRN000SWE': 'POINT(63.0414 13.9679)'},
#         'age_surface_lithology': 'http://inspire.ec.europa.eu/codelist/GeochronologicEraValue/tonian2',
#         'depth_m': '2495.8',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5054_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5054_1_A',
#         'lithology_geologic_unit': 'http://inspire.ec.europa.eu/codelist/LithologyValue/micaSchist',
#     },
#     'COSC-2 A': {
#         'GML_location': 'POINT(63.31245 13.52648)',
#         'GNSS': {
#             'GRN000SWE': 'POINT(63.0414 13.9679)',
#             'HED000SWE': 'POINT(62.4195 13.5132)',
#         },
#         'age_surface_lithology': 'http://inspire.ec.europa.eu/codelist/GeochronologicEraValue/floian',
#         'depth_m': '2276.05',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5054_2_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5054_2_A',
#         'lithology_geologic_unit': 'http://inspire.ec.europa.eu/codelist/LithologyValue/wacke',
#     },
#     'Chesapeake, CBIS Eyreville-1 Corehole 63G69 (A)': {
#         'GML_location': 'POINT(37.3217 -75.9757)',
#         'depth_m': '2142.7',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5001_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5001_1_A',
#     },
#     'Donghai, CCSD-MH-2K': {
#         'GML_location': 'POINT(34.41 118.67)',
#         'depth_m': '3525.18',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5004_4_D',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5004_4_D',
#     },
#     'Donghai, CCSD-PH': {
#         'GML_location': 'POINT(34.41 118.67)',
#         'depth_m': '2039.54',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5004_4_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5004_4_A',
#     },
#     'Hawaii, HSDP-2a': {
#         'GML_location': 'POINT(19.74 -155.05)',
#         'depth_m': '3099.67',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5027_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5027_1_A',
#     },
#     'Iceland, IDDP-1-A, RN-17': {
#         'GML_location': 'POINT(65.71587 -16.76452)',
#         'GNSS': {
#             'HRIC00ISL': 'POINT(64.9504 -16.924)',
#             'KRAC00ISL': 'POINT(65.6945 -16.7749)',
#             'RHOF00ISL': 'POINT(66.4611 -15.9467)',
#         },
#         'age_surface_lithology': 'http://inspire.ec.europa.eu/codelist/GeochronologicEraValue/pleistocene',
#         'depth_m': '2100.0',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5029_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5029_1_A',
#         'lithology_geologic_unit': 'http://inspire.ec.europa.eu/codelist/LithologyValue/tuffBrecciaAgglomerateOrPyroclasticBreccia',
#     },
#     'Kola SG-3': {
#         'GML_location': 'POINT(69.17 29.28)',
#         'depth_m': '12261.0',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5016_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5016_1_A',
#     },
#     'Koyna, KFD1': {
#         'GML_location': 'POINT(17.283 73.733)',
#         'depth_m': '3012.0',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5058_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5058_1_A',
#     },
#     'Outokumpu': {
#         'GML_location': 'POINT(62.71781 29.06199)',
#         'GNSS': {
#             'NUR200FIN': 'POINT(63.513508262634765 29.12036122650406)',
#             'SLIN00FIN': 'POINT(61.87355658240056 28.725577291922274)',
#         },
#         'age_surface_lithology': 'http://inspire.ec.europa.eu/codelist/GeochronologicEraValue/upperPleistocene',
#         'depth_m': '2516.0',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5015_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5015_1_A',
#         'lithology_geologic_unit': 'http://inspire.ec.europa.eu/codelist/LithologyValue/clay',
#     },
#     'SAFOD-MH-ST1': {
#         'GML_location': 'POINT(35.97417 -120.55185)',
#         'depth_m': '2994.81',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5025_1_C',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5025_1_C',
#     },
#     'SAFOD-PH': {
#         'GML_location': 'POINT(35.97426 -120.55211)',
#         'depth_m': '2154.94',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5025_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5025_1_A',
#     },
#     'Songliao 1A': {
#         'GML_location': 'POINT(46.2408 125.36307)',
#         'depth_m': '4192.0',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5012_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5012_1_A',
#     },
# }

# %% [markdown]
# Create a new Python dictionary that keeps all sensor data, to avoid duplication (one station can be within the limit of multiple boreholes)

# %%
sensordata = {}

# %% [markdown]
# Retrieve GNSS station velocity (last week) and 10 years of position timeseries data, and add the retrieved data to the dictionary

# %%
# # target URLs for selected GNSS GlassFramwork services (from EPOS portal & service documentation):
# URL velocity: https://gnssproducts.epos.ubi.pt/GlassFramework/webresources/products/velocities/<station>/SGO-EPND/enu/json
# URL position: https://gnssproducts.epos.ubi.pt/GlassFramework/webresources/products/timeseries/<station>/SGO-EPND/weekly/enu/covjson/?epoch_start=<datestart>&epoch_end=<dateend>
stationlist = []

# start- and enddate of the position timeseries
yearsback = 10 # years back from present
def calcdatestart(years):
    return(str(date.today() - relativedelta(years=years)))

for key in boreholes.keys():
    for subkey, subvalue in boreholes.get(key).items():
        if subkey == 'GNSS':
            for station in subvalue.keys():
                stationlist.append(station)

# discard duplicate values
stationlist = set(stationlist)

# add keys to the sensordata dictionary for storing GNSS data
positionkey = 'positions' + str(yearsback) + 'years'
sensordata['GNSS'] = {}
sensordata['GNSS']['velocities'] = {}
sensordata['GNSS'][positionkey] = {}

# send requests and store the returned data as string in the dictionary; the json is not converted to python dictonary but can be directly used with tools that require the original json or covjson format
for value in stationlist:
    urlvel = 'https://gnssproducts.epos.ubi.pt/GlassFramework/webresources/products/velocities/' + value + '/SGO-EPND/enu/json'
    urlpos = 'https://gnssproducts.epos.ubi.pt/GlassFramework/webresources/products/timeseries/' + value + '/SGO-EPND/weekly/enu/covjson/?epoch_start=' + str(calcdatestart(yearsback)) + '&epoch_end=' + str(date.today())
    print('URL for velocity:', urlvel)
    print('URL for position timeseries:', urlpos)
    datavel = requests.get(urlvel)
    datapos = requests.get(urlpos)
    # check for unsuccessful requests and empty returns
    try:
        pp(datavel.json()) # throws error if valid json cannot be extracted, without printing, assign to variable, e.g.
        # json_test = datavel.json()
        sensordata['GNSS']['velocities'][value] = datavel.text
    except:
        print("No valid velocity data retrieved for this station.")
    print('─' * 20)
        
    # returns text if empty, needs to be tested differently
    if "type" in datapos.json():
        pp(datapos.json()) # throws error if valid json cannot be extracted, without printing, assign to variable, e.g. json_test = datapos.json()
        sensordata['GNSS'][positionkey][value] = datapos.text
    else:
        print("No valid position data retrieved for this station.")
    print('─' * 20)

    print('─' * 100)
# Out:
# URL for velocity: https://gnssproducts.epos.ubi.pt/GlassFramework/webresources/products/velocities/SLIN00FIN/SGO-EPND/enu/json
# URL for position timeseries: https://gnssproducts.epos.ubi.pt/GlassFramework/webresources/products/timeseries/SLIN00FIN/SGO-EPND/weekly/enu/covjson/?epoch_start=2015-06-16&epoch_end=2025-06-16
# No valid velocity data retrieved for this station.
# ────────────────────
# No valid position data retrieved for this station.
# ────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# URL for velocity: https://gnssproducts.epos.ubi.pt/GlassFramework/webresources/products/velocities/HRIC00ISL/SGO-EPND/enu/json
# URL for position timeseries: https://gnssproducts.epos.ubi.pt/GlassFramework/webresources/products/timeseries/HRIC00ISL/SGO-EPND/weekly/enu/covjson/?epoch_start=2015-06-16&epoch_end=2025-06-16
# No valid velocity data retrieved for this station.
# ────────────────────
# No valid position data retrieved for this station.
# ────────────────────
# ────────────────────────────────────────────────────────────────────────────────────────────────────
# URL for velocity: https://gnssproducts.epos.ubi.pt/GlassFramework/webresources/products/velocities/GRN000SWE/SGO-EPND/enu/json
# URL for position timeseries: https://gnssproducts.epos.ubi.pt/GlassFramework/webresources/products/timeseries/GRN000SWE/SGO-EPND/weekly/enu/covjson/?epoch_start=2015-06-16&epoch_end=2025-06-16
# {
#     'AnalysisCentre': 'SGO-EPND',
#     'DOI': 'unknown',
#     'JSON_Version': '1.0',
#     'Method_URL': 'https://gnssproducts.epos.ubi.pt/methods/SGO_TS.pdf',
#     'ReferenceFrame': 'IGS14',
#     'ReleaseVersion': '2023.1',
#     'Software': 'Midas',
#     'Station_metadata': {
#         'DGW': 'https://gnssdata-epos.oca.eu/#/metadata/marker=GRN000SWE',
#         'MOID': 'https://gnss-metadata.eu/MOID/GRN000SWE',
#         'StationID': 'GRN000SWE',
#         'isEPOS': False,
#     },
#     'Title': 'EPOS-GNSS Velocities',
#     'Unit': 'meters',
#     'results': [
#         {
#             'de/dt': 0.01535,
#             'dn/dt': 0.01494,
#             'du/dt': 0.00806,
#             'first_epoch': '2008-10-12 00:00:00',
#             'last_epoch': '2022-03-13 00:00:00',
#             'ref_elong': 13.96788,
#             'ref_epoch': '2010-01-01 00:00:00',
#             'ref_nlat': 63.04144,
#             'ref_up': 606.04,
#             'reu': 0.0,
#             'rne': -0.0,
#             'rnu': -0.0,
#             'sed': 6e-05,
#             'snd': 6e-05,
#             'sud': 6e-05,
#         },
#     ],
# }
# ────────────────────
# {
#     'domain': {
#         'axes': {
#             't': {
#                 'values': [
#                     '2015-06-21T12:00:00',
#                     '2015-06-28T12:00:00',
#                     '2015-07-05T12:00:00',
#                     '2015-07-12T12:00:00',
#                     '2015-07-19T12:00:00',
#                     '2015-07-26T12:00:00',
#                     '2015-08-02T12:00:00',
#                     '2015-08-16T12:00:00',
#                     '2015-08-23T12:00:00',
#                     '2015-08-30T12:00:00',
#                     '2015-09-06T12:00:00',
#                     '2015-09-13T12:00:00',
#                     '2015-09-20T12:00:00',
#                     '2015-09-27T12:00:00',
#                     '2015-10-04T12:00:00',
#                     '2015-10-11T12:00:00',
#                     '2015-10-18T12:00:00',
#                     '2015-10-25T12:00:00',
#                     '2015-11-01T12:00:00',
#                     '2015-11-08T12:00:00',
#                     '2015-11-15T12:00:00',
#                     '2015-11-22T12:00:00',
#                     '2015-11-29T12:00:00',
#                     '2015-12-06T12:00:00',
#                     '2015-12-13T12:00:00',
#                     '2015-12-20T12:00:00',
#                     '2015-12-27T12:00:00',
#                     '2016-01-03T12:00:00',
#                     '2016-01-10T12:00:00',
#                     '2016-01-17T12:00:00',
#                     '2016-01-24T12:00:00',
#                     '2016-01-31T12:00:00',
#                     '2016-02-07T12:00:00',
#                     '2016-02-14T12:00:00',
#                     '2016-02-21T12:00:00',
#                     '2016-02-28T12:00:00',
#                     '2016-03-06T12:00:00',
#                     '2016-03-13T12:00:00',
#                     '2016-03-20T12:00:00',
#                     '2016-03-27T12:00:00',
#                     '2016-04-03T12:00:00',
#                     '2016-04-10T12:00:00',
#                     '2016-04-17T12:00:00',
#                     '2016-04-24T12:00:00',
#                     '2016-05-01T12:00:00',
#                     '2016-05-08T12:00:00',
#                     '2016-05-15T12:00:00',
#                     '2016-05-22T12:00:00',
#                     '2016-05-29T12:00:00',
#                     '2016-06-05T12:00:00',
#                     '2016-06-12T12:00:00',
#                     '2016-06-19T12:00:00',
#                     '2016-06-26T12:00:00',
#                     '2016-07-03T12:00:00',
#                     '2016-07-10T12:00:00',
#                     '2016-07-17T12:00:00',
#                     '2016-07-24T12:00:00',
#                     '2016-07-31T12:00:00',
#                     '2016-08-07T12:00:00',
#                     '2016-08-14T12:00:00',
#                     '2016-08-21T12:00:00',
#                     '2016-08-28T12:00:00',
#                     '2016-09-04T12:00:00',
#                     '2016-09-11T12:00:00',
#                     '2016-09-18T12:00:00',
#                     '2016-09-25T12:00:00',
#                     '2016-10-02T12:00:00',
#                     '2016-10-09T12:00:00',
#                     '2016-10-16T12:00:00',
#                     '2016-10-23T12:00:00',
#                     '2016-10-30T12:00:00',
#                     '2016-11-06T12:00:00',
#                     '2016-11-20T12:00:00',
#                     '2016-11-27T12:00:00',
#                     '2016-12-04T12:00:00',
#                     '2016-12-11T12:00:00',
#                     '2016-12-18T12:00:00',
#                     '2016-12-25T12:00:00',
#                     '2017-01-01T12:00:00',
#                     '2017-01-08T12:00:00',
#                     '2017-01-15T12:00:00',
#                     '2017-01-22T12:00:00',
#                     '2017-01-29T12:00:00',
#                     '2017-02-05T12:00:00',
#                     '2017-02-12T12:00:00',
#                     '2017-02-19T12:00:00',
#                     '2017-02-26T12:00:00',
#                     '2017-03-05T12:00:00',
#                     '2017-03-12T12:00:00',
#                     '2017-03-19T12:00:00',
#                     '2017-03-26T12:00:00',
#                     '2017-04-02T12:00:00',
#                     '2017-04-09T12:00:00',
#                     '2017-04-16T12:00:00',
#                     '2017-04-23T12:00:00',
#                     '2017-04-30T12:00:00',
#                     '2017-05-07T12:00:00',
#                     '2017-05-14T12:00:00',
#                     '2017-05-21T12:00:00',
#                     '2017-05-28T12:00:00',
#                     '2017-06-04T12:00:00',
#                     '2017-06-11T12:00:00',
#                     '2017-06-18T12:00:00',
#                     '2017-06-25T12:00:00',
#                     '2017-07-02T12:00:00',
#                     '2017-07-09T12:00:00',
#                     '2017-07-16T12:00:00',
#                     '2017-07-23T12:00:00',
#                     '2017-07-30T12:00:00',
#                     '2017-08-06T12:00:00',
#                     '2017-08-13T12:00:00',
#                     '2017-08-20T12:00:00',
#                     '2017-08-27T12:00:00',
#                     '2017-09-03T12:00:00',
#                     '2017-09-10T12:00:00',
#                     '2017-09-17T12:00:00',
#                     '2017-09-24T12:00:00',
#                     '2017-10-01T12:00:00',
#                     '2017-10-08T12:00:00',
#                     '2017-10-15T12:00:00',
#                     '2017-10-22T12:00:00',
#                     '2017-10-29T12:00:00',
#                     '2017-11-05T12:00:00',
#                     '2017-11-12T12:00:00',
#                     '2017-11-19T12:00:00',
#                     '2017-11-26T12:00:00',
#                     '2017-12-03T12:00:00',
#                     '2017-12-10T12:00:00',
#                     '2017-12-17T12:00:00',
#                     '2017-12-24T12:00:00',
#                     '2018-01-14T12:00:00',
#                     '2018-01-21T12:00:00',
#                     '2018-01-28T12:00:00',
#                     '2018-02-25T12:00:00',
#                     '2018-03-04T12:00:00',
#                     '2018-03-11T12:00:00',
#                     '2018-03-25T12:00:00',
#                     '2018-04-01T12:00:00',
#                     '2018-04-08T12:00:00',
#                     '2018-04-15T12:00:00',
#                     '2018-04-22T12:00:00',
#                     '2018-04-29T12:00:00',
#                     '2018-05-06T12:00:00',
#                     '2018-05-13T12:00:00',
#                     '2018-05-20T12:00:00',
#                     '2018-05-27T12:00:00',
#                     '2018-06-03T12:00:00',
#                     '2018-06-10T12:00:00',
#                     '2018-06-17T12:00:00',
#                     '2018-06-24T12:00:00',
#                     '2018-07-01T12:00:00',
#                     '2018-07-08T12:00:00',
#                     '2018-07-15T12:00:00',
#                     '2018-07-22T12:00:00',
#                     '2018-07-29T12:00:00',
#                     '2018-08-05T12:00:00',
#                     '2018-08-12T12:00:00',
#                     '2018-08-19T12:00:00',
#                     '2018-08-26T12:00:00',
#                     '2018-09-02T12:00:00',
#                     '2018-09-09T12:00:00',
#                     '2018-09-16T12:00:00',
#                     '2018-09-23T12:00:00',
#                     '2018-09-30T12:00:00',
#                     '2018-10-07T12:00:00',
#                     '2018-10-14T12:00:00',
#                     '2018-10-21T12:00:00',
#                     '2018-10-28T12:00:00',
#                     '2018-11-04T12:00:00',
#                     '2018-11-11T12:00:00',
#                     '2018-11-18T12:00:00',
#                     '2018-11-25T12:00:00',
#                     '2018-12-02T12:00:00',
#                     '2018-12-09T12:00:00',
#                     '2018-12-16T12:00:00',
#                     '2018-12-23T12:00:00',
#                     '2018-12-30T12:00:00',
#                     '2019-01-06T12:00:00',
#                     '2019-01-13T12:00:00',
#                     '2019-01-20T12:00:00',
#                     '2019-01-27T12:00:00',
#                     '2019-02-03T12:00:00',
#                     '2019-02-10T12:00:00',
#                     '2019-02-17T12:00:00',
#                     '2019-02-24T12:00:00',
#                     '2019-03-03T12:00:00',
#                     '2019-03-10T12:00:00',
#                     '2019-03-17T12:00:00',
#                     '2019-03-24T12:00:00',
#                     '2019-03-31T12:00:00',
#                     '2019-04-07T12:00:00',
#                     '2019-04-14T12:00:00',
#                     '2019-04-21T12:00:00',
#                     '2019-04-28T12:00:00',
#                     '2019-05-05T12:00:00',
#                     '2019-05-12T12:00:00',
#                     '2019-05-19T12:00:00',
#                     '2019-05-26T12:00:00',
#                     '2019-06-02T12:00:00',
#                     '2019-06-09T12:00:00',
#                     '2019-06-16T12:00:00',
#                     '2019-06-23T12:00:00',
#                     '2019-06-30T12:00:00',
#                     '2019-07-07T12:00:00',
#                     '2019-07-14T12:00:00',
#                     '2019-07-21T12:00:00',
#                     '2019-07-28T12:00:00',
#                     '2019-08-04T12:00:00',
#                     '2019-08-11T12:00:00',
#                     '2019-08-18T12:00:00',
#                     '2019-08-25T12:00:00',
#                     '2019-09-01T12:00:00',
#                     '2019-09-08T12:00:00',
#                     '2019-09-15T12:00:00',
#                     '2019-09-22T12:00:00',
#                     '2019-09-29T12:00:00',
#                     '2019-10-06T12:00:00',
#                     '2019-10-13T12:00:00',
#                     '2019-10-20T12:00:00',
#                     '2019-10-27T12:00:00',
#                     '2019-11-03T12:00:00',
#                     '2019-11-10T12:00:00',
#                     '2019-11-17T12:00:00',
#                     '2019-11-24T12:00:00',
#                     '2019-12-01T12:00:00',
#                     '2019-12-08T12:00:00',
#                     '2019-12-15T12:00:00',
#                     '2019-12-22T12:00:00',
#                     '2019-12-29T12:00:00',
#                     '2020-01-05T12:00:00',
#                     '2020-01-12T12:00:00',
#                     '2020-01-19T12:00:00',
#                     '2020-01-26T12:00:00',
#                     '2020-02-02T12:00:00',
#                     '2020-02-09T12:00:00',
#                     '2020-02-16T12:00:00',
#                     '2020-02-23T12:00:00',
#                     '2020-03-01T12:00:00',
#                     '2020-03-08T12:00:00',
#                     '2020-03-15T12:00:00',
#                     '2020-03-22T12:00:00',
#                     '2020-03-29T12:00:00',
#                     '2020-04-05T12:00:00',
#                     '2020-04-12T12:00:00',
#                     '2020-04-19T12:00:00',
#                     '2020-04-26T12:00:00',
#                     '2020-05-03T12:00:00',
#                     '2020-05-10T12:00:00',
#                     '2020-05-17T12:00:00',
#                     '2020-05-24T12:00:00',
#                     '2020-05-31T12:00:00',
#                     '2020-06-07T12:00:00',
#                     '2020-06-14T12:00:00',
#                     '2020-06-21T12:00:00',
#                     '2020-06-28T12:00:00',
#                     '2020-07-05T12:00:00',
#                     '2020-07-12T12:00:00',
#                     '2020-07-19T12:00:00',
#                     '2020-07-26T12:00:00',
#                     '2020-08-02T12:00:00',
#                     '2020-08-09T12:00:00',
#                     '2020-08-16T12:00:00',
#                     '2020-08-23T12:00:00',
#                     '2020-08-30T12:00:00',
#                     '2020-09-06T12:00:00',
#                     '2020-09-13T12:00:00',
#                     '2020-09-20T12:00:00',
#                     '2020-09-27T12:00:00',
#                     '2020-10-04T12:00:00',
#                     '2020-10-11T12:00:00',
#                     '2020-10-18T12:00:00',
#                     '2020-10-25T12:00:00',
#                     '2020-11-01T12:00:00',
#                     '2020-11-08T12:00:00',
#                     '2020-11-15T12:00:00',
#                     '2020-11-22T12:00:00',
#                     '2020-11-29T12:00:00',
#                     '2020-12-06T12:00:00',
#                     '2020-12-13T12:00:00',
#                     '2020-12-20T12:00:00',
#                     '2020-12-27T12:00:00',
#                     '2021-02-21T12:00:00',
#                     '2021-02-28T12:00:00',
#                     '2021-03-07T12:00:00',
#                     '2021-03-14T12:00:00',
#                     '2021-03-21T12:00:00',
#                     '2021-03-28T12:00:00',
#                     '2021-04-04T12:00:00',
#                     '2021-04-11T12:00:00',
#                     '2021-04-18T12:00:00',
#                     '2021-04-25T12:00:00',
#                     '2021-05-02T12:00:00',
#                     '2021-05-09T12:00:00',
#                     '2021-05-16T12:00:00',
#                     '2021-05-23T12:00:00',
#                     '2021-05-30T12:00:00',
#                     '2021-06-06T12:00:00',
#                     '2021-06-13T12:00:00',
#                     '2021-06-20T12:00:00',
#                     '2021-06-27T12:00:00',
#                     '2021-07-04T12:00:00',
#                     '2021-07-11T12:00:00',
#                     '2021-07-18T12:00:00',
#                     '2021-07-25T12:00:00',
#                     '2021-08-01T12:00:00',
#                     '2021-08-08T12:00:00',
#                     '2021-08-15T12:00:00',
#                     '2021-08-22T12:00:00',
#                     '2021-08-29T12:00:00',
#                     '2021-09-05T12:00:00',
#                     '2021-09-12T12:00:00',
#                     '2021-09-19T12:00:00',
#                     '2021-09-26T12:00:00',
#                     '2021-10-03T12:00:00',
#                     '2021-10-10T12:00:00',
#                     '2021-10-17T12:00:00',
#                     '2021-10-24T12:00:00',
#                     '2021-10-31T12:00:00',
#                     '2021-11-07T12:00:00',
#                     '2021-11-14T12:00:00',
#                     '2021-11-21T12:00:00',
#                     '2021-11-28T12:00:00',
#                     '2021-12-05T12:00:00',
#                     '2021-12-12T12:00:00',
#                     '2021-12-19T12:00:00',
#                     '2021-12-26T12:00:00',
#                     '2022-01-02T12:00:00',
#                     '2022-01-09T12:00:00',
#                     '2022-01-16T12:00:00',
#                     '2022-01-23T12:00:00',
#                     '2022-01-30T12:00:00',
#                     '2022-02-06T12:00:00',
#                     '2022-02-13T12:00:00',
#                     '2022-02-20T12:00:00',
#                     '2022-02-27T12:00:00',
#                     '2022-03-06T12:00:00',
#                     '2022-03-13T12:00:00',
#                 ],
#             },
#             'x': {'values': [13.9679]},
#             'y': {'values': [63.0414]},
#             'z': {'values': [605.96]},
#         },
#         'domainType': 'PointSeries',
#         'referencing': [
#             {
#                 'coordinates': ['x', 'y', 'z'],
#                 'system': {
#                     'id': 'http://www.opengis.net/def/crs/OGC/1.3/CRS84',
#                     'type': 'GeographicCRS',
#                 },
#             },
#             {
#                 'coordinates': ['t'],
#                 'system': {'calendar': 'Gregorian', 'type': 'TemporalRS'},
#             },
#         ],
#         'type': 'Domain',
#     },
#     'epos:info': {
#         'date_created': '2025-06-16 10:44:45',
#         'format': 'covjson',
#         'resampling_method': 'null',
#         'tcs': 'wp10',
#         'type': 'CovJSON Timeseries Values',
#         'usage': 'timeseries',
#         'web_service_url': '',
#     },
#     'gnss_europe:info': {
#         'DOI': 'unknown',
#         'analysis_centre': 'SGO-EPND',
#         'apply_offsets': '',
#         'calibration_model': '',
#         'coordinate_type': 'enu',
#         'cut_of_angle': '',
#         'epoch_end': '',
#         'epoch_start': '',
#         'format': 'covjson',
#         'marker': 'GRN000SWE',
#         'otl_model': '',
#         'reference_frame': 'ITRF2014',
#         'remove_outliers': '',
#         'sampling_period': 'weekly',
#         'version': '2023.1',
#     },
#     'parameters': {
#         'E': {
#             'description': {'en': 'Geographic east component (positive east)'},
#             'observedProperty': {
#                 'id': 'https://gnssproducts.epos.ubi.pt/faq',
#                 'label': {'en': 'East component'},
#             },
#             'type': 'Parameter',
#             'unit': {
#                 'label': {'en': 'East'},
#                 'symbol': {
#                     'type': 'https://gnssproducts.epos.ubi.pt/faq',
#                     'value': 'mm',
#                 },
#             },
#         },
#         'N': {
#             'description': {
#                 'en': 'Geographic North component (positive North)',
#             },
#             'observedProperty': {
#                 'id': 'https://gnssproducts.epos.ubi.pt/faq',
#                 'label': {'en': 'North component'},
#             },
#             'type': 'Parameter',
#             'unit': {
#                 'label': {'en': 'North'},
#                 'symbol': {
#                     'type': 'https://gnssproducts.epos.ubi.pt/faq',
#                     'value': 'mm',
#                 },
#             },
#         },
#         'U': {
#             'description': {'en': 'Geographic UP component (positive UP)'},
#             'observedProperty': {
#                 'id': 'https://gnssproducts.epos.ubi.pt/faq',
#                 'label': {'en': 'Up component'},
#             },
#             'type': 'Parameter',
#             'unit': {
#                 'label': {'en': 'Up'},
#                 'symbol': {
#                     'type': 'https://gnssproducts.epos.ubi.pt/faq',
#                     'value': 'mm',
#                 },
#             },
#         },
#     },
#     'ranges': {
#         'E': {
#             'axisNames': ['t'],
#             'dataType': 'float',
#             'shape': [337],
#             'type': 'NdArray',
#             'values': [
#                 399.69620364996786,
#                 400.29550641314034,
#                 401.2323448114316,
#                 399.8900931385267,
#                 400.6326976766792,
#                 401.12559734477225,
#                 401.55874298419195,
#                 402.151745584053,
#                 403.42133482522087,
#                 402.0828315211496,
#                 403.1369055989712,
#                 403.3445858198264,
#                 402.347261735698,
#                 403.2738023131062,
#                 402.44065803475075,
#                 404.5199948271529,
#                 404.82521328579963,
#                 404.98663812038734,
#                 404.0648331451671,
#                 402.6351410724703,
#                 404.1732008770679,
#                 406.6208062828574,
#                 405.84500246068455,
#                 405.4584597801524,
#                 404.5246779218448,
#                 408.0764041851212,
#                 404.6989619660058,
#                 409.5220056156103,
#                 409.5499902499357,
#                 410.51171063973663,
#                 406.81253446792607,
#                 407.36400449016327,
#                 408.5183717734252,
#                 409.8451045757489,
#                 188.81996526638554,
#                 192.70754817676783,
#                 194.6307054238799,
#                 190.93207588001965,
#                 193.39162393304997,
#                 192.93012072543536,
#                 194.0342047863431,
#                 190.3211931079662,
#                 192.45715540953375,
#                 190.97058742015255,
#                 193.70987855046457,
#                 192.52123233004778,
#                 193.10176626703375,
#                 193.6636620072339,
#                 188.59322603486902,
#                 193.9405476763915,
#                 196.71520132428347,
#                 194.76275706769363,
#                 194.39375493150803,
#                 195.6092971838242,
#                 193.68082001036976,
#                 194.4260562541796,
#                 194.9583646189685,
#                 194.13539286777353,
#                 195.3698181928397,
#                 195.42268568069883,
#                 196.91584145603997,
#                 196.89286930313267,
#                 194.34768053646468,
#                 192.95525632632138,
#                 196.28134849057577,
#                 193.7116481170618,
#                 198.38380968097675,
#                 195.40177433886072,
#                 193.89835607723964,
#                 194.41458561099367,
#                 200.24605516245595,
#                 201.24796894259248,
#                 202.83152158229248,
#                 201.1535005049551,
#                 199.14033576633705,
#                 199.05070623755432,
#                 202.54806329415376,
#                 203.48933076399405,
#                 198.4419556955071,
#                 191.36510761618686,
#                 201.89433679369836,
#                 198.77433172434738,
#                 198.4409772656719,
#                 198.46391385492552,
#                 198.41733723733483,
#                 197.80041056445253,
#                 195.16017989696576,
#                 197.6847837958987,
#                 197.32232704751632,
#                 199.19544543389227,
#                 199.52442120927765,
#                 198.4502738600004,
#                 198.11321659532132,
#                 197.88803957668827,
#                 198.4439329573015,
#                 199.47314696670117,
#                 201.8343951792016,
#                 201.86129579458517,
#                 200.86923021642048,
#                 202.19854854974145,
#                 201.99546785053872,
#                 202.09097213932696,
#                 197.94816266190824,
#                 200.41958803440411,
#                 201.9381993323313,
#                 201.12345089655034,
#                 203.98799235171458,
#                 202.56198022410084,
#                 203.20477435461987,
#                 200.30728702982188,
#                 204.43213822746299,
#                 201.91907329103472,
#                 203.87150096298018,
#                 207.60781035105254,
#                 208.88759848286915,
#                 205.15880665296604,
#                 209.28307392618018,
#                 205.9846056037175,
#                 204.70140632351647,
#                 202.5495345710289,
#                 202.19112340571442,
#                 209.5976499114342,
#                 201.9450539344431,
#                 194.57449100599285,
#                 190.79549586925677,
#                 196.14247501747417,
#                 204.46730281300373,
#                 200.12875979671108,
#                 197.44004997247276,
#                 207.32255413981687,
#                 210.16994319982794,
#                 207.76828835473833,
#                 208.8405779438617,
#                 208.1291147403479,
#                 209.7136204067883,
#                 208.05739265605646,
#                 210.89030876811213,
#                 206.60154895528993,
#                 207.3915842497701,
#                 206.5233555332396,
#                 207.36870566533312,
#                 208.13657412838015,
#                 209.26026724172146,
#                 208.51118967664462,
#                 207.29769076808006,
#                 207.58658876519266,
#                 207.60278219588596,
#                 208.31758673956324,
#                 206.50153124978843,
#                 209.48538473791535,
#                 207.76759830528675,
#                 209.021080850872,
#                 210.54579938013933,
#                 208.31365457008212,
#                 212.81101817748595,
#                 212.6942982682621,
#                 210.13570000707816,
#                 209.6877657644404,
#                 211.11229856601082,
#                 210.51301405809937,
#                 213.03250362171954,
#                 215.17598519068312,
#                 214.97646316572613,
#             'HED000SWE': '{"Title":"EPOS-GNSS Velocities","AnalysisCentre":"SGO-EPND","DOI":"unknown","ReferenceFrame":"IGS14","Software":"Midas","ReleaseVersion":"2023.1","Method_URL":"https://gnssproducts.epos.ubi.pt/methods/SGO_TS.pdf","JSON_Version":"1.0","Unit":"meters","Station_metadata":{"StationID":"HED000SWE","isEPOS":false,"MOID":"https://gnss-metadata.eu/MOID/HED000SWE","DGW":"https://gnssdata-epos.oca.eu/#/metadata/marker=HED000SWE"},"results":[{"ref_epoch":"2010-01-01 00:00:00","ref_nlat":62.41946,"ref_elong":13.51321,"ref_up":470.14,"dn/dt":0.01518,"de/dt":0.01563,"du/dt":0.00775,"snd":0.00012,"sed":0.00012,"sud":0.00012,"rne":0.0,"rnu":-0.0,"reu":0.0,"first_epoch":"2008-10-12 00:00:00","last_epoch":"2022-03-13 00:00:00"}]}',
#         },
#     },
# }

# %% [markdown]
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <center><span style="color:green; font-size:3em; font-weight:bold;">Interacting with services and data</span></center><br>

# %% [markdown]
# <center><span style="color:green; font-size:2.5em; font-weight:bold;">Seismology</span></center>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>

# %% [markdown]
# <span style="font-size:1.25em;">Interacting with services and data</span><br>
# <span style="color:green; font-size:2em;">Seismology</span>

# %% [markdown]
# <span style="font-size:1.4em;">Find seismic stations that are up to 150 km from the borehole and that recorded some data during the last decade</span>

# %% [markdown]
# The EIDA federator service was just moved to new IT infrastructure, where it is expected to run fast and reliable. The code below is from a time when it was rather slow and/or unreliable, and therefore, seismic stations were not reliably discoverable through a single service. This code queries the EIDA nodes separately ("poor man's federator"). Code using the EIDA federator follows further down.<br>
# Community standards: data format (e.g. miniSEED) and data transfer (part of European Integrated Data Archive EIDA). The latter supports circular and rectangular spatial filtering.

# %%
# target URL for FDSN station service (from EPOS portal & service documentation):
# https://<node url>/fdsnws/station/1/query?starttime=<starttime>&endtime=<endtime>&latitude=<lat>&longitude=<lon>&maxradius=<maxrad>&minradius=<minrad>

# dictonary of EIDA nodes from EPOS portal/documentation

EIDAnodes = {'KNMI':'orfeus-eu.org',
             'GFZ':'geofon.gfz-potsdam.de',
             'RESIF':'geofon.gfz-potsdam.de',
             'INGV':'webservices.ingv.it',
             'ETHZ':'eida.ethz.ch',
             'BGR':'eida.bgr.de',
             'NIEP':'eida-sc3.infp.ro',
             'KOERI':'eida.koeri.boun.edu.tr',
             'LMU':'erde.geophysik.uni-muenchen.de',
             'NOA':'eida.gein.noa.gr',
             'UIB-NORSAR':'eida.geo.uib.no',
             'ICGC':'ws.icgc.cat'}

distance = 150 # km

# function to create the spatial query from the borehole location (GML Point) and the search distance
def seisspatialfromgmlpoint(gmlpoint, distancekm):
    calc = re.search(r"(\d{1,2}.\d{1,})\s(-{0,1}\d{1,2}.\d{1,})", gmlpoint)
    lat = calc[1]
    lon = calc[2]
    maxrad = round(distancekm/111.1, 4)
    minrad = 0
    return('&latitude=' + str(lat) + '&longitude=' + str(lon) + '&maxradius=' + str(maxrad) + '&minradius=' + str(minrad))

# create the temporal query
timeforurl = 'starttime=' + str(date.today() - relativedelta(years=yearsback)) + '&endtime=' + str(date.today())

# create a dictionary to hold the retrieved information
SEIS = {}

count = -1

for node, address in EIDAnodes.items():
    count = count+1
    for key, value in boreholes.items():
        for subkey, subvalue in value.items():
            if subkey == 'GML_location':
                # make sure that the key in the dictionary is only writen on the first occasion
                if key not in SEIS:
                    SEIS[key] = {}
                baseURL = ('https://' + address + '/fdsnws/station/1/query?')
                spatialforurl = seisspatialfromgmlpoint(subvalue, distance)
                content = requests.get(baseURL + timeforurl + spatialforurl)
                if not content.text:
                    print('No seismic stations found for', key, 'by provider', node)
                else:
                    # print(xmlmd.parseString(content.text).toprettyxml())
                    # SEIS[key][count] = xmltodict.parse(content.text) # xmltodict has unwanted side effects (it puts multiple features in a list, but not single features of the same type, thus it is difficult to access the data in the dictionary)
                    SEIS[key][count] = content.text
                
print('SEIS dictionary:')
pp(SEIS)
# Out:
# No seismic stations found for Chesapeake, CBIS Eyreville-1 Corehole 63G69 (A) by provider KNMI
# No seismic stations found for Donghai, CCSD-PH by provider KNMI
# No seismic stations found for Donghai, CCSD-MH-2K by provider KNMI
# No seismic stations found for Songliao 1A by provider KNMI
# No seismic stations found for Outokumpu by provider KNMI
# No seismic stations found for Kola SG-3 by provider KNMI
# No seismic stations found for SAFOD-PH by provider KNMI
# No seismic stations found for SAFOD-MH-ST1 by provider KNMI
# No seismic stations found for Hawaii, HSDP-2a by provider KNMI
# No seismic stations found for Koyna, KFD1 by provider KNMI
# No seismic stations found for Chesapeake, CBIS Eyreville-1 Corehole 63G69 (A) by provider GFZ
# No seismic stations found for Donghai, CCSD-PH by provider GFZ
# No seismic stations found for Donghai, CCSD-MH-2K by provider GFZ
# No seismic stations found for Songliao 1A by provider GFZ
# No seismic stations found for SAFOD-PH by provider GFZ
# No seismic stations found for SAFOD-MH-ST1 by provider GFZ
# No seismic stations found for Hawaii, HSDP-2a by provider GFZ
# No seismic stations found for Koyna, KFD1 by provider GFZ
# No seismic stations found for Chesapeake, CBIS Eyreville-1 Corehole 63G69 (A) by provider RESIF
# No seismic stations found for Donghai, CCSD-PH by provider RESIF
# No seismic stations found for Donghai, CCSD-MH-2K by provider RESIF
# No seismic stations found for Songliao 1A by provider RESIF
# No seismic stations found for SAFOD-PH by provider RESIF
# No seismic stations found for SAFOD-MH-ST1 by provider RESIF
# No seismic stations found for Hawaii, HSDP-2a by provider RESIF
# No seismic stations found for Koyna, KFD1 by provider RESIF
# No seismic stations found for Chesapeake, CBIS Eyreville-1 Corehole 63G69 (A) by provider INGV
# No seismic stations found for Donghai, CCSD-PH by provider INGV
# No seismic stations found for Donghai, CCSD-MH-2K by provider INGV
# No seismic stations found for Songliao 1A by provider INGV
# No seismic stations found for Outokumpu by provider INGV
# No seismic stations found for Kola SG-3 by provider INGV
# No seismic stations found for SAFOD-PH by provider INGV
# No seismic stations found for SAFOD-MH-ST1 by provider INGV
# No seismic stations found for Hawaii, HSDP-2a by provider INGV
# No seismic stations found for Iceland, IDDP-1-A, RN-17 by provider INGV
# No seismic stations found for COSC-1 A by provider INGV
# No seismic stations found for COSC-2 A by provider INGV
# No seismic stations found for Koyna, KFD1 by provider INGV
# No seismic stations found for Chesapeake, CBIS Eyreville-1 Corehole 63G69 (A) by provider ETHZ
# No seismic stations found for Donghai, CCSD-PH by provider ETHZ
# No seismic stations found for Donghai, CCSD-MH-2K by provider ETHZ
# No seismic stations found for Songliao 1A by provider ETHZ
# No seismic stations found for Outokumpu by provider ETHZ
# No seismic stations found for Kola SG-3 by provider ETHZ
# No seismic stations found for SAFOD-PH by provider ETHZ
# No seismic stations found for SAFOD-MH-ST1 by provider ETHZ
# No seismic stations found for Hawaii, HSDP-2a by provider ETHZ
# No seismic stations found for Iceland, IDDP-1-A, RN-17 by provider ETHZ
# No seismic stations found for COSC-1 A by provider ETHZ
# No seismic stations found for COSC-2 A by provider ETHZ
# No seismic stations found for Koyna, KFD1 by provider ETHZ
# No seismic stations found for Chesapeake, CBIS Eyreville-1 Corehole 63G69 (A) by provider BGR
# No seismic stations found for Donghai, CCSD-PH by provider BGR
# No seismic stations found for Donghai, CCSD-MH-2K by provider BGR
# No seismic stations found for Songliao 1A by provider BGR
# No seismic stations found for Outokumpu by provider BGR
# No seismic stations found for Kola SG-3 by provider BGR
# No seismic stations found for SAFOD-PH by provider BGR
# No seismic stations found for SAFOD-MH-ST1 by provider BGR
# No seismic stations found for Hawaii, HSDP-2a by provider BGR
# No seismic stations found for Iceland, IDDP-1-A, RN-17 by provider BGR
# No seismic stations found for COSC-1 A by provider BGR
# No seismic stations found for COSC-2 A by provider BGR
# No seismic stations found for Koyna, KFD1 by provider BGR
# No seismic stations found for Chesapeake, CBIS Eyreville-1 Corehole 63G69 (A) by provider NIEP
# No seismic stations found for Donghai, CCSD-PH by provider NIEP
# No seismic stations found for Donghai, CCSD-MH-2K by provider NIEP
# No seismic stations found for Songliao 1A by provider NIEP
# No seismic stations found for Outokumpu by provider NIEP
# No seismic stations found for Kola SG-3 by provider NIEP
# No seismic stations found for SAFOD-PH by provider NIEP
# No seismic stations found for SAFOD-MH-ST1 by provider NIEP
# No seismic stations found for Hawaii, HSDP-2a by provider NIEP
# No seismic stations found for Iceland, IDDP-1-A, RN-17 by provider NIEP
# No seismic stations found for COSC-1 A by provider NIEP
# No seismic stations found for COSC-2 A by provider NIEP
# No seismic stations found for Koyna, KFD1 by provider NIEP
# No seismic stations found for Chesapeake, CBIS Eyreville-1 Corehole 63G69 (A) by provider KOERI
# No seismic stations found for Donghai, CCSD-PH by provider KOERI
# No seismic stations found for Donghai, CCSD-MH-2K by provider KOERI
# No seismic stations found for Songliao 1A by provider KOERI
# No seismic stations found for Outokumpu by provider KOERI
# No seismic stations found for Kola SG-3 by provider KOERI
# No seismic stations found for SAFOD-PH by provider KOERI
# No seismic stations found for SAFOD-MH-ST1 by provider KOERI
# No seismic stations found for Hawaii, HSDP-2a by provider KOERI
# No seismic stations found for Iceland, IDDP-1-A, RN-17 by provider KOERI
# No seismic stations found for COSC-1 A by provider KOERI
# No seismic stations found for COSC-2 A by provider KOERI
# No seismic stations found for Koyna, KFD1 by provider KOERI
# No seismic stations found for Chesapeake, CBIS Eyreville-1 Corehole 63G69 (A) by provider LMU
# No seismic stations found for Donghai, CCSD-PH by provider LMU
# No seismic stations found for Donghai, CCSD-MH-2K by provider LMU
# No seismic stations found for Songliao 1A by provider LMU
# No seismic stations found for Outokumpu by provider LMU
# No seismic stations found for Kola SG-3 by provider LMU
# No seismic stations found for SAFOD-PH by provider LMU
# No seismic stations found for SAFOD-MH-ST1 by provider LMU
# No seismic stations found for Hawaii, HSDP-2a by provider LMU
# No seismic stations found for Iceland, IDDP-1-A, RN-17 by provider LMU
# No seismic stations found for COSC-1 A by provider LMU
# No seismic stations found for COSC-2 A by provider LMU
# No seismic stations found for Koyna, KFD1 by provider LMU
# No seismic stations found for Chesapeake, CBIS Eyreville-1 Corehole 63G69 (A) by provider NOA
# No seismic stations found for Donghai, CCSD-PH by provider NOA
# No seismic stations found for Donghai, CCSD-MH-2K by provider NOA
# No seismic stations found for Songliao 1A by provider NOA
# No seismic stations found for Outokumpu by provider NOA
# No seismic stations found for Kola SG-3 by provider NOA
# No seismic stations found for SAFOD-PH by provider NOA
# No seismic stations found for SAFOD-MH-ST1 by provider NOA
# No seismic stations found for Hawaii, HSDP-2a by provider NOA
# No seismic stations found for COSC-1 A by provider NOA
# No seismic stations found for COSC-2 A by provider NOA
# No seismic stations found for Koyna, KFD1 by provider NOA
# No seismic stations found for Chesapeake, CBIS Eyreville-1 Corehole 63G69 (A) by provider UIB-NORSAR
# No seismic stations found for Donghai, CCSD-PH by provider UIB-NORSAR
# No seismic stations found for Donghai, CCSD-MH-2K by provider UIB-NORSAR
# No seismic stations found for Songliao 1A by provider UIB-NORSAR
# No seismic stations found for Outokumpu by provider UIB-NORSAR
# No seismic stations found for SAFOD-PH by provider UIB-NORSAR
# No seismic stations found for SAFOD-MH-ST1 by provider UIB-NORSAR
# No seismic stations found for Hawaii, HSDP-2a by provider UIB-NORSAR
# No seismic stations found for Iceland, IDDP-1-A, RN-17 by provider UIB-NORSAR
# No seismic stations found for Koyna, KFD1 by provider UIB-NORSAR
# No seismic stations found for Chesapeake, CBIS Eyreville-1 Corehole 63G69 (A) by provider ICGC
# No seismic stations found for Donghai, CCSD-PH by provider ICGC
# No seismic stations found for Donghai, CCSD-MH-2K by provider ICGC
# No seismic stations found for Songliao 1A by provider ICGC
# No seismic stations found for Outokumpu by provider ICGC
# No seismic stations found for Kola SG-3 by provider ICGC
# No seismic stations found for SAFOD-PH by provider ICGC
# No seismic stations found for SAFOD-MH-ST1 by provider ICGC
# No seismic stations found for Hawaii, HSDP-2a by provider ICGC
# No seismic stations found for Iceland, IDDP-1-A, RN-17 by provider ICGC
# No seismic stations found for COSC-1 A by provider ICGC
# No seismic stations found for COSC-2 A by provider ICGC
# No seismic stations found for Koyna, KFD1 by provider ICGC
# SEIS dictionary:
# {
#     'COSC-1 A': {
#         0: '<?xml version="1.0" encoding="UTF-8"?><FDSNStationXML xmlns="http://www.fdsn.org/xml/station/1" schemaVersion="1.2"><Source>SeisComP</Source><Sender>KNMI</Sender><Created>2025-06-16T10:44:51.011101Z</Created><Network code="UP" startDate="1980-01-01T00:00:00Z" restrictedStatus="open"><Description>SNSN</Description><Station code="NOD" startDate="1999-09-07T12:00:00Z" restrictedStatus="open"><Latitude>63.4428</Latitude><Longitude>14.8573</Longitude><Elevation>450</Elevation><Site><Name>NOR; Norderaasen, OEstersund</Name><Country> OEstersund</Country></Site><CreationDate>1999-09-07T12:00:00Z</CreationDate></Station></Network></FDSNStationXML>\n',
#         1: '<?xml version="1.0" encoding="UTF-8"?><FDSNStationXML xmlns="http://www.fdsn.org/xml/station/1" schemaVersion="1.2"><Source>SeisComP</Source><Sender>GFZ</Sender><Created>2025-06-16T10:44:53.298032Z</Created><Network code="1G" startDate="2012-01-01T00:00:00Z" endDate="2017-12-31T00:00:00Z" restrictedStatus="open"><Description>ScanArray Core</Description><Identifier type="DOI">10.14470/6T569239</Identifier><Station code="SA39" startDate="2012-10-01T00:00:00Z" endDate="2017-05-22T00:00:00Z" restrictedStatus="open"><Latitude>64.0718</Latitude><Longitude>14.09061</Longitude><Elevation>0</Elevation><Site><Name>Station Valsjoebyn, Sweden</Name><Country>Sweden</Country></Site><CreationDate>2012-10-01T00:00:00Z</CreationDate></Station><Station code="SA44" startDate="2012-09-30T00:00:00Z" endDate="2016-10-12T00:00:00Z" restrictedStatus="open"><Latitude>63.70518</Latitude><Longitude>12.34839</Longitude><Elevation>0</Elevation><Site><Name>Station Jaerpen, Sweden</Name><Country>Sweden</Country></Site><CreationDate>2012-09-30T00:00:00Z</CreationDate></Station><Station code="SA48" startDate="2012-09-29T00:00:00Z" endDate="2015-07-15T00:00:00Z" restrictedStatus="open"><Latitude>63.23047</Latitude><Longitude>13.67801</Longitude><Elevation>0</Elevation><Site><Name>Station Moersil, Sweden</Name><Country>Sweden</Country></Site><CreationDate>2012-09
497</Longitude><Elevation>125</Elevation><Site><Name>Station Ruokolahti, Finland</Name><Country>Finland</Country></Site><CreationDate>2016-09-21T00:00:00Z</CreationDate></Station><Station code="NIF" startDate="2017-06-19T00:00:00Z" restrictedStatus="open"><Latitude>63.390016</Latitude><Longitude>27.810279</Longitude><Elevation>199</Elevation><Site><Name>Station Nilsia, Finland</Name><Country>Finland</Country></Site><CreationDate>2017-06-19T00:00:00Z</CreationDate></Station></Network></FDSNStationXML>\n',
#     },
#     'SAFOD-MH-ST1': {},
#     'SAFOD-PH': {},
#     'Songliao 1A': {},
# }

# %% [markdown]
# Process the information about seismic stations: extract and compile station information.

# %% [markdown]
# List XML attributes with full name space.

# %%
for key, value in SEIS.items():
    for subkey, subvalue in value.items():
        elemList = []
        for elem in ET.fromstring(subvalue).iter():
            elemList.append(elem.tag)
pp(elemList)
# Out:
# [
#     '{http://www.fdsn.org/xml/station/1}FDSNStationXML',
#     '{http://www.fdsn.org/xml/station/1}Source',
#     '{http://www.fdsn.org/xml/station/1}Sender',
#     '{http://www.fdsn.org/xml/station/1}Created',
#     '{http://www.fdsn.org/xml/station/1}Network',
#     '{http://www.fdsn.org/xml/station/1}Description',
#     '{http://www.fdsn.org/xml/station/1}Identifier',
#     '{http://www.fdsn.org/xml/station/1}Station',
#     '{http://www.fdsn.org/xml/station/1}Latitude',
#     '{http://www.fdsn.org/xml/station/1}Longitude',
#     '{http://www.fdsn.org/xml/station/1}Elevation',
#     '{http://www.fdsn.org/xml/station/1}Site',
#     '{http://www.fdsn.org/xml/station/1}Name',
#     '{http://www.fdsn.org/xml/station/1}CreationDate',
# ]

# %% [markdown]
# Extract station information and add it to the borehole dictionary, compile a dictionary of unique seismic stations with data providers.

# %%
stationdict = {}
for key, value in SEIS.items():
    boreholes[key]['SeisStation'] = {}
    for subkey, subvalue in value.items():
        xml = ET.fromstring(subvalue)
        networkcode = xml.find("{http://www.fdsn.org/xml/station/1}Network").get('code')
        provider = xml.find("{http://www.fdsn.org/xml/station/1}Sender").text
        try:
            test = (boreholes[key]['SeisStation'][networkcode])
        except:
            boreholes[key]['SeisStation'][networkcode] = {}
        for network in xml.iter('{http://www.fdsn.org/xml/station/1}Network'):
            for station in network.iter("{http://www.fdsn.org/xml/station/1}Station"):
                stationcode = station.get('code')
                stationdatestart = station.get('startdate')
                stationdateend = station.get('enddate')
                locationgml = 'POINT(' + station.find(".//{http://www.fdsn.org/xml/station/1}Latitude").text + ' ' + station.find(".//{http://www.fdsn.org/xml/station/1}Longitude").text + ' ' + station.find(".//{http://www.fdsn.org/xml/station/1}Elevation").text + ')'
                boreholes[key]['SeisStation'][networkcode][stationcode] = locationgml
                stationdict[stationcode] = [provider, networkcode]

print('Boreholes dictionary:')
pp(boreholes)

print('Seismic stations with data providers and network:')
pp(stationdict)
# Out:
# Boreholes dictionary:
# {
#     'COSC-1 A': {
#         'GML_location': 'POINT(63.40163 13.20292)',
#         'GNSS': {'GRN000SWE': 'POINT(63.0414 13.9679)'},
#         'SeisStation': {
#             '1G': {
#                 'SA35': 'POINT(64.53397 12.40071 0)',
#                 'SA39': 'POINT(64.0718 14.09061 0)',
#                 'SA40': 'POINT(64.04353 11.33531 0)',
#                 'SA43': 'POINT(63.81655 15.51477 0)',
#                 'SA44': 'POINT(63.70518 12.34839 0)',
#                 'SA48': 'POINT(63.23047 13.67801 0)',
#                 'SA51': 'POINT(63.04408 11.6437 0)',
#                 'SA53': 'POINT(62.80045 13.05265 0)',
#                 'SA57': 'POINT(62.44944 14.92132 0)',
#             },
#             'NS': {
#                 'LADE': 'POINT(63.455 10.44583 30)',
#                 'NSS': 'POINT(64.53033 11.96583 102)',
#                 'ODLO': 'POINT(63.455 10.44583 30)',
#                 'ROROS': 'POINT(62.5615 11.55517 0)',
#                 'TBLU': 'POINT(63.42033 10.43033 116)',
#                 'TRON': 'POINT(63.4545 10.43633 34)',
#             },
#             'UP': {'NOD': 'POINT(63.4428 14.8573 450)'},
#         },
#         'age_surface_lithology': 'http://inspire.ec.europa.eu/codelist/GeochronologicEraValue/tonian2',
#         'depth_m': '2495.8',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5054_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5054_1_A',
#         'lithology_geologic_unit': 'http://inspire.ec.europa.eu/codelist/LithologyValue/micaSchist',
#     },
#     'COSC-2 A': {
#         'GML_location': 'POINT(63.31245 13.52648)',
#         'GNSS': {
#             'GRN000SWE': 'POINT(63.0414 13.9679)',
#             'HED000SWE': 'POINT(62.4195 13.5132)',
#         },
#         'SeisStation': {
#             '1G': {
#                 'SA35': 'POINT(64.53397 12.40071 0)',
#                 'SA39': 'POINT(64.0718 14.09061 0)',
#                 'SA40': 'POINT(64.04353 11.33531 0)',
#                 'SA43': 'POINT(63.81655 15.51477 0)',
#                 'SA44': 'POINT(63.70518 12.34839 0)',
#                 'SA48': 'POINT(63.23047 13.67801 0)',
#                 'SA50': 'POINT(63.11401 16.32236 0)',
#                 'SA51': 'POINT(63.04408 11.6437 0)',
#                 'SA53': 'POINT(62.80045 13.05265 0)',
#                 'SA57': 'POINT(62.44944 14.92132 0)',
#             },
#             'NS': {'ROROS': 'POINT(62.5615 11.55517 0)'},
#             'UP': {'NOD': 'POINT(63.4428 14.8573 450)'},
#         },
#         'age_surface_lithology': 'http://inspire.ec.europa.eu/codelist/GeochronologicEraValue/floian',
#         'depth_m': '2276.05',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5054_2_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5054_2_A',
#         'lithology_geologic_unit': 'http://inspire.ec.europa.eu/codelist/LithologyValue/wacke',
#     },
#     'Chesapeake, CBIS Eyreville-1 Corehole 63G69 (A)': {
#         'GML_location': 'POINT(37.3217 -75.9757)',
#         'SeisStation': {},
#         'depth_m': '2142.7',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5001_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5001_1_A',
#     },
#     'Donghai, CCSD-MH-2K': {
#         'GML_location': 'POINT(34.41 118.67)',
#         'SeisStation': {},
#         'depth_m': '3525.18',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5004_4_D',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5004_4_D',
#     },
#     'Donghai, CCSD-PH': {
#         'GML_location': 'POINT(34.41 118.67)',
#         'SeisStation': {},
#         'depth_m': '2039.54',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5004_4_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5004_4_A',
#     },
#     'Hawaii, HSDP-2a': {
#         'GML_location': 'POINT(19.74 -155.05)',
#         'SeisStation': {},
#         'depth_m': '3099.67',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5027_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5027_1_A',
#     },
#     'Iceland, IDDP-1-A, RN-17': {
#         'GML_location': 'POINT(65.71587 -16.76452)',
#         'GNSS': {
#             'HRIC00ISL': 'POINT(64.9504 -16.924)',
#             'KRAC00ISL': 'POINT(65.6945 -16.7749)',
#             'RHOF00ISL': 'POINT(66.4611 -15.9467)',
#         },
#         'SeisStation': {
#             '3P': {
#                 'KRA1': 'POINT(65.7071 -16.764 481.76)',
#                 'TH01': 'POINT(65.899075 -17.011321 308.825)',
#                 'TH02': 'POINT(65.935732 -16.889526 357.441)',
#                 'TH03': 'POINT(65.864229 -16.983212 346.932)',
#                 'TH04': 'POINT(65.936618 -16.963495 302.246)',
#                 'TH05': 'POINT(65.882865 -17.305678 185.702)',
#                 'TH06': 'POINT(65.832884 -16.974195 387.735)',
#                 'TH07': 'POINT(65.868483 -16.782713 471.934)',
#                 'TH08': 'POINT(65.791374 -17.077607 353.45)',
#                 'TH09': 'POINT(65.909193 -17.071909 313.29)',
#                 'THC1': 'POINT(65.881797 -16.963475 340.44)',
#                 'THE1': 'POINT(65.878674 -16.943032 378.1)',
#                 'THR1': 'POINT(66.0027 -17.1925 334.064)',
#                 'THW1': 'POINT(65.8853 -16.975 331.79)',
#                 'URH': 'POINT(64.8202731 -17.146659 1018.6)',
#             },
#             '5S': {
#                 'R0DCC': 'POINT(66.047007 -17.341355 50)',
#                 'R21AC': 'POINT(66.04487 -17.340003 20)',
#                 'R49D9': 'POINT(66.043737 -17.33991 20)',
#                 'R581C': 'POINT(65.9176 -17.57855 50)',
#                 'R5D95': 'POINT(66.12336 -17.90967 50)',
#                 'R689F': 'POINT(66.045272 -17.33579 50)',
#                 'R6A46': 'POINT(66.037861 -17.334744 0)',
#                 'R7EB2': 'POINT(66.047007 -17.341355 0)',
#                 'R7F9F': 'POINT(65.9932 -17.37615 30)',
#                 'R7FD0': 'POINT(66.406649 -16.48957 30)',
#                 'R806B': 'POINT(66.12336 -17.90967 0)',
#                 'RBF67': 'POINT(66.1617 -17.24434 0)',
#                 'RDE68': 'POINT(66.0808 -17.30975 0)',
#                 'RF236': 'POINT(66.04576 -17.338336 20)',
#                 'RF29F': 'POINT(65.9444 -18.3872 37)',
#                 'RF47C': 'POINT(66.045272 -17.33579 0)',
#             },
#             'VI': {'ISKR': 'POINT(64.559998 -18.385999 858)'},
#         },
#         'age_surface_lithology': 'http://inspire.ec.europa.eu/codelist/GeochronologicEraValue/pleistocene',
#         'depth_m': '2100.0',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5029_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5029_1_A',
#         'lithology_geologic_unit': 'http://inspire.ec.europa.eu/codelist/LithologyValue/tuffBrecciaAgglomerateOrPyroclasticBreccia',
#     },
#     'Kola SG-3': {
#         'GML_location': 'POINT(69.17 29.28)',
#         'SeisStation': {
#             'FN': {
#                 'KEV': 'POINT(69.75651 27.00356 81)',
#                 'KMNF': 'POINT(69.14895 26.99611 246)',
#                 'RAJF': 'POINT(68.47512 28.31099 238.4)',
#                 'SA03': 'POINT(70.5034 29.06682 272)',
#                 'SA09': 'POINT(69.45361 30.03907 64)',
#                 'SA10': 'POINT(69.20068 25.69157 186)',
#             },
#             'NS': {'VADS': 'POINT(70.12016 29.365 105)'},
#         },
#         'depth_m': '12261.0',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5016_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5016_1_A',
#     },
#     'Koyna, KFD1': {
#         'GML_location': 'POINT(17.283 73.733)',
#         'SeisStation': {},
#         'depth_m': '3012.0',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5058_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5058_1_A',
#     },
#     'Outokumpu': {
#         'GML_location': 'POINT(62.71781 29.06199)',
#         'GNSS': {
#             'NUR200FIN': 'POINT(63.513508262634765 29.12036122650406)',
#             'SLIN00FIN': 'POINT(61.87355658240056 28.725577291922274)',
#         },
#         'SeisStation': {
#             'HE': {
#                 'JOF': 'POINT(62.9187 31.3092 180)',
#                 'NIF': 'POINT(63.390016 27.810279 199)',
#                 'RUF': 'POINT(61.4247 28.9497 125)',
#                 'SUF': 'POINT(62.7194 26.1474 185)',
#             },
#         },
#         'age_surface_lithology': 'http://inspire.ec.europa.eu/codelist/GeochronologicEraValue/upperPleistocene',
#         'depth_m': '2516.0',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5015_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5015_1_A',
#         'lithology_geologic_unit': 'http://inspire.ec.europa.eu/codelist/LithologyValue/clay',
#     },
#     'SAFOD-MH-ST1': {
#         'GML_location': 'POINT(35.97417 -120.55185)',
#         'SeisStation': {},
#         'depth_m': '2994.81',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5025_1_C',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5025_1_C',
#     },
#     'SAFOD-PH': {
#         'GML_location': 'POINT(35.97426 -120.55211)',
#         'SeisStation': {},
#         'depth_m': '2154.94',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5025_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5025_1_A',
#     },
#     'Songliao 1A': {
#         'GML_location': 'POINT(46.2408 125.36307)',
#         'SeisStation': {},
#         'depth_m': '4192.0',
#         'details': 'https://www.geodata.rocks/Boreholes/SD-5012_1_A',
#         'linked_service': 'https://www.geodata.rocks/Boreholes/SD-5012_1_A',
#     },
# }
# Seismic stations with data providers and network:
# {
#     'ISKR': ['KNMI', 'VI'],
#     'JOF': ['GFZ', 'HE'],
#     'KEV': ['GFZ', 'FN'],
#     'KMNF': ['GFZ', 'FN'],
#     'KRA1': ['GFZ', '3P'],
#     'LADE': ['UIB-NORSAR', 'NS'],
#     'NIF': ['GFZ', 'HE'],
#     'NOD': ['KNMI', 'UP'],
#     'NSS': ['UIB-NORSAR', 'NS'],
#     'ODLO': ['UIB-NORSAR', 'NS'],
#     'R0DCC': ['NOA', '5S'],
#     'R21AC': ['NOA', '5S'],
#     'R49D9': ['NOA', '5S'],
#     'R581C': ['NOA', '5S'],
#     'R5D95': ['NOA', '5S'],
#     'R689F': ['NOA', '5S'],
#     'R6A46': ['NOA', '5S'],
#     'R7EB2': ['NOA', '5S'],
#     'R7F9F': ['NOA', '5S'],
#     'R7FD0': ['NOA', '5S'],
#     'R806B': ['NOA', '5S'],
#     'RAJF': ['GFZ', 'FN'],
#     'RBF67': ['NOA', '5S'],
#     'RDE68': ['NOA', '5S'],
#     'RF236': ['NOA', '5S'],
#     'RF29F': ['NOA', '5S'],
#     'RF47C': ['NOA', '5S'],
#     'ROROS': ['UIB-NORSAR', 'NS'],
#     'RUF': ['GFZ', 'HE'],
#     'SA03': ['GFZ', 'FN'],
#     'SA09': ['GFZ', 'FN'],
#     'SA10': ['GFZ', 'FN'],
#     'SA35': ['GFZ', '1G'],
#     'SA39': ['GFZ', '1G'],
#     'SA40': ['GFZ', '1G'],
#     'SA43': ['GFZ', '1G'],
#     'SA44': ['GFZ', '1G'],
#     'SA48': ['GFZ', '1G'],
#     'SA50': ['GFZ', '1G'],
#     'SA51': ['GFZ', '1G'],
#     'SA53': ['GFZ', '1G'],
#     'SA57': ['GFZ', '1G'],
#     'SUF': ['GFZ', 'HE'],
#     'TBLU': ['UIB-NORSAR', 'NS'],
#     'TH01': ['GFZ', '3P'],
#     'TH02': ['GFZ', '3P'],
#     'TH03': ['GFZ', '3P'],
#     'TH04': ['GFZ', '3P'],
#     'TH05': ['GFZ', '3P'],
#     'TH06': ['GFZ', '3P'],
#     'TH07': ['GFZ', '3P'],
#     'TH08': ['GFZ', '3P'],
#     'TH09': ['GFZ', '3P'],
#     'THC1': ['GFZ', '3P'],
#     'THE1': ['GFZ', '3P'],
#     'THR1': ['GFZ', '3P'],
#     'THW1': ['GFZ', '3P'],
#     'TRON': ['UIB-NORSAR', 'NS'],
#     'URH': ['GFZ', '3P'],
#     'VADS': ['UIB-NORSAR', 'NS'],
# }

# %% [markdown]
# Get data and add these to the data dictionary.<br>
# To not put too much strain on EIDA and the use case, we use the last 12 hours.

# %%
# target URL for FDSN data select service (from EPOS portal & service documentation):
# https://<node url>/fdsnws/dataselect/1/query?network=<network code>&station=<station code>&start=<timestart>&end=<timeend>
from datetime import timezone

# reduce requested time for small data volume in this demonstration
timeforurlmod = 'start=' + ((datetime.now(timezone.utc) - relativedelta(hours=12)).strftime("%Y-%m-%dT%H:%M:%SZ")) + '&end=' + ((datetime.now(timezone.utc) - relativedelta(hours=11, minutes=50)).strftime("%Y-%m-%dT%H:%M:%SZ"))

sensordata['Seismic'] = {}
sensordata['Seismic']['waveforms'] = {}

for key, value in stationdict.items():
    print(key, value[0], value[1])
    print('https://' + EIDAnodes[value[0]] + '/fdsnws/dataselect/1/query?network=' + value[1] + '&station=' + key + '&' + timeforurlmod)
    #sensordata['Seismic']['waveforms'][key] = requests.get('https://' + EIDAnodes[value[0]] + '/fdsnws/dataselect/1/query?network=' + value[1] + '&station=' + key + '&' + timeforurlmod)

print('No simple way forward from here, better use the ObsPy module.')
# Out:
# JOF GFZ HE
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=HE&station=JOF&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# SUF GFZ HE
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=HE&station=SUF&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# RUF GFZ HE
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=HE&station=RUF&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# NIF GFZ HE
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=HE&station=NIF&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# RAJF GFZ FN
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=FN&station=RAJF&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# KMNF GFZ FN
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=FN&station=KMNF&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# SA09 GFZ FN
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=FN&station=SA09&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# SA10 GFZ FN
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=FN&station=SA10&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# SA03 GFZ FN
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=FN&station=SA03&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# KEV GFZ FN
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=FN&station=KEV&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# VADS UIB-NORSAR NS
# https://eida.geo.uib.no/fdsnws/dataselect/1/query?network=NS&station=VADS&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# ISKR KNMI VI
# https://orfeus-eu.org/fdsnws/dataselect/1/query?network=VI&station=ISKR&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# TH01 GFZ 3P
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=3P&station=TH01&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# TH02 GFZ 3P
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=3P&station=TH02&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# TH03 GFZ 3P
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=3P&station=TH03&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# TH04 GFZ 3P
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=3P&station=TH04&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# TH05 GFZ 3P
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=3P&station=TH05&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# TH06 GFZ 3P
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=3P&station=TH06&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# TH07 GFZ 3P
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=3P&station=TH07&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# TH08 GFZ 3P
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=3P&station=TH08&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# TH09 GFZ 3P
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=3P&station=TH09&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# THR1 GFZ 3P
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=3P&station=THR1&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# THW1 GFZ 3P
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=3P&station=THW1&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# THC1 GFZ 3P
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=3P&station=THC1&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# THE1 GFZ 3P
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=3P&station=THE1&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# KRA1 GFZ 3P
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=3P&station=KRA1&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# URH GFZ 3P
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=3P&station=URH&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# R7F9F NOA 5S
# https://eida.gein.noa.gr/fdsnws/dataselect/1/query?network=5S&station=R7F9F&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# R689F NOA 5S
# https://eida.gein.noa.gr/fdsnws/dataselect/1/query?network=5S&station=R689F&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# RF29F NOA 5S
# https://eida.gein.noa.gr/fdsnws/dataselect/1/query?network=5S&station=RF29F&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# R581C NOA 5S
# https://eida.gein.noa.gr/fdsnws/dataselect/1/query?network=5S&station=R581C&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# R6A46 NOA 5S
# https://eida.gein.noa.gr/fdsnws/dataselect/1/query?network=5S&station=R6A46&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# R7FD0 NOA 5S
# https://eida.gein.noa.gr/fdsnws/dataselect/1/query?network=5S&station=R7FD0&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# R21AC NOA 5S
# https://eida.gein.noa.gr/fdsnws/dataselect/1/query?network=5S&station=R21AC&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# RDE68 NOA 5S
# https://eida.gein.noa.gr/fdsnws/dataselect/1/query?network=5S&station=RDE68&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# RF236 NOA 5S
# https://eida.gein.noa.gr/fdsnws/dataselect/1/query?network=5S&station=RF236&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# R0DCC NOA 5S
# https://eida.gein.noa.gr/fdsnws/dataselect/1/query?network=5S&station=R0DCC&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# R7EB2 NOA 5S
# https://eida.gein.noa.gr/fdsnws/dataselect/1/query?network=5S&station=R7EB2&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# R49D9 NOA 5S
# https://eida.gein.noa.gr/fdsnws/dataselect/1/query?network=5S&station=R49D9&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# RF47C NOA 5S
# https://eida.gein.noa.gr/fdsnws/dataselect/1/query?network=5S&station=RF47C&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# RBF67 NOA 5S
# https://eida.gein.noa.gr/fdsnws/dataselect/1/query?network=5S&station=RBF67&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# R5D95 NOA 5S
# https://eida.gein.noa.gr/fdsnws/dataselect/1/query?network=5S&station=R5D95&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# R806B NOA 5S
# https://eida.gein.noa.gr/fdsnws/dataselect/1/query?network=5S&station=R806B&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# NOD KNMI UP
# https://orfeus-eu.org/fdsnws/dataselect/1/query?network=UP&station=NOD&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# SA39 GFZ 1G
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=1G&station=SA39&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# SA44 GFZ 1G
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=1G&station=SA44&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# SA48 GFZ 1G
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=1G&station=SA48&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# SA51 GFZ 1G
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=1G&station=SA51&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# SA57 GFZ 1G
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=1G&station=SA57&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# SA53 GFZ 1G
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=1G&station=SA53&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# SA35 GFZ 1G
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=1G&station=SA35&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# SA40 GFZ 1G
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=1G&station=SA40&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# SA43 GFZ 1G
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=1G&station=SA43&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# ROROS UIB-NORSAR NS
# https://eida.geo.uib.no/fdsnws/dataselect/1/query?network=NS&station=ROROS&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# LADE UIB-NORSAR NS
# https://eida.geo.uib.no/fdsnws/dataselect/1/query?network=NS&station=LADE&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# NSS UIB-NORSAR NS
# https://eida.geo.uib.no/fdsnws/dataselect/1/query?network=NS&station=NSS&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# ODLO UIB-NORSAR NS
# https://eida.geo.uib.no/fdsnws/dataselect/1/query?network=NS&station=ODLO&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# TBLU UIB-NORSAR NS
# https://eida.geo.uib.no/fdsnws/dataselect/1/query?network=NS&station=TBLU&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# TRON UIB-NORSAR NS
# https://eida.geo.uib.no/fdsnws/dataselect/1/query?network=NS&station=TRON&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# SA50 GFZ 1G
# https://geofon.gfz-potsdam.de/fdsnws/dataselect/1/query?network=1G&station=SA50&start=2025-06-15T22:46:30Z&end=2025-06-15T22:56:30Z
# No simple way forward from here, better use the ObsPy module.

# %%
from obspy.clients.fdsn import Client
from obspy.core import UTCDateTime

sensordata['Seismic'] = {}
sensordata['Seismic']['waveforms'] = {}

timestart = UTCDateTime((datetime.now(timezone.utc) - relativedelta(hours=12)))
timeend = UTCDateTime((datetime.now(timezone.utc) - relativedelta(hours=0)))

nodataforstation = []

for key, value in stationdict.items():
    try:
        st = Client('https://' + EIDAnodes[value[0]]).get_waveforms(value[1],key,"00","*Z",timestart,timeend)
    except:
        nodataforstation.append({str(key): str(EIDAnodes[value[0]])})
    else:
        try:
            sensordata['Seismic']['waveforms'][key]
        except:
            sensordata['Seismic']['waveforms'][key] = {}
        sensordata['Seismic']['waveforms'][key][value[1]] = st

print('No data available for this time intervall for station | from provider')

for item in nodataforstation:
    for station, provider in item.items():
        print(station, "|", provider)

# for station, content in sensordata['Seismic']['waveforms'].items():
#     for network, data in content.items():
#         data.plot()
# Out:
# No data available for this time intervall for station | from provider
# JOF | geofon.gfz-potsdam.de
# SUF | geofon.gfz-potsdam.de
# RUF | geofon.gfz-potsdam.de
# NIF | geofon.gfz-potsdam.de
# RAJF | geofon.gfz-potsdam.de
# KMNF | geofon.gfz-potsdam.de
# SA09 | geofon.gfz-potsdam.de
# SA10 | geofon.gfz-potsdam.de
# SA03 | geofon.gfz-potsdam.de
# KEV | geofon.gfz-potsdam.de
# ISKR | orfeus-eu.org
# TH01 | geofon.gfz-potsdam.de
# TH02 | geofon.gfz-potsdam.de
# TH03 | geofon.gfz-potsdam.de
# TH04 | geofon.gfz-potsdam.de
# TH05 | geofon.gfz-potsdam.de
# TH06 | geofon.gfz-potsdam.de
# TH07 | geofon.gfz-potsdam.de
# TH08 | geofon.gfz-potsdam.de
# TH09 | geofon.gfz-potsdam.de
# THR1 | geofon.gfz-potsdam.de
# THW1 | geofon.gfz-potsdam.de
# THC1 | geofon.gfz-potsdam.de
# THE1 | geofon.gfz-potsdam.de
# KRA1 | geofon.gfz-potsdam.de
# URH | geofon.gfz-potsdam.de
# R7F9F | eida.gein.noa.gr
# R689F | eida.gein.noa.gr
# RF29F | eida.gein.noa.gr
# R581C | eida.gein.noa.gr
# R6A46 | eida.gein.noa.gr
# R7FD0 | eida.gein.noa.gr
# R21AC | eida.gein.noa.gr
# RDE68 | eida.gein.noa.gr
# RF236 | eida.gein.noa.gr
# R0DCC | eida.gein.noa.gr
# R7EB2 | eida.gein.noa.gr
# R49D9 | eida.gein.noa.gr
# RF47C | eida.gein.noa.gr
# RBF67 | eida.gein.noa.gr
# R5D95 | eida.gein.noa.gr
# R806B | eida.gein.noa.gr
# NOD | orfeus-eu.org
# SA39 | geofon.gfz-potsdam.de
# SA44 | geofon.gfz-potsdam.de
# SA48 | geofon.gfz-potsdam.de
# SA51 | geofon.gfz-potsdam.de
# SA57 | geofon.gfz-potsdam.de
# SA53 | geofon.gfz-potsdam.de
# SA35 | geofon.gfz-potsdam.de
# SA40 | geofon.gfz-potsdam.de
# SA43 | geofon.gfz-potsdam.de
# ODLO | eida.geo.uib.no
# TBLU | eida.geo.uib.no
# TRON | eida.geo.uib.no
# SA50 | geofon.gfz-potsdam.de

# %% [markdown]
# Not all stations that have collected some data during the last 10 years have data from the last 12 hours.<br>
# This might be due to termination or a delay in publishing the data.

# %%
for station, content in sensordata['Seismic']['waveforms'].items():
    for network, data in content.items():
        data.plot()

# %% [markdown]
# <span style="font-size:1.25em;">Interacting with services and data</span><br>
# <span style="color:green; font-size:2em;">Seismology</span>

# %% [markdown]
# <span style="font-size:1.4em;">__Use ObsPy__ to find seismic stations that are up to 150 km from the borehole and that recorded some data during the last decade</span>

# %% [markdown]
# Let the module do the federating ("routing").

# %%
# import the federator ("routing client") and the date-time converter
from obspy.clients.fdsn import RoutingClient
from obspy.core import UTCDateTime

# set the routing service
client = RoutingClient("eida-routing")

# Pitfall: Passing all arguments to the ObsPy functions (and other Python functions) in a single variable does not work! Casting to string has no effect. 
#          It is not interpreted in the same way as arguments passed to the function as a written string literal. Casting to string does not help.
# function to create the arguments for the spatial query from the borehole location (GML Point) and the search distance
def obspyspatialfromgmlpoint(gmlpoint, distancekm):
    calc = re.search(r"(\d{1,2}.\d{1,})\s(-{0,1}\d{1,2}.\d{1,})", gmlpoint)
    dict = {
        "lat": calc[1],
        "lon": calc[2],
        "maxrad": round(distancekm/111.1, 4),
        "minrad": 0
    }
    return(dict)

# time for the temporal query
timeforobspy = {
    "starttime": str(UTCDateTime(date.today() - relativedelta(years=10))),
    "endtime": str(UTCDateTime(date.today() - relativedelta(years=0)))
}

# create a dictionary to hold the retrieved ObsPy "inventories"
OBSPY = {}

for key, value in boreholes.items():
    for subkey, subvalue in value.items():
        if subkey == 'GML_location':
            # make sure that the key in the dictionary is only writen on the first occasion
            if key not in OBSPY:
                OBSPY[key] = {}
            spatialforobspy = obspyspatialfromgmlpoint(subvalue, 150)
            stations = client.get_stations(channel="LHZ", starttime=timeforobspy['starttime'], endtime=timeforobspy['endtime'], latitude=spatialforobspy['lat'], longitude=spatialforobspy['lon'], maxradius=spatialforobspy['maxrad'], minradius=spatialforobspy['minrad'])
            OBSPY[key]['inventory'] = stations

# %%
for key, value in OBSPY.items():
    print('\033[1m' + key + ":" + "\033[0;0m")
    print(value['inventory'])
# Out:
# Chesapeake, CBIS Eyreville-1 Corehole 63G69 (A):
# Inventory created at 2025-06-16T10:46:50.731364Z
# 	Created by: ObsPy 1.4.2
# 		    https://www.obspy.org
# 	Sending institution: ObsPy FDSN Routing 1.4.2
# 	Contains:
# 		Networks (0):
#
# 		Stations (0):
#
# 		Channels (0):
#
# Donghai, CCSD-PH:
# Inventory created at 2025-06-16T10:46:54.995734Z
# 	Created by: ObsPy 1.4.2
# 		    https://www.obspy.org
# 	Sending institution: ObsPy FDSN Routing 1.4.2
# 	Contains:
# 		Networks (0):
#
# 		Stations (0):
#
# 		Channels (0):
#
# Donghai, CCSD-MH-2K:
# Inventory created at 2025-06-16T10:46:59.191905Z
# 	Created by: ObsPy 1.4.2
# 		    https://www.obspy.org
# 	Sending institution: ObsPy FDSN Routing 1.4.2
# 	Contains:
# 		Networks (0):
#
# 		Stations (0):
#
# 		Channels (0):
#
# Songliao 1A:
# Inventory created at 2025-06-16T10:47:03.377114Z
# 	Created by: ObsPy 1.4.2
# 		    https://www.obspy.org
# 	Sending institution: ObsPy FDSN Routing 1.4.2
# 	Contains:
# 		Networks (0):
#
# 		Stations (0):
#
# 		Channels (0):
#
# Outokumpu:
# Inventory created at 2025-06-16T10:47:07.723949Z
# 	Created by: ObsPy 1.4.2
# 		    https://www.obspy.org
# 	Sending institution: ObsPy FDSN Routing 1.4.2,SeisComP (GFZ)
# 	Contains:
# 		Networks (1):
# 			HE
# 		Stations (4):
# 			HE.JOF (Station Hattuvaara, Finland)
# 			HE.NIF (Station Nilsia, Finland)
# 			HE.RUF (Station Ruokolahti, Finland)
# 			HE.SUF (Station Sumiainen, Finland)
# 		Channels (0):
#
# Kola SG-3:
# Inventory created at 2025-06-16T10:47:12.113194Z
# 	Created by: ObsPy 1.4.2
# 		    https://www.obspy.org
# 	Sending institution: ObsPy FDSN Routing 1.4.2,SeisComP (GFZ,UIB-NORSAR)
# 	Contains:
# 		Networks (4):
# 			1G, FN, HE, NS
# 		Stations (7):
# 			1G.SA03 (Station Monteret, Norway)
# 			1G.SA09 (Station Svanvik, Norway)
# 			1G.SA10 (Station Mareveadji, Norway)
# 			FN.KMNF (SGO Station Inari, Kaamanen, Finland)
# 			FN.RAJF (SGO Station Inari, Raja-jooseppi, Finland)
# 			HE.KEV (Station Kevo, Finland)
# 			NS.VADS (Vadso, Norway)
# 		Channels (0):
#
# SAFOD-PH:
# Inventory created at 2025-06-16T10:47:16.249534Z
# 	Created by: ObsPy 1.4.2
# 		    https://www.obspy.org
# 	Sending institution: ObsPy FDSN Routing 1.4.2
# 	Contains:
# 		Networks (0):
#
# 		Stations (0):
#
# 		Channels (0):
#
# SAFOD-MH-ST1:
# Inventory created at 2025-06-16T10:47:20.393989Z
# 	Created by: ObsPy 1.4.2
# 		    https://www.obspy.org
# 	Sending institution: ObsPy FDSN Routing 1.4.2
# 	Contains:
# 		Networks (0):
#
# 		Stations (0):
#
# 		Channels (0):
#
# Hawaii, HSDP-2a:
# Inventory created at 2025-06-16T10:47:24.633211Z
# 	Created by: ObsPy 1.4.2
# 		    https://www.obspy.org
# 	Sending institution: ObsPy FDSN Routing 1.4.2
# 	Contains:
# 		Networks (0):
#
# 		Stations (0):
#
# 		Channels (0):
#
# Iceland, IDDP-1-A, RN-17:
# Inventory created at 2025-06-16T10:47:28.861693Z
# 	Created by: ObsPy 1.4.2
# 		    https://www.obspy.org
# 	Sending institution: ObsPy FDSN Routing 1.4.2,SeisComP (GFZ,KNMI,NOA)
# 	Contains:
# 		Networks (4):
# 			3P, 5L, 5S, VI
# 		Stations (32):
# 			3P.KRA1 (KRA1)
# 			3P.TH01 (TH01)
# 			3P.TH02 (TH02)
# 			3P.TH03 (TH03)
# 			3P.TH04 (TH04)
# 			3P.TH05 (TH05)
# 			3P.TH06 (TH06)
# 			3P.TH07 (TH07)
# 			3P.TH08 (TH08)
# 			3P.TH09 (TH09)
# 			3P.THC1 (THC1)
# 			3P.THE1 (THE1)
# 			3P.THR1 (THR1)
# 			3P.THW1 (THW1)
# 			5L.URH (Urdarhals, Vatnajoekull, Iceland)
# 			5S.R0DCC (Icelandic Strong-motion Arrays (ICEARRAY))
# 			5S.R21AC (Icelandic Strong-motion Arrays (ICEARRAY))
# 			5S.R49D9 (Icelandic Strong-motion Arrays (ICEARRAY))
# 			5S.R581C (Icelandic Strong-motion Arrays (ICEARRAY))
# 			5S.R5D95 (Icelandic Strong-motion Arrays (ICEARRAY))
# 			5S.R689F (Icelandic Strong-motion Arrays (ICEARRAY))
# 			5S.R6A46 (Icelandic Strong-motion Arrays (ICEARRAY))
# 			5S.R7EB2 (Icelandic Strong-motion Arrays (ICEARRAY))
# 			5S.R7F9F (Icelandic Strong-motion Arrays (ICEARRAY))
# 			5S.R7FD0 (Icelandic Strong-motion Arrays (ICEARRAY))
# 			5S.R806B (Icelandic Strong-motion Arrays (ICEARRAY))
# 			5S.RBF67 (Icelandic Strong-motion Arrays (ICEARRAY))
# 			5S.RDE68 (Icelandic Strong-motion Arrays (ICEARRAY))
# 			5S.RF236 (Icelandic Strong-motion Arrays (ICEARRAY))
# 			5S.RF29F (Icelandic Strong-motion Arrays (ICEARRAY))
# 			5S.RF47C (Icelandic Strong-motion Arrays (ICEARRAY))
# 			VI.ISKR (SKROKKALDA, ICELAND)
# 		Channels (0):
#
# COSC-1 A:
# Inventory created at 2025-06-16T10:47:34.062320Z
# 	Created by: ObsPy 1.4.2
# 		    https://www.obspy.org
# 	Sending institution: ObsPy FDSN Routing 1.4.2,SeisComP (GFZ,KNMI,UIB-NORSAR)
# 	Contains:
# 		Networks (3):
# 			1G, NS, UP
# 		Stations (16):
# 			1G.SA35 (Station Grong, Norway)
# 			1G.SA39 (Station Valsjoebyn, Sweden)
# 			1G.SA40 (Station Steinkjer, Norway)
# 			1G.SA43 (Station Tullingsas, Sweden)
# 			1G.SA44 (Station Jaerpen, Sweden)
# 			1G.SA48 (Station Moersil, Sweden)
# 			1G.SA51 (Station Tydal, Norway)
# 			1G.SA53 (Station Storsjoekapell, Sweden)
# 			1G.SA57 (Station Oeverturingen, Sweden)
# 			NS.LADE (LADE )
# 			NS.NSS (Namsos, Norway)
# 			NS.ODLO (Temporary site at NGU, Trondheim, Norway)
# 			NS.ROROS (Roros, Norway)
# 			NS.TBLU (Trondheim, Norway)
# 			NS.TRON (Trondheim, Norway)
# 			UP.NOD (NOR; Norderaasen, OEstersund)
# 		Channels (0):
#
# COSC-2 A:
# Inventory created at 2025-06-16T10:47:38.292612Z
# 	Created by: ObsPy 1.4.2
# 		    https://www.obspy.org
# 	Sending institution: ObsPy FDSN Routing 1.4.2,SeisComP (GFZ,KNMI,UIB-NORSAR)
# 	Contains:
# 		Networks (3):
# 			1G, NS, UP
# 		Stations (12):
# 			1G.SA35 (Station Grong, Norway)
# 			1G.SA39 (Station Valsjoebyn, Sweden)
# 			1G.SA40 (Station Steinkjer, Norway)
# 			1G.SA43 (Station Tullingsas, Sweden)
# 			1G.SA44 (Station Jaerpen, Sweden)
# 			1G.SA48 (Station Moersil, Sweden)
# 			1G.SA50 (Station Hammarstrand, Sweden)
# 			1G.SA51 (Station Tydal, Norway)
# 			1G.SA53 (Station Storsjoekapell, Sweden)
# 			1G.SA57 (Station Oeverturingen, Sweden)
# 			NS.ROROS (Roros, Norway)
# 			UP.NOD (NOR; Norderaasen, OEstersund)
# 		Channels (0):
#
# Koyna, KFD1:
# Inventory created at 2025-06-16T10:47:42.650641Z
# 	Created by: ObsPy 1.4.2
# 		    https://www.obspy.org
# 	Sending institution: ObsPy FDSN Routing 1.4.2
# 	Contains:
# 		Networks (0):
#
# 		Stations (0):
#
# 		Channels (0):

# %%
OBSPY['Kola SG-3']['inventory'].plot()

# %% [markdown]
# Get the data!

# %%
# inspect the inventory
OBSPY['Kola SG-3']['inventory']
# Out:
# Inventory created at 2025-06-16T10:47:12.113194Z
# 	Created by: ObsPy 1.4.2
# 		    https://www.obspy.org
# 	Sending institution: ObsPy FDSN Routing 1.4.2,SeisComP (GFZ,UIB-NORSAR)
# 	Contains:
# 		Networks (4):
# 			1G, FN, HE, NS
# 		Stations (7):
# 			1G.SA03 (Station Monteret, Norway)
# 			1G.SA09 (Station Svanvik, Norway)
# 			1G.SA10 (Station Mareveadji, Norway)
# 			FN.KMNF (SGO Station Inari, Kaamanen, Finland)
# 			FN.RAJF (SGO Station Inari, Raja-jooseppi, Finland)
# 			HE.KEV (Station Kevo, Finland)
# 			NS.VADS (Vadso, Norway)
# 		Channels (0):

# %%
print(OBSPY['Kola SG-3']['inventory'][0])
# Out:
# Network NS (UIB)
# 	Station Count: None/None (Selected/Total)
# 	1980-01-01T00:00:00.000000Z - --
# 	Access: open
# 	Contains:
# 		Stations (1):
# 			NS.VADS (Vadso, Norway)
# 		Channels (0):

# %%
# how does the object at network level look like?
dir(OBSPY['Kola SG-3']['inventory'][0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__short_str__',
#  '__sizeof__',
#  '__slotnames__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_alternate_code',
#  '_code',
#  '_historical_code',
#  '_identifiers',
#  '_operators',
#  '_repr_pretty_',
#  '_selected_number_of_stations',
#  '_source_id',
#  '_stations',
#  '_total_number_of_stations',
#  'alternate_code',
#  'code',
#  'comments',
#  'copy',
#  'data_availability',
#  'description',
#  'end_date',
#  'get_channel_metadata',
#  'get_contents',
#  'get_coordinates',
#  'get_orientation',
#  'get_response',
#  'historical_code',
#  'identifiers',
#  'is_active',
#  'operators',
#  'plot',
#  'plot_response',
#  'restricted_status',
#  'select',
#  'selected_number_of_stations',
#  'source_id',
#  'start_date',
#  'stations',
#  'total_number_of_stations']

# %%
# and how does the object at station level look like?
dir(OBSPY['Kola SG-3']['inventory'][0][0])
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__slotnames__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_alternate_code',
#  '_code',
#  '_creation_date',
#  '_elevation',
#  '_equipments',
#  '_external_references',
#  '_historical_code',
#  '_identifiers',
#  '_latitude',
#  '_longitude',
#  '_operators',
#  '_repr_pretty_',
#  '_selected_number_of_channels',
#  '_source_id',
#  '_termination_date',
#  '_total_number_of_channels',
#  '_water_level',
#  'alternate_code',
#  'channels',
#  'code',
#  'comments',
#  'copy',
#  'creation_date',
#  'data_availability',
#  'description',
#  'elevation',
#  'end_date',
#  'equipments',
#  'external_references',
#  'geology',
#  'get_contents',
#  'historical_code',
#  'identifiers',
#  'is_active',
#  'latitude',
#  'longitude',
#  'operators',
#  'plot',
#  'restricted_status',
#  'select',
#  'selected_number_of_channels',
#  'site',
#  'source_id',
#  'start_date',
#  'termination_date',
#  'total_number_of_channels',
#  'vault',
#  'water_level']

# %%
# get network and station codes for single inventory and check start and stop times of data acquisition
for network in OBSPY['Kola SG-3']['inventory']:
    for station in network:
        print(network.code + ', ' + station.code)
        print(station.start_date, station.end_date)
# Out:
# NS, VADS
# 2016-09-07T00:00:00.000000Z 2029-12-31T00:00:00.000000Z
# FN, RAJF
# 2024-04-22T00:00:00.000000Z None
# FN, KMNF
# 2024-04-22T00:00:00.000000Z None
# 1G, SA09
# 2013-09-23T00:00:00.000000Z 2016-05-09T00:00:00.000000Z
# 1G, SA10
# 2013-09-25T00:00:00.000000Z 2016-05-11T00:00:00.000000Z
# 1G, SA03
# 2012-08-03T00:00:00.000000Z 2017-08-31T00:00:00.000000Z
# HE, KEV
# 1980-01-01T00:00:00.000000Z None

# %%
# generalise for the dictionary and only list stations that are presently active 
for borehole, content in OBSPY.items():
    for network in content['inventory']:
        for station in network:
            if not station.end_date:
                print(borehole)
                print('  Network:' + network.code)
                print('    Station:' + station.code, station.start_date, station.end_date)
                # print('      Channels:' + str(station.channels))
# Out:
# Outokumpu
#   Network:HE
#     Station:JOF 2006-01-01T00:00:00.000000Z None
# Outokumpu
#   Network:HE
#     Station:SUF 2006-01-01T00:00:00.000000Z None
# Outokumpu
#   Network:HE
#     Station:RUF 2016-09-21T00:00:00.000000Z None
# Outokumpu
#   Network:HE
#     Station:NIF 2017-06-19T00:00:00.000000Z None
# Kola SG-3
#   Network:FN
#     Station:RAJF 2024-04-22T00:00:00.000000Z None
# Kola SG-3
#   Network:FN
#     Station:KMNF 2024-04-22T00:00:00.000000Z None
# Kola SG-3
#   Network:HE
#     Station:KEV 1980-01-01T00:00:00.000000Z None
# Iceland, IDDP-1-A, RN-17
#   Network:VI
#     Station:ISKR 1996-10-01T00:00:00.000000Z None
# COSC-1 A
#   Network:UP
#     Station:NOD 1999-09-07T12:00:00.000000Z None
# COSC-2 A
#   Network:UP
#     Station:NOD 1999-09-07T12:00:00.000000Z None

# %%
# get the data with client.get_waveforms("<network>","<station>","<location>","<channel>","<starttime>","<endtime>")
# not sure about location, we use all locations (instruments) "*"
# no channel information, we use all channels "*"
# test how to extract this information

active_stations = []

for borehole, content in OBSPY.items():
    for network in content['inventory']:
        for station in network:
            if not station.end_date:
                active_stations.append([network.code, station.code])
print(active_stations)
# create a list of tuples, make the tuples unique, and convert back to a list
unique_active_stations = [list(x) for x in set(tuple(x) for x in active_stations)]
print(unique_active_stations)
# Out:
# [['HE', 'JOF'], ['HE', 'SUF'], ['HE', 'RUF'], ['HE', 'NIF'], ['FN', 'RAJF'], ['FN', 'KMNF'], ['HE', 'KEV'], ['VI', 'ISKR'], ['UP', 'NOD'], ['UP', 'NOD']]
# [['HE', 'JOF'], ['HE', 'KEV'], ['HE', 'SUF'], ['HE', 'RUF'], ['VI', 'ISKR'], ['FN', 'KMNF'], ['HE', 'NIF'], ['FN', 'RAJF'], ['UP', 'NOD']]

# %%
tstart = UTCDateTime("2025-04-2T00:00:00.000")
tend = tstart + 6000
print("start time: " + str(tstart))
print("end time: " + str(tend))

for item in unique_active_stations:
    print("Network: " + item[0] + ", Station: " + item[1])
    data = client.get_waveforms(network=item[0], station=item[1], location="*", channel="*", starttime=tstart, endtime=tend)
    item.append(data)
    print(data)
# Out:
# start time: 2025-04-02T00:00:00.000000Z
# end time: 2025-04-02T01:40:00.000000Z
# Network: HE, Station: JOF
# 3 Trace(s) in Stream:
# HE.JOF..HHE | 2025-04-01T23:59:56.430000Z - 2025-04-02T01:40:03.380000Z | 100.0 Hz, 600696 samples
# Network: FN, Station: RAJF
# 6 Trace(s) in Stream:
# FN.RAJF..BHE | 2025-04-01T23:59:45.250000Z - 2025-04-02T01:40:00.400000Z | 20.0 Hz, 120304 samples
# FN.RAJF..BHN | 2025-04-01T23:59:41.950000Z - 2025-04-02T01:40:12.600000Z | 20.0 Hz, 120614 samples
# FN.RAJF..BHZ | 2025-04-01T23:59:59.650000Z - 2025-04-02T01:40:14.800000Z | 20.0 Hz, 120304 samples
# FN.RAJF..HHE | 2025-04-01T23:59:59.850000Z - 2025-04-02T01:40:02.680000Z | 100.0 Hz, 600284 samples
# FN.RAJF..HHN | 2025-04-01T23:59:58.350000Z - 2025-04-02T01:40:01.180000Z | 100.0 Hz, 600284 samples
# FN.RAJF..HHZ | 2025-04-01T23:59:58.190000Z - 2025-04-02T01:40:01.020000Z | 100.0 Hz, 600284 samples
# Network: UP, Station: NOD
# 3 Trace(s) in Stream:
# UP.NOD..HHE | 2025-04-01T23:59:57.200000Z - 2025-04-02T01:40:01.090000Z | 100.0 Hz, 600390 samples
# UP.NOD..HHN | 2025-04-01T23:59:57.540000Z - 2025-04-02T01:40:02.350000Z | 100.0 Hz, 600482 samples
# UP.NOD..HHZ | 2025-04-01T23:59:58.890000Z - 2025-04-02T01:40:00.280000Z | 100.0 Hz, 600140 samples

# %%
pp(dir(unique_active_stations[0][2]))
unique_active_stations[1][2].plot()
# Out:
# [
#     '__add__',
#     '__class__',
#     '__delattr__',
#     '__delitem__',
#     '__dict__',
#     '__dir__',
#     '__doc__',
#     '__eq__',
#     '__format__',
#     '__ge__',
#     '__getattribute__',
#     '__getitem__',
#     '__getslice__',
#     '__getstate__',
#     '__gt__',
#     '__hash__',
#     '__iadd__',
#     '__init__',
#     '__init_subclass__',
#     '__iter__',
#     '__le__',
#     '__len__',
#     '__lt__',
#     '__module__',
#     '__mul__',
#     '__ne__',
#     '__new__',
#     '__nonzero__',
#     '__reduce__',
#     '__reduce_ex__',
#     '__repr__',
#     '__setattr__',
#     '__setitem__',
#     '__sizeof__',
#     '__slotnames__',
#     '__str__',
#     '__subclasshook__',
#     '__weakref__',
#     '_cleanup',
#     '_dummy_stream_from_string',
#     '_get_common_channels_info',
#     '_groupby',
#     '_ltrim',
#     '_merge_checks',
#     '_repr_pretty_',
#     '_rotate_specific_channels_to_zne',
#     '_rotate_to_zne',
#     '_rtrim',
#     '_trim_common_channels',
#     'append',
#     'attach_response',
#     'clear',
#     'copy',
#     'count',
#     'cutout',
#     'decimate',
#     'detrend',
#     'differentiate',
#     'extend',
#     'filter',
#     'get_gaps',
#     'insert',
#     'integrate',
#     'interpolate',
#     'max',
#     'merge',
#     'normalize',
#     'plot',
#     'pop',
#     'print_gaps',
#     'remove',
#     'remove_response',
#     'remove_sensitivity',
#     'resample',
#     'reverse',
#     'rotate',
#     'select',
#     'simulate',
#     'slice',
#     'slide',
#     'sort',
#     'spectrogram',
#     'split',
#     'stack',
#     'std',
#     'taper',
#     'traces',
#     'trigger',
#     'trim',
#     'verify',
#     'write',
# ]

# %% [markdown]
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <center><span style="color:green; font-size:3em; font-weight:bold;">Process the data, send the data to a computing e-infrastructure</span></center><br>

# %% [markdown]
# <center><span style="color:green; font-size:2.5em; font-weight:bold;">or simply visualise the data as they are</span></center>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>
#
# <br>

# %% [markdown]
# <span style="font-size:1.25em;">Processing, visualisation</span><br>
# <span style="color:green; font-size:2em;">Web map, integration of other data</span>

# %% [markdown]
# <span style="font-size:1.4em;">Use Folium, a Python interface to Leaflet.js, to display stations and data</span>

# %% [markdown]
# Compile list of station locations for the sizing of the background map (sizing works only in the notebook, not in the slides!)

# %%
gmllist = []
lat_min = 90.00
lat_max = -90.00
lon_min = 180.00
lon_max = -180.00

# GML point to lat lon tuple
def latlonfromgmlpoint(gmlpoint):
    latlon = re.search(r"(\d{1,2}.\d{1,})\s(-{0,1}\d{1,2}.\d{1,})", gmlpoint)
    return latlon[1], latlon[2]

# borehole locations
for key, value in boreholes.items():
    gmllist.append(boreholes[key]['GML_location'])
# locations of GNSS stations
for key, value in boreholes.items():
    if 'GNSS' in boreholes[key]:
        for subkey, subvalue in boreholes[key]['GNSS'].items():
            gmllist.append(subvalue)
# locations of seismic stations
for key, value in boreholes.items():
    if 'SeisStation' in boreholes[key]:
        for subkey, subvalue in boreholes[key]['SeisStation'].items():
            for subsubkey, subsubvalue in subvalue.items():
                gmllist.append(subsubvalue)
# discard duplicate values                
gmllist = set(gmllist)

# compile minimum and maximum values for latitude and longitude, add some boundary space
for item in gmllist:
    latlonitem = latlonfromgmlpoint(item)
    lat = float(latlonitem[0])
    lon = float(latlonitem[1])
    if lat > lat_max:
        lat_max = round(lat * 1.05, 4)
    if lat < lat_min:
        lat_min = round(lat * 0.95, 4)
    if lon > lon_max:
        lon_max = round(lon * 1.05, 4)
    if lon < lon_min:
        lon_min = round(lon * 0.95, 4)

pp(gmllist)
print(lat_max, lat_min, lon_max, lon_min)
# Out:
# set([
#     'POINT(17.283 73.733)',
#     'POINT(19.74 -155.05)',
#     'POINT(34.41 118.67)',
#     'POINT(35.97417 -120.55185)',
#     'POINT(35.97426 -120.55211)',
#     'POINT(37.3217 -75.9757)',
#     'POINT(46.2408 125.36307)',
#     'POINT(61.4247 28.9497 125)',
#     'POINT(61.87355658240056 28.725577291922274)',
#     'POINT(62.4195 13.5132)',
#     'POINT(62.44944 14.92132 0)',
#     'POINT(62.5615 11.55517 0)',
#     'POINT(62.71781 29.06199)',
#     'POINT(62.7194 26.1474 185)',
#     'POINT(62.80045 13.05265 0)',
#     'POINT(62.9187 31.3092 180)',
#     'POINT(63.0414 13.9679)',
#     'POINT(63.04408 11.6437 0)',
#     'POINT(63.11401 16.32236 0)',
#     'POINT(63.23047 13.67801 0)',
#     'POINT(63.31245 13.52648)',
#     'POINT(63.390016 27.810279 199)',
#     'POINT(63.40163 13.20292)',
#     'POINT(63.42033 10.43033 116)',
#     'POINT(63.4428 14.8573 450)',
#     'POINT(63.4545 10.43633 34)',
#     'POINT(63.455 10.44583 30)',
#     'POINT(63.513508262634765 29.12036122650406)',
#     'POINT(63.70518 12.34839 0)',
#     'POINT(63.81655 15.51477 0)',
#     'POINT(64.04353 11.33531 0)',
#     'POINT(64.0718 14.09061 0)',
#     'POINT(64.53033 11.96583 102)',
#     'POINT(64.53397 12.40071 0)',
#     'POINT(64.559998 -18.385999 858)',
#     'POINT(64.8202731 -17.146659 1018.6)',
#     'POINT(64.9504 -16.924)',
#     'POINT(65.6945 -16.7749)',
#     'POINT(65.7071 -16.764 481.76)',
#     'POINT(65.71587 -16.76452)',
#     'POINT(65.791374 -17.077607 353.45)',
#     'POINT(65.832884 -16.974195 387.735)',
#     'POINT(65.864229 -16.983212 346.932)',
#     'POINT(65.868483 -16.782713 471.934)',
#     'POINT(65.878674 -16.943032 378.1)',
#     'POINT(65.881797 -16.963475 340.44)',
#     'POINT(65.882865 -17.305678 185.702)',
#     'POINT(65.8853 -16.975 331.79)',
#     'POINT(65.899075 -17.011321 308.825)',
#     'POINT(65.909193 -17.071909 313.29)',
#     'POINT(65.9176 -17.57855 50)',
#     'POINT(65.935732 -16.889526 357.441)',
#     'POINT(65.936618 -16.963495 302.246)',
#     'POINT(65.9444 -18.3872 37)',
#     'POINT(65.9932 -17.37615 30)',
#     'POINT(66.0027 -17.1925 334.064)',
#     'POINT(66.037861 -17.334744 0)',
#     'POINT(66.043737 -17.33991 20)',
#     'POINT(66.04487 -17.340003 20)',
#     'POINT(66.045272 -17.33579 0)',
#     'POINT(66.045272 -17.33579 50)',
#     'POINT(66.04576 -17.338336 20)',
#     'POINT(66.047007 -17.341355 0)',
#     'POINT(66.047007 -17.341355 50)',
#     'POINT(66.0808 -17.30975 0)',
#     'POINT(66.12336 -17.90967 0)',
#     'POINT(66.12336 -17.90967 50)',
#     'POINT(66.1617 -17.24434 0)',
#     'POINT(66.406649 -16.48957 30)',
#     'POINT(66.4611 -15.9467)',
#     'POINT(68.47512 28.31099 238.4)',
#     'POINT(69.14895 26.99611 246)',
#     'POINT(69.17 29.28)',
#     'POINT(69.20068 25.69157 186)',
#     'POINT(69.45361 30.03907 64)',
#     'POINT(69.75651 27.00356 81)',
#     'POINT(70.12016 29.365 105)',
#     'POINT(70.5034 29.06682 272)',
# ])
# 73.6262 16.4188 131.25 -147.25

# %% [markdown]
# Set up a basic map with boreholes

# %%
import folium

# define the map
map = folium.Map(location=[(lat_max + lat_min)/2,(lon_max + lon_min)/2], tiles="CartoDB positron")
map.fit_bounds([[lat_min,lon_min],[lat_max,lon_max]])

# add the borehole locations to the map
for key, value in boreholes.items():
    coord = latlonfromgmlpoint(boreholes[key]['GML_location'])
    bh_icon = folium.features.CustomIcon('./images/Rigg_black_large.png', icon_size=(62,72), icon_anchor=(31,36),)
    bh_marker = folium.Marker(location=[coord[0],coord[1]], icon=bh_icon)
    bh_pop = folium.Popup(key)
    bh_marker.add_child(bh_pop)
    map.add_child(bh_marker)

# plot the map object
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a990dc058c05115d74425bc26e6c62e6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a990dc058c05115d74425bc26e6c62e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a990dc058c05115d74425bc26e6c62e6 = L.map(
#                 &quot;map_a990dc058c05115d74425bc26e6c62e6&quot;,
#                 {
#                     center: [45.0225, -8.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_deb62c9a07382a9dab3333462f62d58e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_deb62c9a07382a9dab3333462f62d58e.addTo(map_a990dc058c05115d74425bc26e6c62e6);
#
#
#             map_a990dc058c05115d74425bc26e6c62e6.fitBounds(
#                 [[16.4188, -147.25], [73.6262, 131.25]],
#                 {}
#             );
#
#
#             var marker_3b2107cfa66c113b4f1cb0e384416c91 = L.marker(
#                 [37.3217, -75.9757],
#                 {
# }
#             ).addTo(map_a990dc058c05115d74425bc26e6c62e6);
#
#
#         var icon_a19440f23f9560bbd7c280b2c9da6e84 = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [62, 72],
#   &quot;iconAnchor&quot;: [31, 36],
# });
#
#
#         var popup_c6c299b4d525f15c7b4c325fad8129ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd63c6e95c3da4cc8fe3585c2a092600 = $(`&lt;div id=&quot;html_cd63c6e95c3da4cc8fe3585c2a092600&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chesapeake, CBIS Eyreville-1 Corehole 63G69 (A)&lt;/div&gt;`)[0];
#                 popup_c6c299b4d525f15c7b4c325fad8129ab.setContent(html_cd63c6e95c3da4cc8fe3585c2a092600);
#
#
#
#         marker_3b2107cfa66c113b4f1cb0e384416c91.bindPopup(popup_c6c299b4d525f15c7b4c325fad8129ab)
#         ;
#
#
#
#
#                 marker_3b2107cfa66c113b4f1cb0e384416c91.setIcon(icon_a19440f23f9560bbd7c280b2c9da6e84);
#
#
#             var marker_76bd943cf98fef946dda3a98a94c1fbf = L.marker(
#                 [34.41, 118.0],
#                 {
# }
#             ).addTo(map_a990dc058c05115d74425bc26e6c62e6);
#
#
#         var icon_b55a8e50aaa2c91f731d5c417491c7bc = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [62, 72],
#   &quot;iconAnchor&quot;: [31, 36],
# });
#
#
#         var popup_c3fba42ab77ea3a33a99d06db92176b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0ad3e54dc79019a2f5f7be10b1ca625 = $(`&lt;div id=&quot;html_b0ad3e54dc79019a2f5f7be10b1ca625&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Donghai, CCSD-PH&lt;/div&gt;`)[0];
#                 popup_c3fba42ab77ea3a33a99d06db92176b8.setContent(html_b0ad3e54dc79019a2f5f7be10b1ca625);
#
#
#
#         marker_76bd943cf98fef946dda3a98a94c1fbf.bindPopup(popup_c3fba42ab77ea3a33a99d06db92176b8)
#         ;
#
#
#
#
#                 marker_76bd943cf98fef946dda3a98a94c1fbf.setIcon(icon_b55a8e50aaa2c91f731d5c417491c7bc);
#
#
#             var marker_8a099a62d67f3c12d649dcd31e6509d6 = L.marker(
#                 [34.41, 118.0],
#                 {
# }
#             ).addTo(map_a990dc058c05115d74425bc26e6c62e6);
#
#
#         var icon_9667cc2f0580ee6a23c58e610ca8019d = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [62, 72],
#   &quot;iconAnchor&quot;: [31, 36],
# });
#
#
#         var popup_187c9a8782c4eb38a0fe19f10b9a4365 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1cf08e066551d9ba546848913ac60f16 = $(`&lt;div id=&quot;html_1cf08e066551d9ba546848913ac60f16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Donghai, CCSD-MH-2K&lt;/div&gt;`)[0];
#                 popup_187c9a8782c4eb38a0fe19f10b9a4365.setContent(html_1cf08e066551d9ba546848913ac60f16);
#
#
#
#         marker_8a099a62d67f3c12d649dcd31e6509d6.bindPopup(popup_187c9a8782c4eb38a0fe19f10b9a4365)
#         ;
#
#
#
#
#                 marker_8a099a62d67f3c12d649dcd31e6509d6.setIcon(icon_9667cc2f0580ee6a23c58e610ca8019d);
#
#
#             var marker_6934c3a9d24aef68c7333b0c5a49370a = L.marker(
#                 [46.2408, 125.0],
#                 {
# }
#             ).addTo(map_a990dc058c05115d74425bc26e6c62e6);

# %% [markdown]
# Add GNSS stations

# %%
# compile data for the markers
GNSSstations = {}
for key, value in boreholes.items():
    if 'GNSS' in boreholes[key]:
        for subkey, subvalue in boreholes[key]['GNSS'].items():
            coord = latlonfromgmlpoint(subvalue)
            if subkey in sensordata['GNSS']['positions10years']:
                timeseries = sensordata['GNSS']['positions10years'][subkey]
            else:
                timeseries = {}
            GNSSstations[subkey] = [coord[0], coord[1], timeseries]

# %%
# %%capture

# get rid of filter warnings, mainly with regard to deprecation warnings between packages
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning)

# import matplotlib to plot data for popups
import matplotlib.pyplot as plt

# import mpld3 converter to convert matplotlib figures to html string
import mpld3


# define the icon for GNSS stations
gnss_icon = folium.features.CustomIcon(
    'https://www.epos-eu.org/sites/default/files/2021-11/GNSS%20Data%20and%20Products%20v2.png',
    icon_size=(30,30),
    icon_anchor=(15, 15),
)

# define the plot function
def gnssplot(data):
    time = []
    data = json.loads(data)
    for t in data['domain']['axes']['t']['values']:
        time.append(datetime.fromisoformat(t.replace('Z', '+00:00')))
    e = data['ranges']['E']['values']
    n = data['ranges']['N']['values']
    u = data['ranges']['U']['values']
    fig = plt.figure(figsize=(5, 2))
    plt.plot(time, e, label='E', marker='.', markersize=1, linewidth=0.5)
    plt.plot(time, n, label='N', marker='.', markersize=1, linewidth=0.5)
    plt.plot(time, u, label='U', marker='.', markersize=1, linewidth=0.5)
    plt.xlabel('year')
    plt.ylabel('rel. dist. [mm]')
    plt.title(k)
    plt.legend()
    return fig


# if time series data are available, prepare the plot
for k,v in GNSSstations.items():
    if v[2] != {}:
        figure = gnssplot(v[2])
#define the data pop-up
        htmlplot = mpld3.fig_to_html(figure)
        iframe = folium.IFrame(htmlplot, width=525, height=225)
        popup = folium.Popup(iframe, max_width=2650)

    else:
        popup = folium.Popup(k)
       
# define the marker
    gnss_marker = folium.Marker(location=[v[0],v[1]], icon=gnss_icon, popup=popup)

# add the marker to the map
    map.add_child(gnss_marker)

# %%
# call the map object
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a990dc058c05115d74425bc26e6c62e6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a990dc058c05115d74425bc26e6c62e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a990dc058c05115d74425bc26e6c62e6 = L.map(
#                 &quot;map_a990dc058c05115d74425bc26e6c62e6&quot;,
#                 {
#                     center: [45.0225, -8.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_deb62c9a07382a9dab3333462f62d58e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_deb62c9a07382a9dab3333462f62d58e.addTo(map_a990dc058c05115d74425bc26e6c62e6);
#
#
#             map_a990dc058c05115d74425bc26e6c62e6.fitBounds(
#                 [[16.4188, -147.25], [73.6262, 131.25]],
#                 {}
#             );
#
#
#             var marker_3b2107cfa66c113b4f1cb0e384416c91 = L.marker(
#                 [37.3217, -75.9757],
#                 {
# }
#             ).addTo(map_a990dc058c05115d74425bc26e6c62e6);
#
#
#         var icon_a19440f23f9560bbd7c280b2c9da6e84 = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [62, 72],
#   &quot;iconAnchor&quot;: [31, 36],
# });
#
#
#         var popup_c6c299b4d525f15c7b4c325fad8129ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd63c6e95c3da4cc8fe3585c2a092600 = $(`&lt;div id=&quot;html_cd63c6e95c3da4cc8fe3585c2a092600&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chesapeake, CBIS Eyreville-1 Corehole 63G69 (A)&lt;/div&gt;`)[0];
#                 popup_c6c299b4d525f15c7b4c325fad8129ab.setContent(html_cd63c6e95c3da4cc8fe3585c2a092600);
#
#
#
#         marker_3b2107cfa66c113b4f1cb0e384416c91.bindPopup(popup_c6c299b4d525f15c7b4c325fad8129ab)
#         ;
#
#
#
#
#                 marker_3b2107cfa66c113b4f1cb0e384416c91.setIcon(icon_a19440f23f9560bbd7c280b2c9da6e84);
#
#
#             var marker_76bd943cf98fef946dda3a98a94c1fbf = L.marker(
#                 [34.41, 118.0],
#                 {
# }
#             ).addTo(map_a990dc058c05115d74425bc26e6c62e6);
#
#
#         var icon_b55a8e50aaa2c91f731d5c417491c7bc = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [62, 72],
#   &quot;iconAnchor&quot;: [31, 36],
# });
#
#
#         var popup_c3fba42ab77ea3a33a99d06db92176b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0ad3e54dc79019a2f5f7be10b1ca625 = $(`&lt;div id=&quot;html_b0ad3e54dc79019a2f5f7be10b1ca625&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Donghai, CCSD-PH&lt;/div&gt;`)[0];
#                 popup_c3fba42ab77ea3a33a99d06db92176b8.setContent(html_b0ad3e54dc79019a2f5f7be10b1ca625);
#
#
#
#         marker_76bd943cf98fef946dda3a98a94c1fbf.bindPopup(popup_c3fba42ab77ea3a33a99d06db92176b8)
#         ;
#
#
#
#
#                 marker_76bd943cf98fef946dda3a98a94c1fbf.setIcon(icon_b55a8e50aaa2c91f731d5c417491c7bc);
#
#
#             var marker_8a099a62d67f3c12d649dcd31e6509d6 = L.marker(
#                 [34.41, 118.0],
#                 {
# }
#             ).addTo(map_a990dc058c05115d74425bc26e6c62e6);
#
#
#         var icon_9667cc2f0580ee6a23c58e610ca8019d = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [62, 72],
#   &quot;iconAnchor&quot;: [31, 36],
# });
#
#
#         var popup_187c9a8782c4eb38a0fe19f10b9a4365 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1cf08e066551d9ba546848913ac60f16 = $(`&lt;div id=&quot;html_1cf08e066551d9ba546848913ac60f16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Donghai, CCSD-MH-2K&lt;/div&gt;`)[0];
#                 popup_187c9a8782c4eb38a0fe19f10b9a4365.setContent(html_1cf08e066551d9ba546848913ac60f16);
#
#
#
#         marker_8a099a62d67f3c12d649dcd31e6509d6.bindPopup(popup_187c9a8782c4eb38a0fe19f10b9a4365)
#         ;
#
#
#
#
#                 marker_8a099a62d67f3c12d649dcd31e6509d6.setIcon(icon_9667cc2f0580ee6a23c58e610ca8019d);
#
#
#             var marker_6934c3a9d24aef68c7333b0c5a49370a = L.marker(
#                 [46.2408, 125.0],
#                 {
# }
#             ).addTo(map_a990dc058c05115d74425bc26e6c62e6);

# %% [markdown]
# Add seismic stations that have data (first case with dictionaries)

# %%
# %%capture

# compile data for the markers
stations = []
for key, value in boreholes.items():
    if 'SeisStation' in boreholes[key]:
        for subkey, subvalue in boreholes[key]['SeisStation'].items():
            for subsubkey, subsubvalue in subvalue.items():
                coord = latlonfromgmlpoint(subsubvalue)
                if subsubkey in sensordata['Seismic']['waveforms']:
                    stations.append((subsubkey,coord[0],coord[1]))
stations = set(stations)

for item in stations:
# define the icon for seismic stations
    seis_icon = folium.features.CustomIcon(
        'https://www.epos-eu.org/sites/default/files/2021-11/Seismology%20v2.png',
        icon_size=(30,30),
        icon_anchor=(15, 15),
    )

#define the data pop-up
    htmlplot = mpld3.fig_to_html(sensordata['Seismic']['waveforms'][item[0]][next(iter(sensordata['Seismic']['waveforms'][item[0]]))].plot())
    iframe = folium.IFrame(htmlplot, width=840, height=290)
    popup = folium.Popup(iframe, max_width=2650)
        
# define the marker
    seis_marker = folium.Marker(location=[item[1],item[2]], icon=seis_icon, popup=popup)

# add the marker to the map
    map.add_child(seis_marker)

# %%
# call the map object
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a990dc058c05115d74425bc26e6c62e6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a990dc058c05115d74425bc26e6c62e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a990dc058c05115d74425bc26e6c62e6 = L.map(
#                 &quot;map_a990dc058c05115d74425bc26e6c62e6&quot;,
#                 {
#                     center: [45.0225, -8.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_deb62c9a07382a9dab3333462f62d58e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_deb62c9a07382a9dab3333462f62d58e.addTo(map_a990dc058c05115d74425bc26e6c62e6);
#
#
#             map_a990dc058c05115d74425bc26e6c62e6.fitBounds(
#                 [[16.4188, -147.25], [73.6262, 131.25]],
#                 {}
#             );
#
#
#             var marker_3b2107cfa66c113b4f1cb0e384416c91 = L.marker(
#                 [37.3217, -75.9757],
#                 {
# }
#             ).addTo(map_a990dc058c05115d74425bc26e6c62e6);
#
#
#         var icon_a19440f23f9560bbd7c280b2c9da6e84 = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [62, 72],
#   &quot;iconAnchor&quot;: [31, 36],
# });
#
#
#         var popup_c6c299b4d525f15c7b4c325fad8129ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd63c6e95c3da4cc8fe3585c2a092600 = $(`&lt;div id=&quot;html_cd63c6e95c3da4cc8fe3585c2a092600&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chesapeake, CBIS Eyreville-1 Corehole 63G69 (A)&lt;/div&gt;`)[0];
#                 popup_c6c299b4d525f15c7b4c325fad8129ab.setContent(html_cd63c6e95c3da4cc8fe3585c2a092600);
#
#
#
#         marker_3b2107cfa66c113b4f1cb0e384416c91.bindPopup(popup_c6c299b4d525f15c7b4c325fad8129ab)
#         ;
#
#
#
#
#                 marker_3b2107cfa66c113b4f1cb0e384416c91.setIcon(icon_a19440f23f9560bbd7c280b2c9da6e84);
#
#
#             var marker_76bd943cf98fef946dda3a98a94c1fbf = L.marker(
#                 [34.41, 118.0],
#                 {
# }
#             ).addTo(map_a990dc058c05115d74425bc26e6c62e6);
#
#
#         var icon_b55a8e50aaa2c91f731d5c417491c7bc = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [62, 72],
#   &quot;iconAnchor&quot;: [31, 36],
# });
#
#
#         var popup_c3fba42ab77ea3a33a99d06db92176b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0ad3e54dc79019a2f5f7be10b1ca625 = $(`&lt;div id=&quot;html_b0ad3e54dc79019a2f5f7be10b1ca625&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Donghai, CCSD-PH&lt;/div&gt;`)[0];
#                 popup_c3fba42ab77ea3a33a99d06db92176b8.setContent(html_b0ad3e54dc79019a2f5f7be10b1ca625);
#
#
#
#         marker_76bd943cf98fef946dda3a98a94c1fbf.bindPopup(popup_c3fba42ab77ea3a33a99d06db92176b8)
#         ;
#
#
#
#
#                 marker_76bd943cf98fef946dda3a98a94c1fbf.setIcon(icon_b55a8e50aaa2c91f731d5c417491c7bc);
#
#
#             var marker_8a099a62d67f3c12d649dcd31e6509d6 = L.marker(
#                 [34.41, 118.0],
#                 {
# }
#             ).addTo(map_a990dc058c05115d74425bc26e6c62e6);
#
#
#         var icon_9667cc2f0580ee6a23c58e610ca8019d = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [62, 72],
#   &quot;iconAnchor&quot;: [31, 36],
# });
#
#
#         var popup_187c9a8782c4eb38a0fe19f10b9a4365 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1cf08e066551d9ba546848913ac60f16 = $(`&lt;div id=&quot;html_1cf08e066551d9ba546848913ac60f16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Donghai, CCSD-MH-2K&lt;/div&gt;`)[0];
#                 popup_187c9a8782c4eb38a0fe19f10b9a4365.setContent(html_1cf08e066551d9ba546848913ac60f16);
#
#
#
#         marker_8a099a62d67f3c12d649dcd31e6509d6.bindPopup(popup_187c9a8782c4eb38a0fe19f10b9a4365)
#         ;
#
#
#
#
#                 marker_8a099a62d67f3c12d649dcd31e6509d6.setIcon(icon_9667cc2f0580ee6a23c58e610ca8019d);
#
#
#             var marker_6934c3a9d24aef68c7333b0c5a49370a = L.marker(
#                 [46.2408, 125.0],
#                 {
# }
#             ).addTo(map_a990dc058c05115d74425bc26e6c62e6);

# %% [markdown]
# <span style="font-size:1.4em;">Add data from a local resource ("own" or "other research data")</span>

# %% [markdown]
# International database of Glacially Induced Faults (Munier et al. 2020)

# %%
# Commented out, as data were already downloaded in the explanatory section above
## Create data directory, if it does not exist
#if not os.path.exists('./data'):
#   os.makedirs('./data')
## use geopandas to read/convert diverse common geodata formats
import geopandas
#
## download data from PANGAEA database, dataset https://doi.org/10.1594/PANGAEA.922705 and unpack the shape file into the working directory
#getfile = urllib.request.urlretrieve("https://download.pangaea.de/dataset/922705/files/Glacially-Induced_Faults.zip", "./data/Glacially-Induced_Faults.zip")
#with zipfile.ZipFile('./data/Glacially-Induced_Faults.zip', 'r') as zip_ref:
#    zip_ref.extractall(path="./data")
## read the shape file and display it
gif = geopandas.read_file("./data/GIF.shp")
folium.GeoJson(gif, style_function=lambda x:{'color': 'red'}, tooltip=folium.GeoJsonTooltip(fields=['Complex_na'])).add_to(map)

# call the map object
map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a990dc058c05115d74425bc26e6c62e6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a990dc058c05115d74425bc26e6c62e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a990dc058c05115d74425bc26e6c62e6 = L.map(
#                 &quot;map_a990dc058c05115d74425bc26e6c62e6&quot;,
#                 {
#                     center: [45.0225, -8.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_deb62c9a07382a9dab3333462f62d58e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_deb62c9a07382a9dab3333462f62d58e.addTo(map_a990dc058c05115d74425bc26e6c62e6);
#
#
#             map_a990dc058c05115d74425bc26e6c62e6.fitBounds(
#                 [[16.4188, -147.25], [73.6262, 131.25]],
#                 {}
#             );
#
#
#             var marker_3b2107cfa66c113b4f1cb0e384416c91 = L.marker(
#                 [37.3217, -75.9757],
#                 {
# }
#             ).addTo(map_a990dc058c05115d74425bc26e6c62e6);
#
#
#         var icon_a19440f23f9560bbd7c280b2c9da6e84 = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [62, 72],
#   &quot;iconAnchor&quot;: [31, 36],
# });
#
#
#         var popup_c6c299b4d525f15c7b4c325fad8129ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cd63c6e95c3da4cc8fe3585c2a092600 = $(`&lt;div id=&quot;html_cd63c6e95c3da4cc8fe3585c2a092600&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Chesapeake, CBIS Eyreville-1 Corehole 63G69 (A)&lt;/div&gt;`)[0];
#                 popup_c6c299b4d525f15c7b4c325fad8129ab.setContent(html_cd63c6e95c3da4cc8fe3585c2a092600);
#
#
#
#         marker_3b2107cfa66c113b4f1cb0e384416c91.bindPopup(popup_c6c299b4d525f15c7b4c325fad8129ab)
#         ;
#
#
#
#
#                 marker_3b2107cfa66c113b4f1cb0e384416c91.setIcon(icon_a19440f23f9560bbd7c280b2c9da6e84);
#
#
#             var marker_76bd943cf98fef946dda3a98a94c1fbf = L.marker(
#                 [34.41, 118.0],
#                 {
# }
#             ).addTo(map_a990dc058c05115d74425bc26e6c62e6);
#
#
#         var icon_b55a8e50aaa2c91f731d5c417491c7bc = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [62, 72],
#   &quot;iconAnchor&quot;: [31, 36],
# });
#
#
#         var popup_c3fba42ab77ea3a33a99d06db92176b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0ad3e54dc79019a2f5f7be10b1ca625 = $(`&lt;div id=&quot;html_b0ad3e54dc79019a2f5f7be10b1ca625&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Donghai, CCSD-PH&lt;/div&gt;`)[0];
#                 popup_c3fba42ab77ea3a33a99d06db92176b8.setContent(html_b0ad3e54dc79019a2f5f7be10b1ca625);
#
#
#
#         marker_76bd943cf98fef946dda3a98a94c1fbf.bindPopup(popup_c3fba42ab77ea3a33a99d06db92176b8)
#         ;
#
#
#
#
#                 marker_76bd943cf98fef946dda3a98a94c1fbf.setIcon(icon_b55a8e50aaa2c91f731d5c417491c7bc);
#
#
#             var marker_8a099a62d67f3c12d649dcd31e6509d6 = L.marker(
#                 [34.41, 118.0],
#                 {
# }
#             ).addTo(map_a990dc058c05115d74425bc26e6c62e6);
#
#
#         var icon_9667cc2f0580ee6a23c58e610ca8019d = L.icon({
#   &quot;iconUrl&quot;: &quot;data:image/png;base64,...&quot;,
#   &quot;iconSize&quot;: [62, 72],
#   &quot;iconAnchor&quot;: [31, 36],
# });
#
#
#         var popup_187c9a8782c4eb38a0fe19f10b9a4365 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1cf08e066551d9ba546848913ac60f16 = $(`&lt;div id=&quot;html_1cf08e066551d9ba546848913ac60f16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Donghai, CCSD-MH-2K&lt;/div&gt;`)[0];
#                 popup_187c9a
